# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import json

from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.feature_extraction._stop_words import ENGLISH_STOP_WORDS
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB

from mytools import load_csv, preprocess_n_train, predict_n_evaluate, evaluate

# %% [markdown]
# ## Build corpus from train.csv file

# %%
traindf = load_csv("train")
traindf.head()

# %%
traindf.columns
# Out:
# Index(['movieid', 'reviewerName', 'isFrequentReviewer', 'reviewText',
#        'sentiment'],
#       dtype='object')

# %%
traindf.isna().sum()
# Out:
# movieid                  0
# reviewerName             0
# isFrequentReviewer       0
# reviewText            6447
# sentiment                0
# dtype: int64

# %%
traindf["reviewText"].fillna(" ", inplace=True) # replace NaN with empty string

# %%
pos_neg_ratio = traindf["sentiment"].value_counts()[0] / traindf["sentiment"].value_counts()[1]
pos_neg_ratio
# Out:
# 2.014204492842195

# %%
text = traindf["reviewText"]
text
# Out:
# 0         Henry Selick’s first movie since 2009’s Corali...
# 1         With a cast that reads like the Vogue Oscar pa...
# 2         Creed II does not give us anything but another...
# 3         I know what you're thinking, but this is no Li...
# 4         Director Fernando Meirelles tells the story wi...
#                                 ...
# 162753    A top-notch thriller with genuine surprises an...
# 162754    Some people find Derek Zoolander funny and lik...
# 162755    This fun, gentle comedy focuses mainly on them...
# 162756    The film is rescued by a strong third act, but...
# 162757            A peerless exercise in stimulus response.
# Name: reviewText, Length: 162758, dtype: object

# %% [markdown]
# ## Stop words

# %%
from sklearn.feature_extraction._stop_words import ENGLISH_STOP_WORDS

# %%
stop_words_all = json.load(open("stop_words.json", "r"))
type(stop_words_all), len(stop_words_all)
# Out:
# (list, 1160)

# %%
len(ENGLISH_STOP_WORDS), ENGLISH_STOP_WORDS

# %%
def get_tfidfs(text, stop_words=stop_words_all, max_features=10000):
    tvec = TfidfVectorizer(stop_words=stop_words, max_features=max_features)
    tvec.fit(text)
    text_transformed = tvec.transform(text)
    return text_transformed

# %%
text_transformed = get_tfidfs(text)
text_transformed.shape
# Out:
# c:\Users\All users\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:388: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['articl', 'mon'] not in stop_words.
#   warnings.warn('Your stop_words may be inconsistent with '
# (162758, 10000)

# %%
pos_text = traindf[traindf["sentiment"] == "POSITIVE"]["reviewText"]
neg_text = traindf[traindf["sentiment"] == "NEGATIVE"]["reviewText"]
pos_text.shape, neg_text.shape
# Out:
# ((108761,), (53997,))

# %%
pos_text_transformed = get_tfidfs(pos_text)
neg_text_transformed = get_tfidfs(neg_text)
pos_text_transformed.shape, neg_text_transformed.shape
# Out:
# ((108761, 10000), (53997, 10000))

# %%
def get_vocab(text, stop_words=stop_words_all, max_features=10000):
    tvec = TfidfVectorizer(stop_words=stop_words, max_features=max_features)
    tvec.fit(text)
    return tvec.vocabulary_

# %%
pos_vocab = get_vocab(pos_text)
neg_vocab = get_vocab(neg_text)
pos_vocab, neg_vocab
# Out:
# ({'henry': 4238,
#   'movie': 5884,
#   '2009': 59,
#   'coraline': 1974,
#   'motion': 5864,
#   'masterpiece': 5547,
#   'creed': 2082,
#   'superior': 8696,
#   'rocky': 7547,
#   'sequel': 7862,
#   'wins': 9841,
#   'points': 6679,
#   'expect': 3176,
#   'knockout': 5040,
#   'thinking': 8987,
#   'limitless': 5258,
#   'bradley': 1070,
#   'cooper': 1967,
#   'lucy': 5372,
#   'taps': 8849,
#   'brain': 1072,
#   'thrills': 9018,
#   'skills': 8102,
#   'passing': 6411,
#   'hour': 4364,
#   'director': 2518,
#   'fernando': 3413,
#   'tells': 8909,
#   'story': 8500,
#   'urgency': 9490,
#   'sharp': 7939,
#   'visual': 9623,
#   'compositions': 1796,
#   'washed': 9707,
#   'cinematography': 1566,
#   'gangster': 3772,
#   'life': 5230,
#   'rich': 7462,
#   'piece': 6577,
#   'storytelling': 8505,
#   'feels': 3398,
#   'bucks': 1187,
#   'heartfelt': 4194,
#   'lovely': 5351,
#   'performance': 6490,
#   'scott': 7765,
#   'bit': 900,
#   'long': 5317,
#   'cartoon': 1350,
#   'feature': 3386,
#   'sign': 8033,
#   'makers': 5442,
#   'fell': 3402,
#   'love': 5348,
#   'ratatouille': 7116,
#   'eighth': 2855,
#   'pixar': 6605,
#   'features': 3388,
#   'anchored': 428,
#   'charming': 1462,
#   'greta': 3992,
#   'gerwig': 3837,
#   'light': 5238,
#   'breezy': 1112,
#   'walk': 9661,
#   'central': 1402,
#   'park': 6392,
#   'refreshing': 7238,
#   'hanks': 4114,
#   'solo': 8225,
#   'beloved': 845,
#   'icon': 4431,
#   'fine': 3477,
#   'unfussy': 9407,
#   'form': 3616,
#   'family': 3315,
#   'films': 3467,
#   'delight': 2323,
#   'children': 1505,
#   'adults': 267,
#   'alike': 363,
#   'kids': 5003,
#   'entertaining': 3009,
#   'amazing': 392,
#   'documentary': 2629,
#   'ingeniously': 4625,
#   'constructed': 1890,
#   'hilarious': 4268,
#   'thrill': 9012,
#   'ride': 7474,
#   'underdog': 9362,
#   'year': 9964,
#   'conflict': 1840,
#   'insightful': 4664,
#   'film': 3457,
#   '13': 6,
#   'assassins': 607,
#   'reliably': 7286,
#   'ultimately': 9315,
#   'traditional': 9155,
#   'classic': 1593,
#   'brown': 1169,
#   'bag': 720,
#   'sneak': 8181,
#   'bottle': 1044,
#   'bitter': 906,
#   'cheap': 1473,
#   'match': 5553,
#   'characters': 1449,
#   'onscreen': 6199,
#   'relationship': 7273,
#   'quirky': 7045,
#   'script': 7783,
#   'packed': 6324,
#   'good': 3918,
#   'lines': 5266,
#   'wall': 9667,
#   'moments': 5810,
#   'stories': 8498,
#   'surprisingly': 8723,
#   'moving': 5890,
#   'places': 6609,
#   'model': 5795,
#   'dignified': 2494,
#   'delicate': 2319,
#   'restraint': 7406,
#   'times': 9063,
#   'weight': 9756,
#   'sumptuous': 8677,
#   'picture': 6573,
#   'fires': 3488,
#   'highly': 4266,
#   'recommend': 7194,
#   'check': 1475,
#   'big': 882,
#   'screen': 7773,
#   'fun': 3728,
#   'fashioned': 3351,
#   'hearted': 4192,
#   'action': 204,
#   'sense': 7843,
#   'humor': 4398,
#   'downbeat': 2669,
#   'theme': 8974,
#   'single': 8063,
#   'man': 5458,
#   'optimistic': 6226,
#   'human': 4384,
#   'gradually': 3951,
#   'peace': 6451,
#   'seemingly': 7818,
#   'pain': 6332,
#   'tragedy': 9160,
#   'intelligent': 4699,
#   'style': 8590,
#   'turns': 9291,
#   'dialogue': 2463,
#   'heavy': 4207,
#   'rote': 7594,
#   'enthralling': 3015,
#   'experience': 3184,
#   'bad': 716,
#   'sweeps': 8768,
#   'slow': 8146,
#   'spots': 8355,
#   'awful': 696,
#   'lot': 5338,
#   'exposition': 3223,
#   'easily': 2790,
#   'image': 4473,
#   'masculine': 5530,
#   'longing': 5320,
#   'freedom': 3675,
#   'mines': 5731,
#   'deeper': 2292,
#   'concerns': 1818,
#   'mank': 5473,
#   'incredibly': 4570,
#   'tedious': 8897,
#   'question': 7032,
#   'wrote': 9953,
#   'citizen': 1576,
#   'kane': 4965,
#   'hook': 4331,
#   'true': 9261,
#   'immense': 4492,
#   'relief': 7290,
#   'specific': 8291,
#   'failed': 3287,
#   'california': 1261,
#   'bid': 880,
#   'sterling': 8458,
#   'supporting': 8706,
#   'cast': 1360,
#   'parts': 6402,
#   'intelligence': 4698,
#   'sentimentality': 7857,
#   'ease': 2788,
#   'enthusiastically': 3018,
#   'acted': 202,
#   'sharply': 7942,
#   'written': 9951,
#   'honor': 4325,
#   'alien': 358,
#   'movies': 5889,
#   'hold': 4301,
#   'dear': 2255,
#   'assistant': 613,
#   'behaviour': 820,
#   'workplace': 9909,
#   'preach': 6782,
#   'hard': 4126,
#   'absorbed': 145,
#   'fascinating': 3347,
#   'formidable': 3621,
#   'driver': 2722,
#   'hate': 4148,
#   'strong': 8553,
#   'holds': 4303,
#   'audience': 652,
#   'moment': 5808,
#   'star': 8404,
#   'making': 5444,
#   'equally': 3041,
#   'drawn': 2698,
#   'bursts': 1231,
#   'black': 912,
#   'humour': 4401,
#   'emotional': 2921,
#   'depth': 2390,
#   'fan': 3317,
#   'cherish': 1489,
#   'dark': 2215,
#   'wit': 9859,
#   'intensity': 4705,
#   'work': 9901,
#   'eye': 3258,
#   'opener': 6207,
#   'focuses': 3564,
#   'shaking': 7919,
#   'events': 3095,
#   'feel': 3394,
#   'documentaries': 2628,
#   'tricky': 9238,
#   'business': 1236,
#   'staged': 8378,
#   'scenes': 7738,
#   'communicate': 1754,
#   'visceral': 9614,
#   'melancholy': 5621,
#   'hand': 4095,
#   'partners': 6401,
#   'dance': 2195,
#   'stiff': 8470,
#   'drink': 2717,
#   'pleasures': 6651,
#   'combination': 1714,
#   'proves': 6941,
#   'intoxicating': 4740,
#   'fancy': 3320,
#   'pants': 6367,
#   'boys': 1065,
#   'whip': 9787,
#   'outcome': 6257,
#   'campaign': 1275,
#   'progress': 6902,
#   'remains': 7303,
#   'snapshot': 8179,
#   'modern': 5799,
#   'politics': 6699,
#   'flux': 3558,
#   'hopeful': 4340,
#   'account': 181,
#   'idealism': 4438,
#   'brothers': 1166,
#   'coen': 1673,
#   'deliver': 2330,
#   'taut': 8868,
#   'vastly': 9522,
#   'time': 9057,
#   'leave': 5165,
#   'blows': 967,
#   'fresh': 3685,
#   'skeptical': 8088,
#   'wind': 9828,
#   'fairly': 3295,
#   'corny': 1982,
#   'melodramatic': 5626,
#   'territory': 8946,
#   'keeping': 4981,
#   'faith': 3298,
#   'operatic': 6214,
#   'emotions': 2923,
#   'genre': 3822,
#   'mild': 5710,
#   'filled': 3453,
#   'giggles': 3859,
#   'frightening': 3697,
#   'aim': 333,
#   'list': 5278,
#   'nancy': 5958,
#   'meyers': 5689,
#   'wise': 9850,
#   'type': 9305,
#   'acting': 203,
#   'pedigree': 6461,
#   'palatable': 6346,
#   'worth': 9920,
#   'warm': 9686,
#   'romantic': 7572,
#   'comedy': 1725,
#   'lopez': 5329,
#   'reputation': 7352,
#   'entertained': 3007,
#   'parents': 6389,
#   'chuckle': 1550,
#   'worthwhile': 9921,
#   'showcase': 7999,
#   'pacino': 6319,
#   'thoughtful': 8999,
#   'portrayal': 6732,
#   'stage': 8377,
#   'actor': 214,
#   'contemplative': 1902,
#   'darkly': 2218,
#   'comical': 1732,
#   'stylish': 8595,
#   'frisky': 3702,
#   'sets': 7885,
#   'franchise': 3653,
#   'deftly': 2309,
#   'view': 9578,
#   'fans': 3324,
#   'surely': 8712,
#   'fairy': 3296,
#   'tale': 8824,
#   'dreams': 2705,
#   'beast': 799,
#   'strikingly': 8543,
#   'shot': 7993,
#   'cleverly': 1608,
#   'scripted': 7784,
#   'unsettling': 9458,
#   'study': 8576,
#   'troubled': 9257,
#   'psychology': 6960,
#   'pressure': 6826,
#   'cooker': 1961,
#   'claustrophobia': 1600,
#   'small': 8155,
#   'island': 4806,
#   'recommended': 7196,
#   'animated': 455,
#   'oscar': 6251,
#   'basically': 772,
#   'disney': 2569,
#   'dreamworks': 2706,
#   'deserving': 2406,
#   'champion': 1424,
#   'inside': 4660,
#   'brainy': 1075,
#   'matched': 5554,
#   'splendor': 8338,
#   'spirit': 8325,
#   'miyazaki': 5786,
#   'humanist': 4387,
#   'reach': 7136,
#   'extends': 3239,
#   'imaginary': 4477,
#   'friend': 3690,
#   'trailers': 9166,
#   'unique': 9419,
#   'driven': 2721,
#   'remarkable': 7306,
#   'performances': 6491,
#   'costa': 1992,
#   'remember': 7308,
#   'soul': 8255,
#   'pungent': 6984,
#   'gorgeous': 3932,
#   'sweeping': 8767,
#   'entertainment': 3011,
#   'combines': 1717,
#   'epic': 3033,
#   'rain': 7078,
#   'muddy': 5896,
#   'hills': 4273,
#   'awe': 694,
#   'inspiring': 4676,
#   'intimate': 4738,
#   'offbeat': 6169,
#   'feminist': 3409,
#   'relevant': 7284,
#   'female': 3406,
#   'empowerment': 2937,
#   'roles': 7558,
#   'society': 8202,
#   'place': 6607,
#   'beings': 822,
#   'review': 7440,
#   'spanish': 8275,
#   'loses': 5334,
#   'narratively': 5968,
#   'washington': 9708,
#   'building': 1195,
#   'living': 5294,
#   'breathing': 1104,
#   'character': 1443,
#   'gilroy': 3863,
#   'knight': 5035,
#   'bong': 1013,
#   'joon': 4906,
#   'dazzles': 2242,
#   'senses': 7845,
#   'mind': 5726,
#   'delicious': 2321,
#   'concoction': 1824,
#   'artful': 575,
#   'delivers': 2333,
#   'poignant': 6673,
#   'cinematic': 1562,
#   'american': 404,
#   'sniper': 8184,
#   'crammed': 2048,
#   'heart': 4186,
#   'pounding': 6764,
#   'incredible': 4568,
#   'eastwood': 2794,
#   'distracted': 2594,
#   'patriotic': 6435,
#   'desire': 2411,
#   'real': 7149,
#   'ramifications': 7089,
#   'killing': 5008,
#   'titled': 9082,
#   'unsurprisingly': 9467,
#   'upsetting': 9486,
#   'watch': 9713,
#   'compelling': 1771,
#   'vega': 9526,
#   'mighty': 5706,
#   'glamorous': 3874,
#   'hey': 4253,
#   'douglas': 2667,
#   'tidy': 9041,
#   'ingratiating': 4630,
#   'ode': 6166,
#   'high': 4259,
#   'weird': 9759,
#   'resonates': 7383,
#   'silly': 8042,
#   'teeters': 8904,
#   'gimmicky': 3866,
#   'frustratingly': 3713,
#   'ambiguous': 397,
#   'credit': 2080,
#   'scrappy': 7767,
#   'thriller': 9014,
#   'enthralled': 3014,
#   'entire': 3020,
#   'travelogue': 9210,
#   'teeth': 8905,
#   'achieving': 194,
#   'lasting': 5117,
#   'political': 6696,
#   'satire': 7694,
#   'brilliance': 1130,
#   'mirror': 5754,
#   'produced': 6879,
#   'clarke': 1586,
#   'anger': 446,
#   'violence': 9601,
#   'captures': 1311,
#   'brutal': 1176,
#   'precision': 6790,
#   'belies': 828,
#   'inherent': 4636,
#   'messiness': 5672,
#   'phil': 6541,
#   'challenging': 1421,
#   'funny': 3739,
#   'sweet': 8769,
#   'die': 2476,
#   'terrific': 8942,
#   'minute': 5744,
#   'wire': 9847,
#   'james': 4834,
#   'bond': 1008,
#   'satisfying': 7702,
#   'neo': 6008,
#   'classical': 1594,
#   'edge': 2820,
#   'myths': 5949,
#   'face': 3266,
#   'motives': 5868,
#   'french': 3678,
#   'resistance': 7374,
#   'extremely': 3252,
#   'apollo': 500,
#   'space': 8268,
#   'program': 6901,
#   'stuff': 8577,
#   'naked': 5955,
#   'gun': 4055,
#   '20': 48,
#   'years': 9966,
#   'leslie': 5203,
#   'awesome': 695,
#   'gags': 3757,
#   'hit': 4287,
#   'connects': 1865,
#   'resembles': 7361,
#   'easy': 2795,
#   'laugh': 5124,
#   'game': 3767,
#   'fact': 3275,
#   'buy': 1247,
#   'silliness': 8041,
#   'longest': 5319,
#   'ridiculousness': 7480,
#   'honestly': 4321,
#   'jennifer': 4859,
#   'garner': 3784,
#   'sparkles': 8281,
#   'bogged': 990,
#   'abundance': 154,
#   'plot': 6657,
#   'developments': 2450,
#   'produce': 6878,
#   'twists': 9301,
#   'immersive': 4498,
#   'quarters': 7023,
#   'set': 7883,
#   'dream': 2702,
#   'dead': 2246,
#   'thinks': 8988,
#   'loss': 5336,
#   'appealing': 505,
#   'unabashed': 9320,
#   'streak': 8522,
#   'melodrama': 5624,
#   'superb': 8689,
#   'ensemble': 3000,
#   'lead': 5149,
#   'lovable': 5347,
#   'mode': 5794,
#   'circles': 1570,
#   'unusual': 9470,
#   'enigmatic': 2984,
#   'cinema': 1560,
#   'boy': 1060,
#   'dog': 2633,
#   'feelings': 3397,
#   'naomi': 5961,
#   'watts': 9721,
#   'nomination': 6070,
#   'absolutely': 143,
#   'mesmerizing': 5667,
#   'emotionally': 2922,
#   'devastating': 2443,
#   'morbid': 5843,
#   'awkward': 698,
#   'critique': 2107,
#   'jackman': 4824,
#   'perfect': 6486,
#   'mix': 5781,
#   'rogue': 7554,
#   'carefully': 1322,
#   'anxiety': 489,
#   'suffer': 8651,
#   'voyeuristic': 9645,
#   'add': 231,
#   'layers': 5144,
#   'fabulously': 3264,
#   'bizarre': 910,
#   'turned': 9288,
#   'questioning': 7034,
#   'eyes': 3260,
#   'seat': 7799,
#   'cinephiles': 1567,
#   'scintillating': 7759,
#   'cute': 2163,
#   'adorable': 258,
#   'overwhelmingly': 6304,
#   'works': 9910,
#   'beautifully': 807,
#   'executed': 3150,
#   'marks': 5509,
#   'impressive': 4529,
#   'debut': 2261,
#   'drive': 2720,
#   'car': 1313,
#   'suggests': 8664,
#   'people': 6477,
#   'riding': 7481,
#   'arrive': 568,
#   'intact': 4692,
#   'special': 8289,
#   'tolerance': 9091,
#   'envelope': 3026,
#   'pushing': 7007,
#   'deadpan': 2248,
#   'crass': 2054,
#   'magic': 5421,
#   'today': 9085,
#   'message': 5669,
#   'sends': 7838,
#   'continue': 1912,
#   'hear': 4183,
#   'sunny': 8684,
#   '80': 104,
#   'childhood': 1502,
#   'aging': 319,
#   'grandmother': 3963,
#   'garcia': 3777,
#   'nerve': 6013,
#   'tour': 9136,
#   'force': 3590,
#   'appreciated': 521,
#   'actors': 215,
#   'bound': 1048,
#   'choice': 1522,
#   'holiday': 4306,
#   'season': 7796,
#   'blockbuster': 947,
#   'deal': 2250,
#   'downey': 2671,
#   'charms': 1464,
#   'heck': 4209,
#   'opportunity': 6220,
#   'kevin': 4990,
#   'skilled': 8099,
#   'status': 8432,
#   'moves': 5883,
#   'briskly': 1141,
#   'point': 6675,
#   'solid': 8220,
#   'talented': 8826,
#   'modest': 5801,
#   'urban': 9488,
#   'massive': 5540,
#   'critical': 2104,
#   'word': 9899,
#   'mouth': 5878,
#   'cash': 1357,
#   'phenomenon': 6540,
#   'hollywood': 4310,
#   'enchanting': 2942,
#   'popping': 6714,
#   'visuals': 9625,
#   'voice': 9633,
#   'casting': 1361,
#   'fantastical': 3328,
#   'ages': 314,
#   'sinister': 8067,
#   'tapestry': 8846,
#   'unease': 9386,
#   'fury': 3743,
#   'ordinary': 6237,
#   'domestic': 2643,
#   'setting': 7886,
#   'terror': 8947,
#   'original': 6244,
#   'deeply': 2294,
#   'creepy': 2089,
#   'jia': 4872,
#   'creates': 2066,
#   'images': 4475,
#   'great': 3980,
#   'poetic': 6669,
#   'breath': 1101,
#   'suggestive': 8663,
#   'power': 6768,
#   'meaning': 5591,
#   'rarer': 7112,
#   'thing': 8985,
#   'contemporary': 1904,
#   'max': 5571,
#   'jacques': 4828,
#   'wright': 9941,
#   'ability': 131,
#   'lyrical': 5394,
#   'takes': 8823,
#   'including': 4554,
#   'startling': 8417,
#   'floating': 3540,
#   'funeral': 3735,
#   'death': 2256,
#   'soundtrack': 8261,
#   'remind': 7312,
#   'forbidden': 3589,
#   'passion': 6412,
#   'tears': 8881,
#   'rarely': 7111,
#   'blue': 969,
#   'main': 5430,
#   'collet': 1696,
#   'serra': 7874,
#   'drama': 2686,
#   'result': 7408,
#   'closer': 1638,
#   'baggage': 721,
#   'crime': 2093,
#   'novels': 6103,
#   'dennis': 2366,
#   'dumb': 2744,
#   'multiplex': 5903,
#   'fare': 3333,
#   'wings': 9834,
#   'quietly': 7040,
#   'adam': 223,
#   'commendable': 1739,
#   'sensitively': 7849,
#   'directed': 2513,
#   'shape': 7929,
#   'tremendous': 9227,
#   'lends': 5190,
#   'genuine': 3828,
#   'humanity': 4389,
#   'thrillingly': 9017,
#   'paced': 6316,
#   'eerily': 2837,
#   'topical': 9115,
#   'sicario': 8019,
#   'retains': 7412,
#   'predecessor': 6795,
#   'charm': 1459,
#   'creative': 2070,
#   'impact': 4503,
#   'hall': 4078,
#   'strays': 8521,
#   'sports': 8351,
#   'template': 8911,
#   'young': 9973,
#   'leads': 5153,
#   'blast': 923,
#   'stale': 8385,
#   'narrative': 5967,
#   'mary': 5528,
#   'witch': 9860,
#   'flower': 3549,
#   'colorful': 1705,
#   'visually': 9624,
#   'stunning': 8582,
#   'spectacle': 8293,
#   'packs': 6326,
#   'plenty': 6653,
#   'frames': 3648,
#   'truth': 9271,
#   'mother': 5859,
#   'rare': 7110,
#   'enjoy': 2985,
#   'fierce': 3440,
#   'rodriguez': 7550,
#   'seasoned': 7797,
#   'actress': 216,
#   'brings': 1137,
#   'magnificent': 5426,
#   'prove': 6938,
#   'role': 7557,
#   'elegant': 2868,
#   'hughes': 4380,
#   'wisely': 9852,
#   'niche': 6035,
#   'project': 6907,
#   'hell': 4224,
#   'lights': 5246,
#   'ready': 7147,
#   'afford': 294,
#   'viewer': 9580,
#   'pulse': 6972,
#   'rise': 7507,
#   'camera': 1270,
#   'frantic': 3664,
#   'infamous': 4604,
#   'butt': 1242,
#   'scene': 7736,
#   'audiences': 653,
#   'pie': 6576,
#   'shannon': 7928,
#   'conveys': 1949,
#   'killer': 5006,
#   'utter': 9498,
#   'detachment': 2433,
#   'providing': 6944,
#   'menacing': 5642,
#   'presence': 6813,
#   'throwback': 9026,
#   'sandler': 7678,
#   'ridiculous': 7478,
#   'zippy': 9991,
#   'girl': 3868,
#   'peppy': 6479,
#   'keaton': 4976,
#   'mad': 5409,
#   'money': 5815,
#   'wrong': 9952,
#   'filmmakers': 3464,
#   'wonderful': 9882,
#   'wizard': 9871,
#   'thread': 9004,
#   'millions': 5724,
#   'open': 6205,
#   'faced': 3267,
#   'seriousness': 7872,
#   'kid': 4998,
#   'goodness': 3921,
#   'meal': 5588,
#   'lives': 5293,
#   'turn': 9287,
#   'planned': 6620,
#   'surprises': 8721,
#   'provide': 6942,
#   'extra': 3246,
#   'flavor': 3517,
#   'airy': 340,
#   'confection': 1831,
#   'nostalgic': 6089,
#   'aims': 336,
#   'vision': 9617,
#   'moviemaking': 5888,
#   'earnest': 2782,
#   'sentimental': 7856,
#   'rugged': 7621,
#   'exploration': 3210,
#   'manhood': 5468,
#   'mortality': 5854,
#   'lost': 5337,
#   'hemingway': 4236,
#   'wan': 9675,
#   'deft': 2308,
#   'orchestrates': 6234,
#   'scariest': 7727,
#   'threads': 9005,
#   'jenkins': 4858,
#   'apos': 501,
#   'handling': 4104,
#   'sexuality': 7902,
#   'oblique': 6131,
#   '46': 90,
#   '1990s': 41,
#   'media': 5604,
#   'overdue': 6284,
#   'slick': 8134,
#   'riveting': 7523,
#   'mystery': 5941,
#   'succeeds': 8635,
#   'rapport': 7107,
#   'walker': 9664,
#   'melville': 5630,
#   'haunting': 4157,
#   'elegantly': 2869,
#   'spare': 8278,
#   'kind': 5012,
#   'silence': 8038,
#   'bare': 752,
#   'surroundings': 8731,
#   'lonely': 5316,
#   'bird': 897,
#   'studio': 8574,
#   'released': 7279,
#   'mulan': 5897,
#   'build': 1194,
#   'final': 3470,
#   'zemeckis': 9986,
#   'realized': 7160,
#   'material': 5557,
#   'lay': 5140,
#   'stars': 8412,
#   'appeal': 504,
#   'contrived': 1930,
#   'predictable': 6800,
#   'couple': 2011,
#   'hedges': 4211,
#   'wraps': 9932,
#   'powerful': 6770,
#   'gut': 4060,
#   'punch': 6979,
#   'george': 3830,
#   'dramatic': 2688,
#   'step': 8451,
#   'masses': 5539,
#   'disturbing': 2601,
#   'event': 3094,
#   'board': 979,
#   'superbly': 8691,
#   'understated': 9374,
#   'lily': 5253,
#   'rose': 7590,
#   'depp': 2385,
#   'handles': 4103,
#   'condition': 1829,
#   'believing': 836,
#   'sensitivity': 7850,
#   'empathy': 2927,
#   'zombie': 9994,
#   'understands': 9373,
#   'ways': 9726,
#   'creeps': 2088,
#   'difficult': 2485,
#   'interesting': 4716,
#   'insights': 4665,
#   'terms': 8937,
#   'state': 8421,
#   'generally': 3808,
#   'played': 6631,
#   'conceit': 1807,
#   'delicately': 2320,
#   'examining': 3122,
#   'intimacy': 4737,
#   'fall': 3302,
#   'wars': 9702,
#   'han': 4093,
#   'spotlight': 8353,
#   'deserves': 2405,
#   'morgan': 5848,
#   'whimsical': 9785,
#   'grown': 4029,
#   'blend': 933,
#   'noir': 6062,
#   'tropes': 9255,
#   'starts': 8419,
#   'lighthearted': 5240,
#   'bergman': 864,
#   'steam': 8443,
#   'half': 4076,
#   'reality': 7157,
#   'fiction': 3431,
#   'explicitly': 3201,
#   'beach': 792,
#   'raw': 7130,
#   'personal': 6515,
#   'hong': 4324,
#   'essential': 3065,
#   'reminder': 7314,
#   'gondry': 3915,
#   'brooding': 1158,
#   'excellent': 3130,
#   'option': 6228,
#   'hours': 4365,
#   'hustle': 4416,
#   'grand': 3957,
#   'notch': 6092,
#   'comedians': 1722,
#   'steal': 8439,
#   'win': 9826,
#   'strength': 8529,
#   'aesthetic': 280,
#   'watching': 9717,
#   'based': 769,
#   'mood': 5832,
#   'skate': 8086,
#   'culture': 2143,
#   'hands': 4106,
#   'filmmaker': 3463,
#   'doc': 2621,
#   'sport': 8349,
#   'cum': 2145,
#   'lifestyle': 5232,
#   'gary': 3785,
#   'gray': 3978,
#   'sympathetic': 8795,
#   'bombastic': 1004,
#   'depicts': 2384,
#   'rough': 7598,
#   'stupid': 8586,
#   'excesses': 3137,
#   'fame': 3309,
#   'quasi': 7025,
#   'criminal': 2095,
#   'activities': 212,
#   'bravery': 1084,
#   'compassion': 1769,
#   'resilience': 7371,
#   'cave': 1385,
#   'sober': 8195,
#   'huppert': 4410,
#   'manages': 5461,
#   'hansen': 4118,
#   'flat': 3516,
#   'writing': 9950,
#   'alive': 364,
#   'energetic': 2968,
#   'caper': 1298,
#   'fails': 3290,
#   'succeed': 8632,
#   'penn': 6474,
#   'sympathies': 8796,
#   'lie': 5228,
#   'driving': 2724,
#   'intent': 4706,
#   'document': 2626,
#   'celebrate': 1386,
#   'save': 7711,
#   'sequences': 7865,
#   'pictures': 6574,
#   'jacket': 4822,
#   'wearing': 9739,
#   'hopper': 4346,
#   'mirrors': 5755,
#   ...},
#  {'cast': 1381,
#   'reads': 7124,
#   'oscar': 6219,
#   'party': 6372,
#   'guest': 4092,
#   'list': 5293,
#   'valentine': 9508,
#   'day': 2216,
#   'cinema': 1571,
#   'standard': 8380,
#   'hollywood': 4377,
#   'schmaltz': 7696,
#   'small': 8110,
#   'pleasures': 6605,
#   'movie': 5862,
#   'offer': 6151,
#   'memorable': 5616,
#   'inventive': 4837,
#   'news': 6002,
#   'reporting': 7325,
#   'process': 6837,
#   'inside': 4734,
#   'walk': 9657,
#   'talk': 8838,
#   'rumor': 7579,
#   'realize': 7136,
#   'interesting': 4796,
#   'character': 1453,
#   'spend': 8280,
#   'time': 9058,
#   'robinson': 7495,
#   'handsome': 4168,
#   'dud': 2762,
#   'film': 3462,
#   'suggests': 8674,
#   'jennifer': 4916,
#   'cam': 1290,
#   'puke': 6940,
#   'scene': 7687,
#   'dream': 2708,
#   'stretched': 8529,
#   '80': 120,
#   'minutes': 5712,
#   'feels': 3413,
#   'lot': 5361,
#   'men': 5620,
#   'diluted': 2463,
#   'adaptation': 238,
#   'point': 6631,
#   'preposterousness': 6775,
#   'eastwood': 2833,
#   'handled': 4164,
#   'squeaky': 8351,
#   'clean': 1608,
#   'insufferably': 4767,
#   'perfect': 6452,
#   'protagonist': 6903,
#   'hope': 4403,
#   'people': 6447,
#   'unhappy': 9409,
#   'efforts': 2874,
#   'reduced': 7194,
#   'pop': 6665,
#   'psychological': 6930,
#   'observations': 6115,
#   'filmmaker': 3468,
#   'making': 5456,
#   'intentions': 4791,
#   'ambition': 405,
#   'deeply': 2263,
#   'vacuous': 9502,
#   'ironically': 4858,
#   'inconsequential': 4628,
#   'death': 2235,
#   '1973': 31,
#   'country': 1984,
#   'singer': 8006,
#   'legend': 5200,
#   'figure': 3451,
#   'rambling': 7067,
#   'low': 5377,
#   'key': 5026,
#   'modest': 5777,
#   'contribution': 1921,
#   'werner': 9776,
#   'herzog': 4305,
#   'story': 8494,
#   'chef': 1501,
#   'shut': 7965,
#   'great': 4022,
#   'stuck': 8570,
#   'screams': 7724,
#   'ideas': 4504,
#   'execution': 3173,
#   'problem': 6831,
#   'release': 7256,
#   'lies': 5246,
#   'script': 7736,
#   'late': 5145,
#   '40': 96,
#   'years': 9957,
#   'review': 7409,
#   'spanish': 8245,
#   'special': 8259,
#   'effects': 2867,
#   'extravaganza': 3278,
#   'dead': 2221,
#   'wrong': 9941,
#   'turns': 9292,
#   'robert': 7492,
#   'downey': 2665,
#   'game': 3794,
#   'witty': 9869,
#   'kind': 5047,
#   'cutesy': 2150,
#   'idea': 4499,
#   'ring': 7461,
#   'remotely': 7298,
#   'true': 9267,
#   'dark': 2197,
#   'places': 6568,
#   'girl': 3898,
#   'terms': 8935,
#   'flynn': 3581,
#   'crafting': 2011,
#   'distasteful': 2573,
#   'female': 3419,
#   'characters': 1459,
#   'speak': 8255,
#   'stories': 8492,
#   'male': 5461,
#   'filmmakers': 3469,
#   'unfunny': 9407,
#   'aimless': 337,
#   'star': 8389,
#   'framed': 3668,
#   'life': 5247,
#   'cold': 1692,
#   'blooded': 994,
#   'killer': 5040,
#   'choice': 1534,
#   'dull': 2770,
#   'uninvolving': 9422,
#   'performance': 6456,
#   'chooses': 1539,
#   'path': 6395,
#   'glance': 3906,
#   'downward': 2670,
#   'reveals': 7399,
#   'worn': 9908,
#   'plot': 6612,
#   'vehicles': 9534,
#   'road': 7486,
#   'shallow': 7868,
#   'cleverness': 1614,
#   'acknowledging': 218,
#   'shallowness': 7869,
#   'storyline': 8495,
#   'clever': 1612,
#   'takes': 8832,
#   'scenes': 7689,
#   'observation': 6113,
#   'painfully': 6307,
#   'obvious': 6123,
#   'influences': 4694,
#   'strangers': 8511,
#   'innovation': 4721,
#   'imaginative': 4542,
#   'set': 7829,
#   'pieces': 6536,
#   'movies': 5866,
#   'premise': 6767,
#   'extreme': 3279,
#   'haunt': 4225,
#   'situation': 8027,
#   'actors': 230,
#   'talented': 8835,
#   'funny': 3762,
#   'queen': 7012,
#   'latifah': 5147,
#   'steve': 8449,
#   'martin': 5527,
#   'waste': 9701,
#   'offensive': 6149,
#   'exercise': 3176,
#   'bad': 729,
#   'sitcom': 8023,
#   'supernatural': 8711,
#   'romance': 7522,
#   'cum': 2130,
#   'whodunit': 9802,
#   'strains': 8504,
#   'weight': 9760,
#   'elements': 2902,
#   'bangkok': 764,
#   'cinematography': 1576,
#   'moments': 5786,
#   'falls': 3327,
#   'short': 7935,
#   'gritty': 4057,
#   'realism': 7130,
#   'original': 6214,
#   'whiff': 9788,
#   'exotic': 3197,
#   'redolent': 7192,
#   'banal': 757,
#   'groundbreaking': 4068,
#   'storytelling': 8498,
#   'fairly': 3317,
#   'trivial': 9253,
#   'leads': 5176,
#   'cynicism': 2157,
#   'blatant': 967,
#   'unpleasant': 9440,
#   'seemingly': 7767,
#   'pointed': 6632,
#   'draining': 2688,
#   'watch': 9707,
#   'wall': 9663,
#   'separates': 7807,
#   'producers': 6843,
#   'writers': 9937,
#   'directors': 2489,
#   'mental': 5624,
#   'effort': 2871,
#   'represent': 7326,
#   'artistic': 580,
#   'manner': 5486,
#   'clichés': 1623,
#   'disposal': 2562,
#   'worked': 9901,
#   'budget': 1207,
#   'wonders': 9889,
#   'disappearance': 2497,
#   'alice': 364,
#   'creed': 2054,
#   'handles': 4165,
#   'shifts': 7909,
#   'twists': 9302,
#   'efficiently': 2870,
#   'result': 7379,
#   'remains': 7280,
#   'crucially': 2099,
#   'lacking': 5106,
#   'surprise': 8730,
#   'cinematic': 1573,
#   'equivalent': 3069,
#   'patronizing': 6407,
#   'bar': 769,
#   'pretentious': 6797,
#   'untalented': 9465,
#   'enjoy': 3009,
#   'cruel': 2104,
#   'fate': 3377,
#   'dialogue': 2428,
#   'animation': 459,
#   'left': 5195,
#   'sense': 7792,
#   'qualifies': 7000,
#   'animal': 456,
#   'cruelty': 2105,
#   'issue': 4873,
#   'hint': 4335,
#   'levity': 5234,
#   'distract': 2581,
#   'gravity': 4019,
#   'lightness': 5258,
#   'initially': 4712,
#   'blithe': 983,
#   'spirit': 8297,
#   'enjoyable': 3010,
#   'experience': 3212,
#   'eventually': 3122,
#   'peter': 6492,
#   'violence': 9596,
#   'southern': 8237,
#   'thriller': 9015,
#   'acting': 221,
#   'amateurish': 398,
#   'disservice': 2566,
#   'hard': 4192,
#   'working': 9903,
#   'intriguing': 4826,
#   'setup': 7838,
#   'runner': 7581,
#   'devolves': 2421,
#   'books': 1060,
#   'die': 2442,
#   'drunken': 2757,
#   'uncle': 9337,
#   'wedding': 9748,
#   'disco': 2518,
#   'fine': 3483,
#   'fun': 3750,
#   'zombie': 9990,
#   'expense': 3210,
#   'quest': 7016,
#   'inevitable': 4677,
#   'inspirational': 4748,
#   'destination': 2390,
#   'continuing': 1914,
#   'trend': 9227,
#   'precious': 6745,
#   'theater': 8963,
#   'space': 8239,
#   'dumping': 2785,
#   'grounds': 4071,
#   'pbs': 6423,
#   'crowd': 2092,
#   'stinker': 8466,
#   'cultural': 2126,
#   'collection': 1703,
#   'dry': 2758,
#   'interviews': 4819,
#   'music': 5899,
#   'suited': 8680,
#   'public': 6935,
#   'big': 918,
#   'screen': 7726,
#   'shake': 7863,
#   'head': 4236,
#   'disbelief': 2512,
#   'nonsensical': 6046,
#   'machinations': 5422,
#   'idiotic': 4513,
#   'motivations': 5846,
#   'required': 7337,
#   'bring': 1163,
#   'terror': 8945,
#   'titans': 9084,
#   'kevin': 5025,
#   'bacon': 728,
#   'degrees': 2287,
#   'separation': 7808,
#   'remarkable': 7284,
#   'virtually': 9601,
#   'decision': 2253,
#   'director': 2487,
#   'completely': 1790,
#   'misguided': 5739,
#   'goofy': 3970,
#   'pig': 6540,
#   'pile': 6542,
#   'happening': 4186,
#   'barely': 775,
#   'beautifully': 842,
#   'shot': 7941,
#   'long': 5338,
#   'pained': 6305,
#   'references': 7208,
#   'holocaust': 4379,
#   'tailor': 8829,
#   'awards': 696,
#   'personal': 6480,
#   'reasons': 7146,
#   'sequel': 7809,
#   '2008': 64,
#   'journey': 4961,
#   'center': 1418,
#   'earth': 2825,
#   'amusement': 426,
#   'park': 6358,
#   'ride': 7443,
#   'grown': 4076,
#   'theme': 8971,
#   'inspired': 4751,
#   'adventure': 281,
#   'step': 8436,
#   'giant': 3877,
#   'leap': 5181,
#   'corporate': 1965,
#   'heart': 4251,
#   'place': 6566,
#   'screenplay': 7728,
#   'sam': 7629,
#   'levinson': 5233,
#   'based': 795,
#   'malcolm': 5460,
#   'marie': 5505,
#   'actual': 234,
#   'events': 3120,
#   'distance': 2569,
#   'material': 5553,
#   'needed': 5971,
#   'leaden': 5173,
#   'attempt': 643,
#   'recapture': 7158,
#   'classic': 1602,
#   'screwball': 7734,
#   'python': 6997,
#   'completists': 1791,
#   'simply': 8001,
#   'runs': 7583,
#   'good': 3961,
#   'nominee': 6042,
#   'starts': 8405,
#   'throwing': 9026,
#   'audience': 659,
#   'sticks': 8456,
#   'class': 1600,
#   'kiss': 5060,
#   'mess': 5645,
#   'theaters': 8964,
#   'tough': 9146,
#   'build': 1213,
#   'study': 8578,
#   'unconvincing': 9342,
#   'impossible': 4578,
#   'master': 5545,
#   'disguise': 2538,
#   'feel': 3409,
#   'embarrassed': 2925,
#   'stars': 8398,
#   'winner': 9842,
#   'berry': 902,
#   'money': 5790,
#   'badly': 732,
#   'redford': 7189,
#   'wanted': 9677,
#   'note': 6061,
#   'accurate': 203,
#   'description': 2371,
#   'pulp': 6945,
#   'daredevil': 2194,
#   'rises': 7474,
#   'mind': 5697,
#   'cake': 1275,
#   'air': 340,
#   'wind': 9829,
#   'balance': 745,
#   'grandiosity': 4002,
#   'playfulness': 6592,
#   'lampoon': 5119,
#   'indian': 4642,
#   'somber': 8197,
#   'account': 201,
#   'history': 4345,
#   'greed': 4027,
#   'exploitation': 3235,
#   'descends': 2367,
#   'nerve': 5988,
#   'incoherence': 4621,
#   'edgar': 2848,
#   'wright': 9932,
#   'watching': 9711,
#   'highly': 4320,
#   'stylized': 8604,
#   'arduous': 538,
#   'altman': 391,
#   'entre': 3048,
#   'su': 8606,
#   'una': 9319,
#   'por': 6673,
#   'title': 9087,
#   'stands': 8385,
#   'audiences': 660,
#   'join': 4942,
#   'delights': 2300,
#   'chase': 1474,
#   'scares': 7680,
#   'fail': 3307,
#   'scale': 7675,
#   'device': 2416,
#   'carey': 1347,
#   'prove': 6909,
#   'pretty': 6799,
#   'decent': 2246,
#   'actress': 231,
#   'reason': 7143,
#   'funniest': 3761,
#   'extraneous': 3272,
#   'conversations': 1934,
#   'physical': 6521,
#   'actions': 224,
#   'romantic': 7524,
#   'comedies': 1730,
#   'sandra': 7637,
#   'bullock': 1223,
#   'ryan': 7596,
#   'reynolds': 7425,
#   'proposal': 6896,
#   'attempts': 646,
#   'false': 3328,
#   'work': 9900,
#   'picture': 6530,
#   'prolonged': 6874,
#   'dragged': 2679,
#   'ennui': 3018,
#   'impact': 4558,
#   'terrifying': 8943,
#   'expectations': 3205,
#   'concoction': 1829,
#   'plucked': 6619,
#   'lower': 5379,
#   'tim': 9057,
#   'burton': 1248,
#   'filmography': 3471,
#   'eccentricity': 2840,
#   'main': 5445,
#   'attraction': 653,
#   'alternates': 388,
#   'marc': 5497,
#   'elaborate': 2889,
#   'episode': 3060,
#   'amusingly': 428,
#   'amoral': 418,
#   'lacks': 5109,
#   'cohesion': 1687,
#   'consistency': 1880,
#   'carnage': 1353,
#   'comedic': 1729,
#   'fruitless': 3734,
#   'franchise': 3674,
#   'launch': 5156,
#   'series': 7816,
#   'doubt': 2657,
#   '46': 103,
#   'running': 7582,
#   'joke': 4945,
#   'familiar': 3333,
#   'predictable': 6758,
#   'vampire': 9514,
#   'suck': 8649,
#   'drive': 2735,
#   'wooden': 9895,
#   'stake': 8369,
#   'throws': 9028,
#   'sharp': 7886,
#   'relief': 7268,
#   'unexplored': 9391,
#   'tragedy': 9169,
#   'artist': 579,
#   'imagine': 4543,
#   'artists': 583,
#   '20th': 79,
#   'century': 1425,
#   'embarrassingly': 2927,
#   'contrived': 1924,
#   'notion': 6068,
#   'pets': 6494,
#   'leading': 5175,
#   'double': 2654,
#   'tapped': 8853,
#   'family': 3336,
#   'kid': 5030,
#   'friendly': 3717,
#   'spy': 8343,
#   'genre': 3852,
#   'latest': 5146,
#   'rob': 7488,
#   'reiner': 7244,
#   'meaning': 5582,
#   'tap': 8851,
#   'universal': 9426,
#   'experiences': 3214,
#   'childhood': 1515,
#   'love': 5369,
#   'bogs': 1034,
#   'squirm': 8354,
#   'inducing': 4657,
#   'manic': 5481,
#   'convincing': 1943,
#   'comedy': 1731,
#   'discernible': 2515,
#   'difference': 2447,
#   'drunk': 2756,
#   'sober': 8166,
#   'formulaic': 3644,
#   'dirge': 2491,
#   'destined': 2391,
#   'forgotten': 3634,
#   'year': 9954,
#   'month': 5802,
#   'hollow': 4375,
#   'man': 5470,
#   'void': 9627,
#   'imagination': 4541,
#   'tone': 9113,
#   'challenged': 1432,
#   'stumble': 8583,
#   'mob': 5765,
#   'trash': 9202,
#   'threads': 9006,
#   'period': 6468,
#   'design': 2377,
#   'easy': 2834,
#   'hate': 4217,
#   'boys': 1114,
#   'excessive': 3156,
#   'humor': 4456,
#   'involving': 4852,
#   'human': 4449,
#   'nauseating': 5961,
#   'jokes': 4947,
#   'women': 9883,
#   'terminator': 8934,
#   'genisys': 3850,
#   'plays': 6595,
#   'worst': 9913,
#   'piece': 6534,
#   'fan': 3339,
#   'fiction': 3435,
#   'written': 9940,
#   'imaginable': 4539,
#   'sort': 8219,
#   'cheap': 1482,
#   'thrown': 9027,
#   'desperate': 2385,
#   'slick': 8083,
#   'engaging': 2997,
#   'fails': 3311,
#   'live': 5306,
#   'silly': 7993,
#   'final': 3475,
#   'steeped': 8431,
#   'consuming': 1896,
#   'aura': 665,
#   'audacious': 657,
#   'indulgence': 4659,
#   'zach': 9976,
#   'braff': 1118,
#   'directorial': 2488,
#   'debut': 2241,
#   'obscure': 6110,
#   'holds': 4369,
#   'lighter': 5254,
#   'granted': 4007,
#   'introduced': 4829,
#   'machines': 5424,
#   'sex': 7847,
#   'occasional': 6126,
#   'angels': 448,
#   'beings': 867,
#   'definition': 2277,
#   'nothingness': 6064,
#   'coherence': 1685,
#   'lost': 5360,
#   'zorro': 9997,
#   'acceptable': 185,
#   'pinch': 6547,
#   'puzzling': 6995,
#   'undeniably': 9346,
#   'compelling': 1774,
#   'broke': 1179,
#   'performances': 6457,
#   'daniels': 2189,
#   'narrative': 5940,
#   'touches': 9143,
#   'thing': 8985,
#   'annoyingly': 467,
#   'indulgent': 4660,
#   'survival': 8743,
#   'epic': 3058,
#   'mediocre': 5594,
#   'eye': 3283,
#   'candy': 1306,
#   'crudely': 2101,
#   'tear': 8881,
#   'jerker': 4919,
#   'earnest': 2819,
#   'heavy': 4269,
#   'handed': 4157,
#   'roberts': 7493,
#   'tragic': 9170,
#   'word': 9899,
#   'plodding': 6610,
#   'hours': 4431,
#   'repetitive': 7317,
#   'compared': 1766,
#   'room': 7534,
#   'listless': 5296,
#   'odyssey': 6143,
#   'lack': 5104,
#   'excitement': 3162,
#   'compounded': 1801,
#   'absence': 161,
#   'bowie': 1106,
#   'gaggle': 3781,
#   'write': 9935,
#   'updated': 9479,
#   'washed': 9696,
#   'dumbed': 2777,
#   'slightest': 8088,
#   'misstep': 5751,
#   'type': 9305,
#   'credibility': 2048,
#   'terrible': 8938,
#   'closure': 1648,
#   'trilogy': 9240,
#   'existed': 3186,
#   'remove': 7299,
#   'mcavoy': 5570,
#   'glass': 3908,
#   'laughable': 5150,
#   '8217': 125,
#   'macabre': 5419,
#   'glee': 3913,
#   '44': 101,
#   'leave': 5188,
#   'wanting': 9678,
#   'digital': 2456,
#   'gore': 3976,
#   'guy': 4116,
#   'rest': 7372,
#   'quot': 7032,
#   'tad': 8825,
#   'suspect': 8749,
#   'slow': 8100,
#   'overly': 6259,
#   'respectful': 7365,
#   'crushingly': 2111,
#   'ghostbusters': 3871,
#   'afterlife': 307,
#   'proof': 6887,
#   'fans': 3346,
#   'careful': 1342,
#   'author': 675,
#   'remembered': 7287,
#   'warmth': 9685,
#   'prose': 6901,
#   'romcom': 7526,
#   'text': 8956,
#   'happy': 4189,
#   'society': 8171,
#   'chopped': 1541,
#   '91': 137,
#   '93': 139,
#   'realized': 7137,
#   'things': 8986,
#   'care': 1337,
#   'force': 3611,
#   'longer': 5339,
#   'cookie': 1948,
#   'cutter': 2152,
#   'proven': 6911,
#   'motel': 5838,
#   'warrant': 9690,
#   'extended': 3263,
#   'stay': 8418,
#   'headache': 4237,
#   'featuring': 3404,
#   'addition': 246,
#   'torture': 9133,
#   'punishment': 6965,
#   'porn': 6674,
#   'expect': 3203,
#   'problematic': 6832,
#   'blockbuster': 988,
#   'essential': 3091,
#   'saving': 7671,
#   'grace': 3989,
#   'profoundly': 6861,
#   'frightening': 3723,
#   'talent': 8834,
#   'capture': 1327,
#   'real': 7127,
#   'disappointment': 2505,
#   '300': 90,
#   'rate': 7094,
#   'esque': 3088,
#   'narration': 5939,
#   'bread': 1133,
#   'angela': 445,
#   'ashes': 589,
#   'minus': 5710,
#   'wit': 9860,
#   'rise': 7473,
#   'meet': 5598,
#   'missed': 5746,
#   'opportunities': 6193,
#   'frustrating': 3737,
#   'choices': 1535,
#   'gimmick': 3893,
#   'wears': 9740,
#   'social': 8168,
#   'commentary': 1746,
#   'superficial': 8702,
#   'matter': 5559,
#   'barrymore': 792,
#   'undeniable': 9345,
#   'charm': 1469,
#   'recommendation': 7169,
#   'struggles': 8562,
#   'complex': 1792,
#   'adults': 277,
#   'simple': 7997,
#   'kids': 5037,
#   'ends': 2982,
#   'annabelle': 462,
#   'dire': 2479,
#   'involved': 4849,
#   'thoughtless': 9001,
#   'wholly': 9805,
#   'uninspired': 9415,
#   'utterly': 9498,
#   'unnecessary': 9437,
#   'tedious': 8898,
#   'tiresome': 9078,
#   'surprising': 8733,
#   'gag': 3780,
#   'reel': 7203,
#   'credits': 2052,
#   'funnier': 3760,
#   '90': 135,
#   'situations': 8028,
#   'jonathan': 4954,
#   'demme': 2316,
#   'ear': 2812,
#   'feeling': 3411,
#   'behave': 862,
#   'penn': 6445,
#   'malick': 5464,
#   'transcendence': 9182,
#   'seeks': 7766,
#   'flops': 3565,
#   'purports': 6977,
#   'literally': 5302,
#   'existence': 3187,
#   'testament': 8950,
#   'faceless': 3293,
#   'lazy': 5171,
#   'pathetic': 6396,
#   'unearned': 9379,
#   'veneer': 9537,
#   'intelligence': 4779,
#   'aptly': 529,
#   'describes': 2369,
#   'ludicrous': 5390,
#   'russell': 7591,
#   'apos': 501,
#   'amsterdam': 423,
#   'unexpected': 9389,
#   'shocking': 7920,
#   'godzilla': 3950,
#   'interminable': 4801,
#   'missing': 5749,
#   'melancholy': 5607,
#   'smith': 8126,
#   'angelina': 447,
#   'jolie': 4949,
#   'michelle': 5670,
#   'pfeiffer': 6496,
#   'appeal': 505,
#   'maleficent': 5462,
#   'mistress': 5756,
#   'evil': 3128,
#   'solidly': 8189,
#   'terrain': 8936,
#   'asked': 594,
#   'weary': 9741,
#   'finds': 3482,
#   'exhausting': 3179,
#   'deliver': 2301,
#   'trite': 9249,
#   'boiled': 1038,
#   '101': 4,
#   '87': 132,
#   'crap': 2021,
#   'lifeless': 5248,
#   'iraq': 4854,
#   'war': 9679,
#   'mad': 5427,
#   'lives': 5309,
#   'friends': 3718,
#   'lived': 5307,
#   'monotonous': 5795,
#   'level': 5231,
#   'concepts': 1818,
#   'challenging': 1434,
#   'drinking': 2729,
#   'smoking': 8128,
#   'dope': 2647,
#   'holding': 4368,
#   'arguments': 548,
#   'meaningless': 5584,
#   'fights': 3449,
#   'tossed': 9137,
#   'lark': 5136,
#   'creator': 2044,
#   'involve': 4848,
#   'decided': 2250,
#   'grind': 4047,
#   'lying': 5413,
#   'hell': 4282,
#   'minute': 5711,
#   'harder': 4195,
#   'misfire': 5735,
#   'respect': 7363,
#   'tonally': 9112,
#   'satisfying': 7662,
#   'blend': 973,
#   'disparate': 2556,
#   'moods': 5810,
#   'pose': 6689,
#   'portrait': 6681,
#   'leaving': 5190,
#   'executed': 3172,
#   'horror': 4420,
#   'sexual': 7851,
#   'danger': 2184,
#   'viewers': 9578,
#   'emotional': 2944,
#   'relationship': 7252,
#   'couple': 1986,
#   'saga': 7615,
#   'everyday': 3124,
#   'angst': 453,
#   'genuine': 3857,
#   'woody': 9898,
#   'allen': 374,
#   'pale': 6318,
#   'imitation': 4548,
#   'flat': 3533,
#   'disjointed': 2547,
#   'moving': 5867,
#   'parts': 6371,
#   'idiot': 4512,
#   'baroque': 784,
#   'tonal': 9111,
#   'monotony': 5796,
#   'treat': 9217,
#   'fashioned': 3369,
#   'comeback': 1726,
#   'emotionally': 2945,
#   'convincingly': 1944,
#   'darn': 2203,
#   'fires': 3494,
#   'existing': 3190,
#   'virginia': 9599,
#   'west': 9779,
#   'drawn': 2703,
#   'stiff': 8458,
#   'affair': 293,
#   'ancient': 438,
#   'army': 554,
#   'foot': 3603,
#   'nazi': 5965,
#   'sausage': 7666,
#   'called': 1283,
#   'attack': 641,
#   'canadian': 1303,
#   'town': 9152,
#   'girls': 3900,
#   'save': 7668,
#   'deserves': 2375,
#   'equal': 3064,
#   'exploit': 3234,
#   'hold': 4367,
#   'tense': 8926,
#   'enjoyment': 3013,
#   'fresh': 3708,
#   'blood': 992,
#   'evolution': 3134,
#   'mouse': 5855,
#   'glosses': 3936,
#   'disney': 2553,
#   'toy': 9154,
#   'growing': 4075,
#   'emptiness': 2961,
#   'mickey': 5671,
#   'endearing': 2973,
#   'iconography': 4496,
#   'blank': 960,
#   'senses': 7794,
#   '8230': 128,
#   'troubling': 9263,
#   'reminds': 7294,
#   'channel': 1445,
#   'pointless': 6634,
#   'remake': 7281,
#   'overrated': 6261,
#   'john': 4939,
#   'carpenter': 1357,
#   'picks': 6529,
#   'pandemic': 6330,
#   'focus': 3583,
#   'check': 1488,
#   'riffs': 7454,
#   'creative': 2041,
#   'speed': 8273,
#   'achieve': 207,
#   'greatness': 4026,
#   'games': 3796,
#   'start': 8399,
#   'stalker': 8372,
#   'cheerful': 1496,
#   'teen': 8901,
#   'attitude': 649,
#   'sci': 7704,
#   'soft': 8178,
#   'sells': 7780,
#   'ethnic': 3108,
#   'climactic': 1627,
#   'massacre': 5542,
#   'broken': 1180,
#   'windows': 9833,
#   'guys': 4117,
#   'idiots': 4514,
#   'standards': 8381,
#   'sick': 7969,
#   ...})

# %%
len(pos_vocab), len(neg_vocab)
# Out:
# (10000, 10000)

# %%
len(pos_vocab.keys() & neg_vocab.keys())
# Out:
# 7695

# %%
len(pos_vocab.keys() - neg_vocab.keys())
# Out:
# 2305

# %%
len(neg_vocab.keys() - pos_vocab.keys())
# Out:
# 2305

# %%
pos_vocab

# %%
neg_vocab

# %% [markdown]
# ## Function for Weighted Class TF-IDF
# [Link](https://www.deepwizai.com/projects/how-to-correctly-use-tf-idf-with-imbalanced-data)

# %%
def get_tfidf_vocab(traindf, stop_words='english', max_features=10000):
    pos_text = traindf[traindf["sentiment"] == "POSITIVE"]["reviewText"]
    neg_text = traindf[traindf["sentiment"] == "NEGATIVE"]["reviewText"]

    n_pos_features = round((len(pos_text) / len(text)) * max_features)
    n_neg_features = round((len(neg_text) / len(text)) * max_features)

    tvec_pos = TfidfVectorizer(stop_words=stop_words, max_features=n_pos_features)
    tvec_pos.fit(pos_text)
    pos_vocab = tvec_pos.vocabulary_

    tvec_neg = TfidfVectorizer(stop_words=pos_vocab, max_features=n_neg_features)
    tvec_neg.fit(neg_text)
    neg_vocab = tvec_neg.vocabulary_

    vocab_combined = pos_vocab | neg_vocab
    return vocab_combined

# %%
v = get_tfidf_vocab(traindf)
# Out:
# 10000

# %%
v.keys()
# Out:
# dict_keys(['henry', 'movie', '2009', 'fifth', 'stop', 'motion', 'masterpiece', 'creed', 'ii', 'does', 'slightly', 'superior', 'rocky', 'sequel', 'wins', 'points', 'just', 'don', 'expect', 'knockout', 'know', 'thinking', 'bradley', 'cooper', 'lucy', 'taps', 'brain', 'new', 'thrills', 'skills', 'passing', 'hour', 'director', 'tells', 'story', 'urgency', 'sharp', 'visual', 'compositions', 'cinematography', 'gangster', 'life', 'rich', 'piece', 'storytelling', 'feels', 'like', 'heartfelt', 'lovely', 'performance', 'scott', 'bit', 'long', 'cartoon', 'feature', 'probably', 'sign', 'makers', 'fell', 'love', 'best', 'pixar', 'features', 'anchored', 'charming', 'greta', 'gerwig', 'light', 'breezy', 'walk', 'central', 'park', 'refreshing', 'largely', 'hanks', 'solo', 'beloved', 'icon', 'fine', 'form', 'family', 'films', 'delight', 'children', 'adults', 'alike', 'kids', 'entertaining', 'amazing', 'documentary', 'ingeniously', 'constructed', 'hilarious', 'thrill', 'ride', 'underdog', 'year', 'little', 'conflict', 'insightful', 'film', '13', 'reliably', 'ultimately', 'traditional', 'classic', 'brown', 'bag', 'bottle', 'bitter', 'cheap', 'match', 'characters', 'onscreen', 'relationship', 'quirky', 'script', 'packed', 'good', 'lines', 'wall', 'moments', 'stories', 'surprisingly', 'moving', 'places', 'model', 'dignified', 'delicate', 'restraint', 'times', 'weight', 'sumptuous', 'picture', 'fires', 'highly', 'recommend', 'check', 'big', 'screen', 'oh', 'fun', 'old', 'fashioned', 'hearted', 'action', 'sense', 'humor', 'despite', 'downbeat', 'theme', 'single', 'man', 'optimistic', 'human', 'gradually', 'make', 'peace', 'seemingly', 'pain', 'tragedy', 'intelligent', 'style', 'turns', 'dialogue', 'heavy', 'potentially', 'enthralling', 'experience', 'bad', 'quite', 'slow', 'spots', 'awful', 'lot', 'exposition', 'easily', 'image', 'masculine', 'longing', 'freedom', 'mines', 'far', 'deeper', 'concerns', 'mank', 'isn', 'incredibly', 'tedious', 'question', 'wrote', 'citizen', 'kane', 'hook', 'true', 'immense', 'relief', 'specific', 'failed', 'california', 'sterling', 'supporting', 'cast', 'parts', 'provides', 'intelligence', 'sentimentality', 'ease', 'acted', 'sharply', 'written', 'honor', 'alien', 'movies', 'hold', 'near', 'dear', 'workplace', 'need', 'hard', 'wouldn', 'absorbed', 'fascinating', 'formidable', 'driver', 'hate', 'strong', 'holds', 'audience', 'moment', 'star', 'making', 'equally', 'drawn', 'bursts', 'black', 'humour', 'emotional', 'depth', 'fan', 'home', 'dark', 'wit', 'intensity', 'seriously', 'work', 'eye', 'focuses', 'world', 'events', 'makes', 'feel', 'documentaries', 'tricky', 'business', 'necessary', 'staged', 'scenes', 'visceral', 'melancholy', 'hand', 'dance', 'stiff', 'drink', 'pleasures', 'combination', 'proves', 'intoxicating', 'fancy', 'pants', 'boys', 'whip', 'outcome', 'campaign', 'progress', 'remains', 'snapshot', 'modern', 'politics', 'hopeful', 'account', 'idealism', 'brothers', 'coen', 'deliver', 'taut', 'vastly', 'time', 'leave', 'blows', 'fresh', 'wind', 'fairly', 'corny', 'melodramatic', 'territory', 'keeping', 'faith', 'operatic', 'emotions', 'genre', 'mild', 'filled', 'run', 'frightening', 'aim', 'list', 'nancy', 'wise', 'type', 'acting', 'palatable', 'right', 'worth', 'seeing', 'warm', 'romantic', 'comedy', 'lopez', 'reputation', 'certainly', 'll', 'entertained', 'parents', 'way', 'worthwhile', 'showcase', 'pacino', 'thoughtful', 'portrayal', 'stage', 'actor', 'contemplative', 'darkly', 'comical', 'stylish', 'sets', 'franchise', 'deftly', 'view', 'sure', 'fans', 'surely', 'fairy', 'tale', 'dreams', 'come', 'beast', 'strikingly', 'shot', 'cleverly', 'scripted', 'unsettling', 'study', 'troubled', 'psychology', 'pressure', 'claustrophobia', 'small', 'island', 'recommended', 'animated', 'oscar', 'basically', 'disney', 'dreamworks', 'deserving', 'champion', 'inside', 'matched', 'splendor', 'spirit', 'miyazaki', 'humanist', 'reach', 'friend', 'suggest', 'unique', 'driven', 'remarkable', 'performances', 'remember', 'soul ...

# %% [markdown]
# ## n_gram

# %%
tvec_ng = TfidfVectorizer(ngram_range=(1,2))
tvec_ng.fit(text)
text_transformed_ng = tvec_ng.transform(text)
text_transformed_ng
# Out:
# <162758x1096578 sparse matrix of type '<class 'numpy.float64'>'
# 	with 6254759 stored elements in Compressed Sparse Row format>

# %%
tvec_ng.vocabulary_
# Out:
# {'henry': 437471,
#  'selick': 827930,
#  'first': 358192,
#  'movie': 623832,
#  'since': 848567,
#  '2009': 3111,
#  'coraline': 219433,
#  'his': 444471,
#  'fifth': 348234,
#  'stop': 889616,
#  'motion': 622509,
#  'masterpiece': 590100,
#  'henry selick': 437520,
#  'selick first': 827936,
#  'first movie': 358598,
#  'movie since': 625894,
#  'since 2009': 848602,
#  '2009 coraline': 3120,
#  'coraline his': 219439,
#  'his fifth': 445547,
#  'fifth stop': 348269,
#  'stop motion': 889727,
#  'motion masterpiece': 622561,
#  'with': 1070138,
#  'cast': 171369,
#  'that': 930838,
#  'reads': 773659,
#  'like': 556788,
#  'the': 937221,
#  'vogue': 1038539,
#  'oscar': 694376,
#  'party': 712015,
#  'guest': 417259,
#  'list': 562510,
#  'valentine': 1027738,
#  'day': 239927,
#  'should': 841765,
#  'have': 428815,
#  'been': 114863,
#  'can': 164745,
#  'miss': 609690,
#  'cinema': 188133,
#  'instead': 489343,
#  'of': 661701,
#  'standard': 881359,
#  'hollywood': 450664,
#  'schmaltz': 816995,
#  'with cast': 1070927,
#  'cast that': 171934,
#  'that reads': 935306,
#  'reads like': 773670,
#  'like the': 559862,
#  'the vogue': 952659,
#  'vogue oscar': 1038547,
#  'oscar party': 694490,
#  'party guest': 712067,
#  'guest list': 417284,
#  'list valentine': 562591,
#  'valentine day': 1027744,
#  'day should': 240276,
#  'should have': 841919,
#  'have been': 428925,
#  'been can': 115023,
#  'can miss': 165316,
#  'miss cinema': 609727,
#  'cinema instead': 188321,
#  'instead of': 489491,
#  'of standard': 672977,
#  'standard hollywood': 881444,
#  'hollywood schmaltz': 451214,
#  'creed': 227858,
#  'ii': 466619,
#  'does': 272452,
#  'not': 652337,
#  'give': 399915,
#  'us': 1024602,
#  'anything': 72004,
#  'but': 153190,
#  'another': 68250,
#  'slightly': 854836,
#  'superior': 907688,
#  'rocky': 800264,
#  'sequel': 830290,
#  'it': 508930,
#  'wins': 1068819,
#  'on': 680254,
#  'points': 735436,
#  'just': 528559,
#  'don': 275048,
#  'expect': 325011,
#  'knockout': 537273,
#  'creed ii': 227879,
#  'ii does': 466644,
#  'does not': 272827,
#  'not give': 653153,
#  'give us': 400238,
#  'us anything': 1024647,
#  'anything but': 72045,
#  'but another': 153359,
#  'another slightly': 69092,
#  'slightly superior': 855099,
#  'superior rocky': 907781,
#  'rocky sequel': 800313,
#  'sequel it': 830432,
#  'it wins': 514228,
#  'wins on': 1068840,
#  'on points': 682406,
#  'points just': 735496,
#  'just don': 528933,
#  'don expect': 275177,
#  'expect knockout': 325100,
#  'know': 537386,
#  'what': 1053901,
#  'you': 1090999,
#  're': 772185,
#  'thinking': 962359,
#  'this': 962811,
#  'is': 500480,
#  'no': 647761,
#  'limitless': 561136,
#  'bradley': 141711,
#  'cooper': 218832,
#  'as': 83383,
#  'cells': 174359,
#  'multiply': 630560,
#  'and': 48779,
#  'lucy': 573468,
#  'taps': 919603,
#  'into': 494239,
#  'more': 616312,
#  'her': 437594,
#  'brain': 141811,
#  'new': 643704,
#  'thrills': 971809,
#  'skills': 852318,
#  'each': 286852,
#  'passing': 712568,
#  'hour': 456087,
#  'know what': 537618,
#  'what you': 1055332,
#  'you re': 1091888,
#  're thinking': 772932,
#  'thinking but': 962375,
#  'but this': 156627,
#  'this is': 964831,
#  'is no': 504511,
#  'no limitless': 648502,
#  'limitless bradley': 561139,
#  'bradley cooper': 141713,
#  'cooper as': 218842,
#  'as the': 88693,
#  'the cells': 939533,
#  'cells multiply': 174368,
#  'multiply and': 630561,
#  'and lucy': 57573,
#  'lucy taps': 573504,
#  'taps into': 919607,
#  'into more': 495411,
#  'more and': 616404,
#  'and more': 58368,
#  'more of': 617945,
#  'of her': 667251,
#  'her brain': 437785,
#  'brain it': 141858,
#  'it new': 511979,
#  'new thrills': 644563,
#  'thrills new': 971881,
#  'new skills': 644477,
#  'skills with': 852365,
#  'with each': 1071746,
#  'each passing': 286996,
#  'passing hour': 712595,
#  'director': 262093,
#  'fernando': 345232,
#  'meirelles': 597657,
#  'tells': 924075,
#  'story': 890405,
#  'urgency': 1024418,
#  'sharp': 836930,
#  'visual': 1037042,
#  'compositions': 208224,
#  'washed': 1044848,
#  'out': 697151,
#  'cinematography': 189555,
#  'ooze': 687937,
#  'gangster': 390072,
#  'life': 554644,
#  'director fernando': 262610,
#  'fernando meirelles': 345237,
#  'meirelles tells': 597671,
#  'tells the': 924167,
#  'the story': 950798,
#  'story with': 891709,
#  'with urgency': 1075879,
#  'urgency and': 1024422,
#  'and his': 55686,
#  'his sharp': 447008,
#  'sharp visual': 837175,
#  'visual compositions': 1037121,
#  'compositions and': 208227,
#  'and washed': 64881,
#  'washed out': 1044853,
#  'out cinematography': 697312,
#  'cinematography ooze': 189645,
#  'ooze gangster': 687940,
#  'gangster life': 390110,
#  'kajillionaire': 530795,
#  'rich': 794747,
#  'piece': 726278,
#  'storytelling': 891960,
#  'feels': 343187,
#  'kajillion': 530793,
#  'bucks': 149657,
#  'kajillionaire is': 530797,
#  'is rich': 505477,
#  'rich piece': 794965,
#  'piece of': 726392,
#  'of storytelling': 673102,
#  'storytelling and': 891974,
#  'and it': 56585,
#  'it feels': 510620,
#  'feels like': 343508,
#  'like kajillion': 558424,
#  'kajillion bucks': 530794,
#  'heartfelt': 434483,
#  'lovely': 571858,
#  'performance': 718889,
#  'from': 379757,
#  'scott': 818942,
#  'chambers': 177060,
#  'heartfelt story': 434643,
#  'with lovely': 1073314,
#  'lovely performance': 571995,
#  'performance from': 719035,
#  'from scott': 382350,
#  'scott chambers': 818971,
#  'if': 464981,
#  'bit': 127880,
#  'long': 567335,
#  'for': 365901,
#  'cartoon': 170536,
#  'feature': 341170,
#  'probably': 750006,
#  'sign': 845331,
#  'its': 514541,
#  'makers': 580371,
#  'fell': 344118,
#  'in': 472367,
#  'love': 571008,
#  'ratatouille': 770314,
#  'eighth': 293838,
#  'one': 684044,
#  'best': 121728,
#  'pixar': 728213,
#  'features': 341531,
#  'if bit': 465092,
#  'bit long': 128093,
#  'long for': 567532,
#  'for cartoon': 366498,
#  'cartoon feature': 170579,
#  'feature probably': 341390,
#  'probably sign': 750262,
#  'sign that': 845348,
#  'that its': 933831,
#  'its makers': 517151,
#  'makers fell': 580387,
#  'fell in': 344131,
#  'in love': 475781,
#  'love with': 571624,
#  'with it': 1072939,
#  'it ratatouille': 512549,
#  'ratatouille is': 770320,
#  'is the': 506561,
#  'the eighth': 941778,
#  'eighth and': 293839,
#  'and one': 58985,
#  'one of': 685102,
#  'of the': 673656,
#  'the best': 938673,
#  'best pixar': 122363,
#  'pixar features': 728273,
#  'anchored': 48633,
#  'by': 157664,
#  'charming': 181114,
#  'greta': 413531,
#  'gerwig': 396029,
#  'light': 555932,
#  'breezy': 144024,
#  'walk': 1040571,
#  'central': 174773,
#  'park': 709835,
#  'refreshing': 780926,
#  'anchored by': 48636,
#  'by charming': 158248,
#  'charming performance': 181345,
#  'from greta': 381046,
#  'greta gerwig': 413536,
#  'gerwig it': 396052,
#  'it as': 509198,
#  'as light': 86409,
#  'light and': 555943,
#  'and breezy': 50519,
#  'breezy as': 144034,
#  'as walk': 89166,
#  'walk in': 1040601,
#  'in central': 473374,
#  'central park': 174858,
#  'park and': 709845,
#  'and just': 56807,
#  'just as': 528629,
#  'as refreshing': 87686,
#  'largely': 542896,
#  'hanks': 422995,
#  'solo': 864800,
#  'show': 842387,
#  'beloved': 120047,
#  'icon': 463427,
#  'fine': 356769,
#  'unfussy': 1015713,
#  'form': 372147,
#  'it largely': 511507,
#  'largely hanks': 542977,
#  'hanks solo': 423079,
#  'solo show': 864842,
#  'show and': 842406,
#  'and the': 63522,
#  'the beloved': 938641,
#  'beloved icon': 120106,
#  'icon is': 463446,
#  'is in': 503448,
#  'in fine': 474608,
#  'fine unfussy': 357104,
#  'unfussy form': 1015720,
#  'those': 967784,
#  'family': 334840,
#  'films': 354297,
#  'will': 1066234,
#  'delight': 247887,
#  'both': 138481,
#  'children': 184704,
#  'adults': 26277,
#  'alike': 34314,
#  'however': 458288,
#  'kids': 534358,
#  'find': 355915,
#  'to': 978529,
#  'be': 107634,
#  'entertaining': 307639,
#  'enough': 306014,
#  'it is': 511394,
#  'is not': 504547,
#  'not one': 653617,
#  'of those': 673712,
#  'those family': 968052,
#  'family films': 335047,
#  'films that': 354811,
#  'that will': 937031,
#  'will delight': 1066414,
#  'delight both': 247901,
#  'both children': 138683,
#  'children and': 184721,
#  'and adults': 49089,
#  'adults alike': 26281,
#  'alike however': 34343,
#  'however the': 458514,
#  'the kids': 945019,
#  'kids will': 534653,
#  'will find': 1066522,
#  'find it': 356107,
#  'it to': 513746,
#  'to be': 979026,
#  'be entertaining': 108629,
#  'entertaining enough': 307810,
#  'amazing': 42169,
#  'johnathan': 524623,
#  'documentary': 271723,
#  'ingeniously': 485420,
#  'constructed': 214197,
#  'hilarious': 442735,
#  'thrill': 970680,
#  'ride': 795586,
#  'underdog': 1011608,
#  'year': 1088358,
#  'the amazing': 937858,
#  'amazing johnathan': 42283,
#  'johnathan documentary': 524624,
#  'documentary is': 271990,
#  'is ingeniously': 503521,
#  'ingeniously constructed': 485423,
#  'constructed hilarious': 214237,
#  'hilarious thrill': 443045,
#  'thrill ride': 970721,
#  'ride and': 795601,
#  'the underdog': 952128,
#  'underdog story': 1011653,
#  'story of': 891208,
#  'the year': 953209,
#  'little': 563319,
#  'conflict': 210797,
#  'less': 551653,
#  'beatification': 111780,
#  'would': 1084581,
#  'made': 576396,
#  'insightful': 487769,
#  'film': 349261,
#  'little more': 564011,
#  'more conflict': 616749,
#  'conflict and': 210802,
#  'and less': 57277,
#  'less beatification': 551716,
#  'beatification would': 111781,
#  'would have': 1084781,
#  'have made': 429605,
#  'made for': 576631,
#  'for more': 368507,
#  'more insightful': 617561,
#  'insightful film': 487812,
#  '13': 615,
#  'assassins': 90489,
#  'reliably': 784167,
#  'ultimately': 1007237,
#  'too': 987917,
#  'traditional': 993135,
#  'classic': 191522,
#  '13 assassins': 623,
#  'assassins is': 90494,
#  'is reliably': 505386,
#  'reliably entertaining': 784178,
#  'entertaining but': 307718,
#  'but ultimately': 156761,
#  'ultimately it': 1007588,
#  'it too': 513766,
#  'too traditional': 988928,
#  'traditional to': 993284,
#  'be classic': 108135,
#  'brown': 148520,
#  'bag': 102048,
#  'sneak': 859344,
#  'bottle': 139956,
#  'something': 867478,
#  'bitter': 128633,
#  'cheap': 182230,
#  'match': 590432,
#  'characters': 179343,
#  'get': 396155,
#  'smashed': 857786,
#  'along': 38215,
#  'onscreen': 687630,
#  'relationship': 782925,
#  'the brown': 939137,
#  'brown bag': 148531,
#  'bag movie': 102073,
#  'movie of': 625385,
#  'year sneak': 1088744,
#  'sneak in': 859348,
#  'in bottle': 473146,
#  'bottle of': 139972,
#  'of something': 672739,
#  'something bitter': 867539,
#  'bitter and': 128639,
#  'and cheap': 51083,
#  'cheap to': 182390,
#  'to match': 982346,
#  'match the': 590494,
#  'the central': 939544,
#  'central characters': 174787,
#  'characters and': 179380,
#  'and get': 54898,
#  'get smashed': 396652,
#  'smashed along': 857788,
#  'along with': 38379,
#  'with the': 1075535,
#  'the onscreen': 947057,
#  'onscreen relationship': 687711,
#  'quirky': 764664,
#  'script': 821156,
#  'packed': 705684,
#  'good': 405398,
#  'lines': 561780,
#  'off': 675144,
#  'wall': 1040858,
#  'moments': 613086,
#  'stories': 890073,
#  'are': 76726,
#  'surprisingly': 910115,
#  'moving': 627206,
#  'places': 728827,
#  'the quirky': 948505,
#  'quirky script': 764814,
#  'script is': 821431,
#  'is packed': 504714,
#  'packed with': 705821,
#  'with good': 1072380,
#  'good lines': 405971,
#  'lines and': 561785,
#  'and off': 58928,
#  'off the': 675620,
#  'the wall': 952725,
#  'wall moments': 1040938,
#  'moments and': 613106,
#  'the stories': 950794,
#  'stories are': 890086,
#  'are surprisingly': 79109,
#  'surprisingly moving': 910329,
#  'moving in': 627385,
#  'in places': 476684,
#  'small': 856646,
#  'pleasures': 732312,
#  'aside': 89698,
#  'doesn': 273125,
#  'offer': 675992,
#  'particularly': 711217,
#  'memorable': 598813,
#  'or': 689479,
#  'inventive': 497740,
#  'small pleasures': 856895,
#  'pleasures aside': 732320,
#  'aside the': 89770,
#  'the movie': 946444,
#  'movie doesn': 624466,
#  'doesn offer': 273484,
#  'offer anything': 676003,
#  'anything particularly': 72169,
#  'particularly memorable': 711418,
#  'memorable or': 598957,
#  'or inventive': 690868,
#  'vanderbilt': 1028486,
#  'tries': 997914,
#  'tv': 1003556,
#  'news': 644959,
#  'reporting': 788044,
#  'process': 750903,
#  'inside': 487426,
#  'fishbowl': 359011,
#  'he': 431163,
#  'so': 860015,
#  'much': 628391,
#  'through': 972154,
#  'world': 1082454,
#  'talk': 918484,
#  'vanderbilt tries': 1028490,
#  'tries to': 997958,
#  'to show': 984163,
#  'show us': 842691,
#  'us the': 1025340,
#  'the tv': 951977,
#  'tv news': 1003683,
#  'news reporting': 645035,
#  'reporting process': 788055,
#  'process from': 750941,
#  'from inside': 381262,
#  'inside the': 487574,
#  'the fishbowl': 942581,
#  'fishbowl but': 359012,
#  'but he': 154726,
#  'he doesn': 431500,
#  'doesn so': 273644,
#  'so much': 861231,
#  'much walk': 629591,
#  'walk us': 1040643,
#  'us through': 1025358,
#  'through the': 972963,
#  'the world': 953117,
#  'world as': 1082506,
#  'as talk': 88612,
#  'talk and': 918488,
#  'and talk': 63301,
#  'talk us': 918552,
#  'through it': 972575,
#  'model': 611534,
#  'dignified': 260224,
#  'delicate': 247504,
#  'restraint': 791144,
#  'there': 958147,
#  'times': 976381,
#  'when': 1055776,
#  'seems': 826127,
#  'suffocate': 904810,
#  'under': 1011079,
#  'weight': 1050561,
#  'own': 703221,
#  'sumptuous': 906182,
#  'respectability': 790394,
#  'is model': 504324,
#  'model of': 611558,
#  'of dignified': 664998,
#  'dignified delicate': 260229,
#  'delicate restraint': 247601,
#  'restraint but': 791151,
#  'but there': 156611,
#  'there are': 958197,
#  'are times': 79219,
#  'times when': 976875,
#  'when it': 1056258,
#  'it seems': 512941,
#  'seems to': 826535,
#  'to suffocate': 984660,
#  'suffocate under': 904812,
#  'under the': 1011310,
#  'the weight': 952849,
#  'weight of': 1050604,
#  'of its': 668025,
#  'its own': 517615,
#  'own sumptuous': 704367,
#  'sumptuous respectability': 906248,
#  'picture': 725593,
#  'fires': 358007,
#  'all': 34520,
#  'pistons': 727761,
#  'the picture': 947694,
#  'picture fires': 725762,
#  'fires on': 358021,
#  'on all': 680374,
#  'all pistons': 35570,
#  'highly': 442373,
#  'recommend': 778295,
#  'check': 182544,
#  'big': 125618,
#  'screen': 819719,
#  'highly recommend': 442525,
#  'recommend you': 778376,
#  'you check': 1091184,
#  'check this': 182580,
#  'this out': 965460,
#  'out on': 697790,
#  'on the': 683154,
#  'the big': 938697,
#  'big screen': 126125,
#  'oh': 678320,
#  'fun': 385094,
#  'an': 45645,
#  'old': 678725,
#  'fashioned': 338769,
#  'hearted': 434247,
#  'action': 19992,
#  'sense': 828874,
#  'humor': 460713,
#  'oh it': 678354,
#  'it fun': 510831,
#  'fun an': 385130,
#  'an old': 47606,
#  'old fashioned': 678991,
#  'fashioned good': 338875,
#  'good hearted': 405853,
#  'hearted action': 434250,
#  'action film': 20216,
#  'film with': 352736,
#  'with sense': 1074827,
#  'sense of': 828973,
#  'of humor': 667502,
#  'rumor': 805553,
#  'has': 425925,
#  'seem': 825472,
#  'realize': 775325,
#  'who': 1061614,
#  'most': 619800,
#  'interesting': 492201,
#  'character': 178399,
#  'spend': 875233,
#  'some': 865165,
#  'time': 975069,
#  'coo': 218269,
#  'ca': 161763,
#  'choo': 186215,
#  'mrs': 628166,
#  'robinson': 799510,
#  'here': 439423,
#  'rumor has': 805555,
#  'has it': 426770,
#  'it doesn': 510230,
#  'doesn seem': 273615,
#  'seem to': 825789,
#  'to realize': 983499,
#  'realize who': 775361,
#  'who its': 1062285,
#  'its most': 517340,
#  'most interesting': 620680,
#  'interesting character': 492270,
#  'character is': 178743,
#  'is and': 500712,
#  'and spend': 62515,
#  'spend some': 875297,
#  'some time': 866717,
#  'time with': 975988,
#  'with her': 1072606,
#  'her coo': 437922,
#  'coo coo': 218272,
#  'coo ca': 218271,
#  'ca choo': 161764,
#  'choo mrs': 186218,
#  'mrs robinson': 628197,
#  'robinson here': 799528,
#  'here to': 439915,
#  'to you': 985614,
#  'handsome': 422576,
#  'dud': 283873,
#  'handsome dud': 422601,
#  'despite': 254322,
#  'downbeat': 277710,
#  'theme': 956766,
#  'single': 849610,
#  'man': 582797,
#  'optimistic': 689299,
#  'about': 12239,
#  'human': 459457,
#  'capability': 166852,
#  'gradually': 409431,
#  'make': 579472,
#  'peace': 715252,
#  'seemingly': 825948,
#  'insurmountable': 490164,
#  'pain': 706302,
#  'tragedy': 993448,
#  'despite its': 254511,
#  'its downbeat': 515775,
#  'downbeat theme': 277750,
#  'theme single': 956843,
#  'single man': 849741,
#  'man is': 583180,
#  'is ultimately': 506840,
#  'ultimately optimistic': 1007689,
#  'optimistic about': 689300,
#  'about the': 14644,
#  'the human': 944079,
#  'human capability': 459523,
#  'capability to': 166854,
#  'to gradually': 981262,
#  'gradually make': 409488,
#  'make peace': 580008,
#  'peace with': 715299,
#  'with seemingly': 1074815,
#  'seemingly insurmountable': 826040,
#  'insurmountable pain': 490171,
#  'pain and': 706305,
#  'and tragedy': 63849,
#  'suggests': 905194,
#  'jennifer': 522621,
#  'connelly': 212113,
#  'snorri': 859684,
#  'cam': 163527,
#  'puke': 758553,
#  'scene': 815806,
#  'requiem': 788676,
#  'dream': 280902,
#  'stretched': 894420,
#  '80': 8704,
#  'minutes': 607995,
#  'the film': 942517,
#  'film suggests': 352258,
#  'suggests jennifer': 905250,
#  'jennifer connelly': 522627,
#  'connelly snorri': 212122,
#  'snorri cam': 859685,
#  'cam puke': 163543,
#  'puke scene': 758561,
#  'scene from': 815886,
#  'from requiem': 382217,
#  'requiem for': 788677,
#  'for dream': 367047,
#  'dream stretched': 281040,
#  'stretched out': 894430,
#  'out to': 698111,
#  'to 80': 978603,
#  '80 minutes': 8733,
#  'lot': 570268,
#  'men': 599310,
#  'diluted': 260506,
#  'adaptation': 23404,
#  'feels lot': 343518,
#  'lot like': 570344,
#  'like men': 558702,
#  'men the': 599603,
#  'the diluted': 941184,
#  'diluted tv': 260521,
#  'tv adaptation': 1003567,
#  'hersh': 441026,
#  'intelligent': 490665,
#  'style': 898753,
#  'turns': 1003096,
#  'dialogue': 257485,
#  'heavy': 435341,
#  'potentially': 741457,
#  'rote': 803487,
#  'enthralling': 308708,
#  'experience': 325771,
#  'hersh intelligent': 441028,
#  'intelligent style': 490884,
#  'style turns': 899215,
#  'turns dialogue': 1003166,
#  'dialogue heavy': 257617,
#  'heavy potentially': 435477,
#  'potentially rote': 741547,
#  'rote film': 803507,
#  'film into': 350863,
#  'into an': 494310,
#  'an enthralling': 46667,
#  'enthralling and': 308713,
#  'and moving': 58441,
#  'moving experience': 627332,
#  'bad': 101184,
#  'never': 642462,
#  'quite': 764871,
#  'sweeps': 912913,
#  'up': 1021900,
#  'slow': 855776,
#  'spots': 878465,
#  'awful': 99295,
#  'exposition': 327937,
#  'too bad': 987983,
#  'bad the': 101657,
#  'movie never': 625351,
#  'never quite': 643175,
#  'quite sweeps': 765577,
#  'sweeps us': 912924,
#  'us up': 1025395,
#  'up it': 1022484,
#  'it slow': 513144,
#  'slow in': 855865,
#  'in spots': 477755,
#  'spots and': 878467,
#  'and there': 63548,
#  'there an': 958183,
#  'an awful': 46387,
#  'awful lot': 99372,
#  'lot of': 570357,
#  'of exposition': 665892,
#  'could': 221296,
#  'easily': 288497,
#  'become': 113511,
#  'figurative': 348667,
#  'image': 467435,
#  'masculine': 589125,
#  'longing': 568096,
#  'freedom': 377106,
#  'mines': 606966,
#  'far': 337134,
#  'deeper': 245048,
#  'concerns': 209454,
#  'what could': 1054181,
#  'could easily': 221431,
#  'easily have': 288614,
#  'have become': 428923,
#  'become its': 113729,
#  'own figurative': 703678,
#  'figurative image': 348674,
#  'image of': 467480,
#  'the masculine': 945842,
#  'masculine longing': 589142,
#  'longing for': 568111,
#  'for freedom': 367442,
#  'freedom mines': 377144,
#  'mines far': 606972,
#  'far deeper': 337183,
#  'deeper concerns': 245066,
#  'mank': 584619,
#  'isn': 507759,
#  'incredibly': 481180,
#  'tedious': 922457,
#  'question': 763172,
#  'wrote': 1087248,
#  'citizen': 190136,
#  'kane': 530954,
#  'hook': 453140,
#  'true': 999802,
#  'interest': 492035,
#  'my': 633296,
#  'immense': 469010,
#  'relief': 784231,
#  'specific': 873944,
#  'upton': 1024212,
#  'sinclair': 849282,
#  'failed': 332456,
#  '1934': 1374,
#  'california': 162677,
#  'gubernatorial': 417063,
#  'bid': 125485,
#  'mank isn': 584626,
#  'isn about': 507765,
#  'the incredibly': 944380,
#  'incredibly tedious': 481359,
#  'tedious question': 922566,
#  'question of': 763244,
#  'of who': 674819,
#  'who wrote': 1063048,
#  'wrote citizen': 1087259,
#  'citizen kane': 190145,
#  'kane that': 530982,
#  'that the': 936487,
#  'the hook': 943990,
#  'hook but': 453150,
#  'but the': 156603,
#  'film true': 352480,
#  'true interest': 1000039,
#  'interest to': 492150,
#  'to my': 982614,
#  'my immense': 633548,
#  'immense relief': 469046,
#  'relief is': 784250,
#  'incredibly specific': 481346,
#  'specific story': 874059,
#  'of upton': 674393,
#  'upton sinclair': 1024214,
#  'sinclair failed': 849283,
#  'failed 1934': 332457,
#  '1934 california': 1376,
#  'california gubernatorial': 162699,
#  'gubernatorial bid': 417064,
#  'sterling': 886116,
#  'supporting': 908467,
#  'down': 277273,
#  'tiniest': 977223,
#  'parts': 711793,
#  'provides': 756244,
#  'astringent': 91704,
#  'intelligence': 490556,
#  'slobbering': 855477,
#  'sentimentality': 829970,
#  'go': 403263,
#  'ease': 288414,
#  'sterling supporting': 886144,
#  'supporting cast': 908475,
#  'cast down': 171532,
#  'down to': 277664,
#  'to the': 984896,
#  'the tiniest': 951606,
#  'tiniest bit': 977224,
#  'bit parts': 128162,
#  'parts provides': 711948,
#  'provides enough': 756289,
#  'enough astringent': 306060,
#  'astringent intelligence': 91707,
#  'intelligence to': 490653,
#  'to make': 982273,
#  'make the': 580188,
#  'the slobbering': 950171,
#  'slobbering sentimentality': 855480,
#  'sentimentality go': 829999,
#  'go down': 403363,
#  'down with': 277701,
#  'with ease': 1071751,
#  'enthusiastically': 308904,
#  'acted': 19373,
#  'sharply': 837273,
#  'written': 1086775,
#  'lovefest': 571791,
#  'honor': 452809,
#  'alien': 34007,
#  'visitation': 1036941,
#  'movies': 626675,
#  'we': 1048402,
#  'hold': 449851,
#  'near': 639013,
#  'dear': 242273,
#  'enthusiastically acted': 308905,
#  'acted and': 19388,
#  'and sharply': 61849,
#  'sharply written': 837321,
#  'written big': 1086804,
#  'big old': 126038,
#  'old lovefest': 679179,
#  'lovefest in': 571793,
#  'in honor': 475176,
#  'honor of': 452842,
#  'the classic': 939831,
#  'classic alien': 191554,
#  'alien visitation': 34106,
#  'visitation movies': 1036944,
#  'movies that': 627120,
#  'that we': 936967,
#  'we all': 1048419,
#  'all hold': 35240,
#  'hold near': 449909,
#  'near and': 639022,
#  'and dear': 52334,
#  'assistant': 90943,
#  'must': 632718,
#  'see': 824273,
#  'because': 113070,
#  'relates': 782883,
#  'behaviour': 117429,
#  'everyone': 319205,
#  'within': 1076352,
#  'workplace': 1082184,
#  'without': 1076563,
#  'need': 639987,
#  'preach': 743810,
#  'the assistant': 938196,
#  'assistant is': 90953,
#  'is must': 504413,
#  'must see': 632855,
#  'see not': 824709,
#  'not just': 653371,
#  'just because': 528666,
#  'because it': 113219,
#  'it relates': 512651,
#  'relates to': 782889,
#  'the behaviour': 938604,
#  'behaviour of': 117439,
#  'of everyone': 665787,
#  'everyone within': 319476,
#  ...}
