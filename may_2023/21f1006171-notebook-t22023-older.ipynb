# %% [markdown]
# # MLP Project (T2 2023) by Ganesh P

# %% [markdown]
# `Disclaimer`
#
# > This final notebook contains only the most relevant code to show the path/flow of my project work over few weeks. Rest of the code is in [my github repo](https://github.com/ganeshbmc/MLP_project) which is private at present (I will make it public after the project is over).

# %% [markdown]
# `Overview`
#
# `PART I`
#
# 1.	> Screen the datasets and import them.
# 2.	> Perform EDA (first round).
# 3.	> Data cleaning.
# 4.	> Basic models including dummy model.
# 5.	> Because this is a text sentiment analysis project, focus on 'reviewText' column, work on cleaning text data and vectorising/tokenising it, build several models till the best possible score is reached.
#
# `PART II`
#
# 6.	> Merge train and movies dataset.
# 7.	> Perform EDA (second round) on merged dataset.
# 8.	> Data cleaning.
# 9.	> Build models on merged dataset.
# 10.	> Understand the results and do another round of EDA if needed.
# 11.	> Build final model.
#
# `PART III (After project window closes)`
#
# 12. > Use NLTK library for further processing text data.
# 13. > Try to address comments from different languages, special characters etc.
# 14. > Try imblearn library to address class imbalance.
# 15. > Try to use currently available LLMs and see how my model performs agains them.

# %% [markdown]
# `Default code on Kaggle notebook`

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# ## Import remaining libraries

# %%
# import pandas as pd
# import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
from itertools import compress

from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.compose import ColumnTransformer
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.preprocessing import FunctionTransformer
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OneHotEncoder, LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.svm import LinearSVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.decomposition import PCA, TruncatedSVD
from sklearn.feature_selection import RFECV
from sklearn.feature_selection import RFE

# import lightgbm as ltb

import scipy.stats as stats
print("Imports done.")
# Out:
# Imports done.

# %% [markdown]
# ## Load datasets

# %%
traindf = pd.read_csv("data/train.csv")
traindf.shape
# Out:
# (162758, 5)

# %%
testdf = pd.read_csv("data/test.csv")
testdf.shape
# Out:
# (55315, 4)

# %% [markdown]
# ## Understanding the data and getting it ready for training and evaluating models
#
# `Handle missing data. Current strategy is to fill in some custom text.`
# `Separate features and labels from traindf`
# `Split training data into training and testing parts`

# %%
traindf.shape
# Out:
# (162758, 5)

# %%
traindf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 162758 entries, 0 to 162757
# Data columns (total 5 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   movieid             162758 non-null  object
#  1   reviewerName        162758 non-null  object
#  2   isFrequentReviewer  162758 non-null  bool
#  3   reviewText          156311 non-null  object
#  4   sentiment           162758 non-null  object
# dtypes: bool(1), object(4)
# memory usage: 5.1+ MB

# %%
traindf.isna().sum()
# Out:
# movieid                  0
# reviewerName             0
# isFrequentReviewer       0
# reviewText            6447
# sentiment                0
# dtype: int64

# %% [markdown]
# ### Fill empty reviewText with custom text

# %%
traindf["reviewText"].fillna("empty", inplace=True)
traindf.isna().sum()
# Out:
# movieid               0
# reviewerName          0
# isFrequentReviewer    0
# reviewText            0
# sentiment             0
# dtype: int64

# %% [markdown]
# ## EDA
# `Currently in a separate file in github repo`

# %%
# Pie chart for sentiment column
plt.figure(figsize=(6, 4))
traindf["sentiment"].value_counts().plot(kind='pie', autopct='%1.0f%%', colors=["lightgreen", "crimson"])
plt.title("Pie chart for sentiment column")
plt.show()

# %%
# Chi-square test for isFrequentReviewer column and sentiment column   

contingency_table = pd.crosstab(traindf['isFrequentReviewer'], traindf['sentiment'])
print(contingency_table)
stats.chi2_contingency(contingency_table)
# Out:
# sentiment           NEGATIVE  POSITIVE
# isFrequentReviewer
# False                  35760     77429
# True                   18237     31332
# (419.89235425657796,
#  2.5755894769493255e-93,
#  1,
#  array([[37551.86493444, 75637.13506556],
#         [16445.13506556, 33123.86493444]]))

# %% [markdown]
# ### Separate features and labels

# %%
train_features = traindf["reviewText"]
train_labels = traindf.iloc[:, -1]
train_features.shape, train_labels.shape
# Out:
# ((162758,), (162758,))

# %% [markdown]
# ### Split traindf into training and testing parts

# %%
X_train, X_test, y_train, y_test = train_test_split(train_features, train_labels, test_size=0.25, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((122068,), (40690,), (122068,), (40690,))

# %% [markdown]
# ### Needs further exploration
#
# `stratify based on reviewer type?`

# %% [markdown]
# ## Model evaluation plan and code

# %%
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import f1_score

# %%
def evaluate(y_test, y_pred):
    print(classification_report(y_test, y_pred))
    print(confusion_matrix(y_test, y_pred))
    # print(f1_score(y_test, y_pred))
    ConfusionMatrixDisplay(y_test, y_pred)
    return

# %% [markdown]
# # Data preprocessing

# %% [markdown]
# ## Define stop words

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

# %%
# stop_words = ["0o", "0s", "3a", "3b", "3d", "6b", "6o", "a", "a1", "a2", "a3", "a4", "ab", "able", "about", "above", "abst", "ac", "accordance", "according", "accordingly", "across", "act", "actually", "ad", "added", "adj", "ae", "af", "affected", "affecting", "affects", "after", "afterwards", "ag", "again", "against", "ah", "ain", "ain't", "aj", "al", "all", "allow", "allows", "almost", "alone", "along", "already", "also", "although", "always", "am", "among", "amongst", "amoungst", "amount", "an", "and", "announce", "another", "any", "anybody", "anyhow", "anymore", "anyone", "anything", "anyway", "anyways", "anywhere", "ao", "ap", "apart", "apparently", "appear", "appreciate", "appropriate", "approximately", "ar", "are", "aren", "arent", "aren't", "arise", "around", "as", "a's", "aside", "ask", "asking", "associated", "at", "au", "auth", "av", "available", "aw", "away", "awfully", "ax", "ay", "az", "b", "b1", "b2", "b3", "ba", "back", "bc", "bd", "be", "became", "because", "become", "becomes", "becoming", "been", "before", "beforehand", "begin", "beginning", "beginnings", "begins", "behind", "being", "believe", "below", "beside", "besides", "best", "better", "between", "beyond", "bi", "bill", "biol", "bj", "bk", "bl", "bn", "both", "bottom", "bp", "br", "brief", "briefly", "bs", "bt", "bu", "but", "bx", "by", "c", "c1", "c2", "c3", "ca", "call", "came", "can", "cannot", "cant", "can't", "cause", "causes", "cc", "cd", "ce", "certain", "certainly", "cf", "cg", "ch", "changes", "ci", "cit", "cj", "cl", "clearly", "cm", "c'mon", "cn", "co", "com", "come", "comes", "con", "concerning", "consequently", "consider", "considering", "contain", "containing", "contains", "corresponding", "could", "couldn", "couldnt", "couldn't", "course", "cp", "cq", "cr", "cry", "cs", "c's", "ct", "cu", "currently", "cv", "cx", "cy", "cz", "d", "d2", "da", "date", "dc", "dd", "de", "definitely", "describe", "described", "despite", "detail", "df", "di", "did", "didn", "didn't", "different", "dj", "dk", "dl", "do", "does", "doesn", "doesn't", "doing", "don", "done", "don't", "down", "downwards", "dp", "dr", "ds", "dt", "du", "due", "during", "dx", "dy", "e", "e2", "e3", "ea", "each", "ec", "ed", "edu", "ee", "ef", "effect", "eg", "ei", "eight", "eighty", "either", "ej", "el", "eleven", "else", "elsewhere", "em", "empty", "en", "end", "ending", "enough", "entirely", "eo", "ep", "eq", "er", "es", "especially", "est", "et", "et-al", "etc", "eu", "ev", "even", "ever", "every", "everybody", "everyone", "everything", "everywhere", "ex", "exactly", "example", "except", "ey", "f", "f2", "fa", "far", "fc", "few", "ff", "fi", "fifteen", "fifth", "fify", "fill", "find", "fire", "first", "five", "fix", "fj", "fl", "fn", "fo", "followed", "following", "follows", "for", "former", "formerly", "forth", "forty", "found", "four", "fr", "from", "front", "fs", "ft", "fu", "full", "further", "furthermore", "fy", "g", "ga", "gave", "ge", "get", "gets", "getting", "gi", "give", "given", "gives", "giving", "gj", "gl", "go", "goes", "going", "gone", "got", "gotten", "gr", "greetings", "gs", "gy", "h", "h2", "h3", "had", "hadn", "hadn't", "happens", "hardly", "has", "hasn", "hasnt", "hasn't", "have", "haven", "haven't", "having", "he", "hed", "he'd", "he'll", "hello", "help", "hence", "her", "here", "hereafter", "hereby", "herein", "heres", "here's", "hereupon", "hers", "herself", "hes", "he's", "hh", "hi", "hid", "him", "himself", "his", "hither", "hj", "ho", "home", "hopefully", "how", "howbeit", "however", "how's", "hr", "hs", "http", "hu", "hundred", "hy", "i", "i2", "i3", "i4", "i6", "i7", "i8", "ia", "ib", "ibid", "ic", "id", "i'd", "ie", "if", "ig", "ignored", "ih", "ii", "ij", "il", "i'll", "im", "i'm", "immediate", "immediately", "importance", "important", "in", "inasmuch", "inc", "indeed", "index", "indicate", "indicated", "indicates", "information", "inner", "insofar", "instead", "interest", "into", "invention", "inward", "io", "ip", "iq", "ir", "is", "isn", "isn't", "it", "itd", "it'd", "it'll", "its", "it's", "itself", "iv", "i've", "ix", "iy", "iz", "j", "jj", "jr", "js", "jt", "ju", "just", "k", "ke", "keep", "keeps", "kept", "kg", "kj", "km", "know", "known", "knows", "ko", "l", "l2", "la", "largely", "last", "lately", "later", "latter", "latterly", "lb", "lc", "le", "least", "les", "less", "lest", "let", "lets", "let's", "lf", "like", "liked", "likely", "line", "little", "lj", "ll", "ll", "ln", "lo", "look", "looking", "looks", "los", "lr", "ls", "lt", "ltd", "m", "m2", "ma", "made", "mainly", "make", "makes", "many", "may", "maybe", "me", "mean", "means", "meantime", "meanwhile", "merely", "mg", "might", "mightn", "mightn't", "mill", "million", "mine", "miss", "ml", "mn", "mo", "more", "moreover", "most", "mostly", "move", "mr", "mrs", "ms", "mt", "mu", "much", "mug", "must", "mustn", "mustn't", "my", "myself", "n", "n2", "na", "name", "namely", "nay", "nc", "nd", "ne", "near", "nearly", "necessarily", "necessary", "need", "needn", "needn't", "needs", "neither", "never", "nevertheless", "new", "next", "ng", "ni", "nine", "ninety", "nj", "nl", "nn", "no", "nobody", "non", "none", "nonetheless", "noone", "nor", "normally", "nos", "not", "noted", "nothing", "novel", "now", "nowhere", "nr", "ns", "nt", "ny", "o", "oa", "ob", "obtain", "obtained", "obviously", "oc", "od", "of", "off", "often", "og", "oh", "oi", "oj", "ok", "okay", "ol", "old", "om", "omitted", "on", "once", "one", "ones", "only", "onto", "oo", "op", "oq", "or", "ord", "os", "ot", "other", "others", "otherwise", "ou", "ought", "our", "ours", "ourselves", "out", "outside", "over", "overall", "ow", "owing", "own", "ox", "oz", "p", "p1", "p2", "p3", "page", "pagecount", "pages", "par", "part", "particular", "particularly", "pas", "past", "pc", "pd", "pe", "per", "perhaps", "pf", "ph", "pi", "pj", "pk", "pl", "placed", "please", "plus", "pm", "pn", "po", "poorly", "possible", "possibly", "potentially", "pp", "pq", "pr", "predominantly", "present", "presumably", "previously", "primarily", "probably", "promptly", "proud", "provides", "ps", "pt", "pu", "put", "py", "q", "qj", "qu", "que", "quickly", "quite", "qv", "r", "r2", "ra", "ran", "rather", "rc", "rd", "re", "readily", "really", "reasonably", "recent", "recently", "ref", "refs", "regarding", "regardless", "regards", "related", "relatively", "research", "research-articl", "respectively", "resulted", "resulting", "results", "rf", "rh", "ri", "right", "rj", "rl", "rm", "rn", "ro", "rq", "rr", "rs", "rt", "ru", "run", "rv", "ry", "s", "s2", "sa", "said", "same", "saw", "say", "saying", "says", "sc", "sd", "se", "sec", "second", "secondly", "section", "see", "seeing", "seem", "seemed", "seeming", "seems", "seen", "self", "selves", "sensible", "sent", "serious", "seriously", "seven", "several", "sf", "shall", "shan", "shan't", "she", "shed", "she'd", "she'll", "shes", "she's", "should", "shouldn", "shouldn't", "should've", "show", "showed", "shown", "showns", "shows", "si", "side", "significant", "significantly", "similar", "similarly", "since", "sincere", "six", "sixty", "sj", "sl", "slightly", "sm", "sn", "so", "some", "somebody", "somehow", "someone", "somethan", "something", "sometime", "sometimes", "somewhat", "somewhere", "soon", "sorry", "sp", "specifically", "specified", "specify", "specifying", "sq", "sr", "ss", "st", "still", "stop", "strongly", "sub", "substantially", "successfully", "such", "sufficiently", "suggest", "sup", "sure", "sy", "system", "sz", "t", "t1", "t2", "t3", "take", "taken", "taking", "tb", "tc", "td", "te", "tell", "ten", "tends", "tf", "th", "than", "thank", "thanks", "thanx", "that", "that'll", "thats", "that's", "that've", "the", "their", "theirs", "them", "themselves", "then", "thence", "there", "thereafter", "thereby", "thered", "therefore", "therein", "there'll", "thereof", "therere", "theres", "there's", "thereto", "thereupon", "there've", "these", "they", "theyd", "they'd", "they'll", "theyre", "they're", "they've", "thickv", "thin", "think", "third", "this", "thorough", "thoroughly", "those", "thou", "though", "thoughh", "thousand", "three", "throug", "through", "throughout", "thru", "thus", "ti", "til", "tip", "tj", "tl", "tm", "tn", "to", "together", "too", "took", "top", "toward", "towards", "tp", "tq", "tr", "tried", "tries", "truly", "try", "trying", "ts", "t's", "tt", "tv", "twelve", "twenty", "twice", "two", "tx", "u", "u201d", "ue", "ui", "uj", "uk", "um", "un", "under", "unfortunately", "unless", "unlike", "unlikely", "until", "unto", "uo", "up", "upon", "ups", "ur", "us", "use", "used", "useful", "usefully", "usefulness", "uses", "using", "usually", "ut", "v", "va", "value", "various", "vd", "ve", "ve", "very", "via", "viz", "vj", "vo", "vol", "vols", "volumtype", "vq", "vs", "vt", "vu", "w", "wa", "want", "wants", "was", "wasn", "wasnt", "wasn't", "way", "we", "wed", "we'd", "welcome", "well", "we'll", "well-b", "went", "were", "we're", "weren", "werent", "weren't", "we've", "what", "whatever", "what'll", "whats", "what's", "when", "whence", "whenever", "when's", "where", "whereafter", "whereas", "whereby", "wherein", "wheres", "where's", "whereupon", "wherever", "whether", "which", "while", "whim", "whither", "who", "whod", "whoever", "whole", "who'll", "whom", "whomever", "whos", "who's", "whose", "why", "why's", "wi", "widely", "will", "willing", "wish", "with", "within", "without", "wo", "won", "wonder", "wont", "won't", "words", "world", "would", "wouldn", "wouldnt", "wouldn't", "www", "x", "x1", "x2", "x3", "xf", "xi", "xj", "xk", "xl", "xn", "xo", "xs", "xt", "xv", "xx", "y", "y2", "yes", "yet", "yj", "yl", "you", "youd", "you'd", "you'll", "your", "youre", "you're", "yours", "yourself", "yourselves", "you've", "yr", "ys", "yt", "z", "zero", "zi", "zz"]
# type(stop_words), len(stop_words)

# %% [markdown]
# ## Feature extraction

# %% [markdown]
# ### Understand CountVectorizer and TfidfVectorizer

# %%
# text = X_train.copy()
# text.head()

# %%
# vectorizer = TfidfVectorizer(stop_words=stop_words)
# vectorized_text = vectorizer.fit_transform(text["reviewText"])
# vectorized_text

# %% [markdown]
# `Without stop words`
# <122068x58624 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2312222 stored elements in Compressed Sparse Row format>
#
# `With stop words`
# <122068x57784 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1188395 stored elements in Compressed Sparse Row format>

# %%
# vectorizer2 = CountVectorizer(stop_words=stop_words)
# vectorized_text2 = vectorizer2.fit_transform(text["reviewText"])
# vectorized_text2

# %% [markdown]
# `Without stop words`
# <122068x58624 sparse matrix of type '<class 'numpy.int64'>'
# 	with 2312222 stored elements in Compressed Sparse Row format>
#
# `With stop words`
# <122068x57784 sparse matrix of type '<class 'numpy.int64'>'
# 	with 1188395 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ### Conclusion
# `TfidfVectorizer is equivalent to CountVectorizer followed by TfidfTransformer.`
#
# https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfVectorizer.html

# %% [markdown]
# ## Model building workflow
#
# `Make pipeline for preprocesing and model training and predictions`

# %%
from sklearn.pipeline import Pipeline

# %%
def preprocess_n_train(X_train, y_train, preprocessor, model):
    pipe = Pipeline(steps=[
                            ("preprocessor", preprocessor),
                            ("model", model)
                        ])
    
    pipe.fit(X_train, y_train)

    print("Given model has been trained. Use predict method to get predictions array.")
    return pipe


def predict_n_evaluate(pipeline, X_test, y_test):
    y_pred = pipeline.predict(X_test)
    print(f"y_pred shape: {y_pred.shape}")
    print(f"Summary of predictions: {np.unique(y_pred, return_counts=True)}")
    print(classification_report(y_test, y_pred))
    print(confusion_matrix(y_test, y_pred))
    return y_pred

# def evaluate(y_test, y_pred):
#     print(classification_report(y_test, y_pred))
#     print(confusion_matrix(y_test, y_pred))
#     # print(f1_score(y_test, y_pred))
#     ConfusionMatrixDisplay(y_test, y_pred)
#     return

# %% [markdown]
# ## Preprocessor(s)

# %%
tvec = TfidfVectorizer()
# tvec_sw = TfidfVectorizer(stop_words=stop_words)

# %% [markdown]
# ## Logistic Regression with TfidVectorizer for preprocessing

# %%
from sklearn.linear_model import LogisticRegression

# %%
logreg = LogisticRegression(max_iter=1000)
logreg
# Out:
# LogisticRegression(max_iter=1000)

# %%
# tvec = TfidfVectorizer()
# cvec = CountVectorizer()        # Note that TfidfVectorizer and CountVectorizer+TfidsTransformer do the same function
# tvec, cvec

# %%
# logreg_pipe = preprocess_n_train(X_train, y_train, tvec, logreg)
# logreg_pipe

# %%
# y_pred_logreg = predict_n_evaluate(logreg_pipe, X_test, y_test)
# y_pred_logreg

# %% [markdown]
# ### Logistic Regression with stop words

# %%
# tvec_sw = TfidfVectorizer(stop_words=stop_words)

# %%
# logreg_sw_pipe = preprocess_n_train(X_train, y_train, tvec_sw, logreg)
# logreg_sw_pipe

# %%
# y_pred_logreg_sw = predict_n_evaluate(logreg_sw_pipe, X_test, y_test)
# y_pred_logreg_sw

# %% [markdown]
# ### Logistic regression with different ngram ranges

# %% [markdown]
# #### ngram range (1,2)

# %%
# tvec_ngram_2 = TfidfVectorizer(ngram_range=(1,2))

# %%
# logreg_ng2_pipe = preprocess_n_train(X_train, y_train, tvec_ngram_2, logreg)
# logreg_ng2_pipe

# %%
# y_pred_logreg_ng2 = predict_n_evaluate(logreg_ng2_pipe, X_test, y_test)
# y_pred_logreg_ng2

# %% [markdown]
# ### Logistic regression with C=2, ngram range (1,2), stop words as None and min_df, max_df adjusted
# ### Class weight balanced

# %%
# logreg = LogisticRegression(max_iter=100000, C=2, class_weight="balanced")

# %%
# tvec_ngram_2_sw_df = TfidfVectorizer(ngram_range=(1,2), stop_words=None, min_df=0.0001, max_df=0.50)
# tvec_ngram_2_sw_df

# %%
# logreg_ng2_sw_df_pipe = preprocess_n_train(X_train, y_train, tvec_ngram_2_sw_df, logreg)
# logreg_ng2_sw_df_pipe

# %%
# y_pred_logreg_ng2_sw_df = predict_n_evaluate(logreg_ng2_sw_df_pipe, X_test, y_test)
# y_pred_logreg_ng2_sw_df

# %% [markdown]
# ## Log reg with parameters from GridSearchCV
#
# `This is the best score with "reviewText column alone for analysis`

# %%
logreg_cv1 = LogisticRegression(max_iter=100000, C=10)
tvec_cv1 = TfidfVectorizer(max_features=None, ngram_range=(1,2))

# %%
pipe_cv1 = Pipeline(steps=[
    ("preprocessor", tvec_cv1),
    ("model", logreg_cv1)
])

# %%
# pipe_cv1.fit(X_train, y_train)

# %%
# pipe_cv1.score(X_train, y_train)

# %% [markdown]
# ## SVM model

# %%
# from sklearn.svm import LinearSVC

# %%
# svm = LinearSVC()
# svm

# %%
# svm_pipe = preprocess_n_train(X_train, y_train, tvec, svm)
# svm_pipe

# %%
# y_pred_svm = predict_n_evaluate(svm_pipe, X_test, y_test)
# y_pred_svm

# %% [markdown]
# ### SVM model with stop words

# %%
# svm_sw_pipe = preprocess_n_train(X_train, y_train, tvec_sw, svm)
# svm_sw_pipe

# %%
# y_pred_svm_sw = predict_n_evaluate(svm_sw_pipe, X_test, y_test)
# y_pred_svm_sw

# %% [markdown]
# ## Naive Bayes model

# %% [markdown]
# ### MultinomialNB

# %%
# from sklearn.naive_bayes import GaussianNB, BernoulliNB, CategoricalNB, ComplementNB, MultinomialNB

# %%
# mnb = MultinomialNB()
# mnb

# %%
# mnb_pipe = preprocess_n_train(X_train, y_train, tvec, mnb)
# mnb_pipe

# %%
# y_pred_mnb = predict_n_evaluate(mnb_pipe, X_test, y_test)
# y_pred_mnb

# %% [markdown]
# ### GaussianNB

# %% [markdown]
# https://stackoverflow.com/questions/28384680/scikit-learns-pipeline-a-sparse-matrix-was-passed-but-dense-data-is-required

# %%
# gnb = GaussianNB()
# gnb

# %%
# gnb_pipe = preprocess_n_train(X_train, y_train, tvec, gnb)
# gnb_pipe

# %% [markdown]
# ## Submitting predictions to Kaggle competition

# %%
def submit(selected_model=logreg, selected_preprocessor=tvec):
    
    # Retrain on the whole train.csv file  
    traindf = pd.read_csv("/kaggle/input/sentiment-prediction-on-movie-reviews/train.csv")
    X_train = traindf["reviewText"]
    X_train.fillna("empty", inplace=True)
    y_train = traindf["sentiment"]
    pipe = preprocess_n_train(X_train, y_train, selected_preprocessor, selected_model)
    
    # Predict on test.csv file
    testdf = pd.read_csv("/kaggle/input/sentiment-prediction-on-movie-reviews/test.csv")
    X_test = testdf["reviewText"]
    X_test.fillna("empty", inplace=True)
    
    y_pred = pipe.predict(X_test)
    
    pred_df = pd.DataFrame(y_pred)
    pred_df.columns = ["sentiment"]
    pred_df.index.name = "id"
    pred_df.to_csv("submission.csv")
    
    return "Successfully created the submission file!!!"

# %%
# submit(logreg_cv1, tvec_cv1)

# %% [markdown]
# ## Part 2: Merge "movies.csv" with "train.csv" to see if score improves

# %% [markdown]
# ### Custom functions

# %%
def load_csv(filename: str):
    df = pd.read_csv(f"data/{filename}.csv")
    return df

# %%
def inspect(df: pd.DataFrame):
    print(f"Shape of the dataframe: {df.shape}")
    print()
    print(f"Columns in the dataframe:\n{df.columns}")
    print()
    print(f"{df.info()}")
    print()
    # print(f"Summary: {df.describe()}")
    print(f"Missing values:\n{df.isna().sum()}")
    return

# %%
def name_fl(name):
    l = name.split()
    n = ' '.join((l[0], l[-1]))
    return n

# %%
def select_features(df: pd.DataFrame, moviesdf: pd.DataFrame):
    '''
    This function merges the given dataframes. Note that the first df must be "train" or "test" and
    the second df should be "movies".
    Note: Sentiment column is present only in "train.csv" file and not "test.csv" file.
    '''
    
    # Drop duplicates from moviesdf
#     movies_unique = moviesdf.drop_duplicates(subset=["movieid"])
    # Drop duplicates using groupby - clubs similar rows and fills in missing values better
    movies_unique = moviesdf.fillna(value=np.nan).groupby("movieid").first()

    # Merge df and movies_unique
    df_merged = pd.merge(df, movies_unique, on="movieid", how='left')
    
    # Rename "isTopCritic" column, if it exists, to "isFrequentReviewer"
    df_merged.rename(columns={"isTopCritic": "isFrequentReviewer"}, inplace=True)
    
    # Drop columns
    df_merged = df_merged.drop(columns=["title", "ratingContents", "releaseDateTheaters", "releaseDateStreaming", "distributor", "soundType"])

    # Fill missing values in "reviewText" with empty string
    final = df_merged.copy()
    final["reviewYN"] = np.where(final["reviewText"].isnull(), 1, 0)    # Feature engineering - adding a new column
    final["reviewWC"] = final.apply(lambda x: len(str(x["reviewText"]).split()), axis=1)    # Feature engineering - adding second new column
    final["reviewText"] = final["reviewText"].fillna("neutral")
    
    # Fill missing values in "rating", "genre", original columns with the word "Unknown"
    final["rating"] = final["rating"].fillna("Unknown")
    final["genre"] = final["genre"].fillna("Unknown")
    final["originalLanguage"] = final["originalLanguage"].fillna("Unknown")

    # Impute missing values for "audienceScore" and "runtimeMinutes" columns
    final["audienceScore"] = final["audienceScore"].fillna(final["audienceScore"].mean())
    final["runtimeMinutes"] = final["runtimeMinutes"].fillna(final["runtimeMinutes"].median())
    
    # Preprocess and impute missing values in "boxOffice" column
    final["boxOffice"] = final["boxOffice"].str[1:]
    final["boxOffice"] = final["boxOffice"].replace(to_replace={"M": "*1000000", "K": "*1000"}, regex=True)
    final["boxOffice"] = final["boxOffice"].loc[final["boxOffice"].notnull()].apply(lambda x: eval(str(x)))
    final["boxOffice"] = final["boxOffice"].fillna(final["boxOffice"].median())
    # (Optional) Replace outliers in boxOffice with median
    median = final["boxOffice"].describe()['50%']
    iqr = final["boxOffice"].describe()['75%'] - final["boxOffice"].describe()['25%']
    ll = median - (1.5*iqr)
    ul = median + (1.5*iqr)
    final.loc[final["boxOffice"] > ul, "boxOffice"] = median
    
    # Clean language names
    final["originalLanguage"].replace({"English (United Kingdom)": "English", 
                                            "English (Australia)" : "English",
                                            "French (France)": "French", 
                                            "French (Canada)": "French",
                                            "Portuguese (Brazil)": "Portuguese",
                                            "Spanish (Spain)": "Spanish"},                                         
                                            inplace=True)
    
    # Clean reviewerName column
    pre_post_fixes = {"Mr. ": "", "Mrs. ": "", "Ms. ": "", "Dr. ": "", 
                      " MD": "", " DDS": "", " DVM": "", " Jr.": "", " PhD": "", " II": "", " IV": ""}
    final["reviewerName"] = final["reviewerName"].replace(pre_post_fixes, regex=True)
    final["reviewerName"] = final["reviewerName"].apply(name_fl)

    return final

# %%
def split_train_predict(features, labels, pipeline, test_size=0.25, random_state=42):
    # cols = features.columns
    if len(features.shape) == 1:
        features = features.to_numpy().reshape(-1, 1)  # reshape to 2D array
    features = pd.DataFrame(features)
    X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=test_size, random_state=random_state)
    pipeline.fit(X_train, y_train)
    y_pred = pipeline.predict(X_test)
    print(classification_report(y_test, y_pred))
    print(confusion_matrix(y_test, y_pred))
    return pipeline

# %% [markdown]
# ### Merge "train.csv" file with "movies.csv" file

# %%
merged = select_features(load_csv("train"), load_csv("movies"))
inspect(merged)
# Out:
# Shape of the dataframe: (162758, 14)
#
# Columns in the dataframe:
# Index(['movieid', 'reviewerName', 'isFrequentReviewer', 'reviewText',
#        'sentiment', 'audienceScore', 'rating', 'runtimeMinutes', 'genre',
#        'originalLanguage', 'director', 'boxOffice', 'reviewYN', 'reviewWC'],
#       dtype='object')
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 162758 entries, 0 to 162757
# Data columns (total 14 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   movieid             162758 non-null  object
#  1   reviewerName        162758 non-null  object
#  2   isFrequentReviewer  162758 non-null  bool
#  3   reviewText          162758 non-null  object
#  4   sentiment           162758 non-null  object
#  5   audienceScore       162758 non-null  float64
#  6   rating              162758 non-null  object
#  7   runtimeMinutes      162758 non-null  float64
#  8   genre               162758 non-null  object
#  9   originalLanguage    162758 non-null  object
#  10  director            162758 non-null  object
#  11  boxOffice           162758 non-null  float64
#  12  reviewYN            162758 non-null  int32
#  13  reviewWC            162758 non-null  int64
# dtypes: bool(1), float64(3), int32(1), int64(1), object(8)
# memory usage: 16.9+ MB
# None
#
# Missing values:
# movieid               0
# reviewerName          0
# isFrequentReviewer    0
# reviewText            0
# sentiment             0
# audienceScore         0
# rating                0
# runtimeMinutes        0
# genre                 0
# originalLanguage      0
# director              0
# boxOffice             0
# reviewYN              0
# reviewWC              0
# dtype: int64

# %%
merged["reviewText"].head()
# Out:
# 0    Henry Selick’s first movie since 2009’s Corali...
# 1    With a cast that reads like the Vogue Oscar pa...
# 2    Creed II does not give us anything but another...
# 3    I know what you're thinking, but this is no Li...
# 4    Director Fernando Meirelles tells the story wi...
# Name: reviewText, dtype: object

# %%
merged["reviewYN"].sum()
# Out:
# 6447

# %%
merged["reviewWC"].head()
# Out:
# 0    11
# 1    24
# 2    22
# 3    34
# 4    20
# Name: reviewWC, dtype: int64

# %%
merged["reviewWC"].describe()
# Out:
# count    162758.000000
# mean         21.013707
# std          10.216532
# min           1.000000
# 25%          14.000000
# 50%          21.000000
# 75%          28.000000
# max          54.000000
# Name: reviewWC, dtype: float64

# %%
sns.histplot(merged["reviewWC"])
# Out:
# <AxesSubplot:xlabel='reviewWC', ylabel='Count'>

# %%
merged['rating'].value_counts()
# Out:
# R          60248
# Unknown    44587
# PG-13      42697
# PG         13669
# TV14         947
# NC-17        285
# TVPG         281
# TVMA          44
# Name: rating, dtype: int64

# %%
merged['isFrequentReviewer'].value_counts()
# Out:
# False    113189
# True      49569
# Name: isFrequentReviewer, dtype: int64

# %%
merged["reviewerName"].head()
# Out:
# 0      Benjamin Henry
# 1       Felicia Lopez
# 2     Charles Burgess
# 3        Ryan Barrett
# 4    Alexander Glover
# Name: reviewerName, dtype: object

# %%
merged['boxOffice'].value_counts()
# Out:
# 14300000.0    57634
# 2000000.0       922
# 1100000.0       891
# 1000000.0       834
# 1200000.0       802
#               ...
# 283100.0          1
# 58500.0           1
# 500800.0          1
# 813700.0          1
# 799400.0          1
# Name: boxOffice, Length: 3130, dtype: int64

# %%
# Check correlation between 'boxOffice' and ''sentiment'
# bo_df = merged.copy()
# print(bo_df["boxOffice"])
# bo_df["boxOffice"] = bo_df["boxOffice"].str[1:]
# bo_df["boxOffice"] = bo_df["boxOffice"].replace(to_replace={"M": "*1000000", "K": "*1000"}, regex=True)
# bo_df["boxOffice"] = bo_df["boxOffice"].loc[bo_df["boxOffice"].notnull()].apply(lambda x: eval(str(x)))
# bo_df["boxOffice"] = bo_df["boxOffice"].fillna(bo_df["boxOffice"].median())
# bo_df["boxOffice"].describe()

# %%
# median = bo_df["boxOffice"].describe()['50%']
# iqr = bo_df["boxOffice"].describe()['75%'] - bo_df["boxOffice"].describe()['25%']
# median, iqr

# %%
# ll = median - (1.5*iqr)
# ul = median + (1.5*iqr)
# ll, ul

# %%
# bo_df["boxOffice"].mean()

# %%
# bo_df.loc[bo_df["boxOffice"] > ul, "boxOffice"] = median
# bo_df["boxOffice"].mean()

# %%
# bo_df["boxOffice"].min(), bo_df["boxOffice"].max()

# %%
# sns.boxplot(x="sentiment", y="boxOffice", data=bo_df, showfliers = False)

# %% [markdown]
# ## EDA

# %% [markdown]
# ### An interesting finding through exploration
#
# * OHE and TfidfVectorizer on director column give the same result when ngram_range(2,2) is used (see code below)!

# %%
# Compare OHE and TfidfVectorizer on director column

# dirs = merged["director"].copy()
# print(dirs.shape)
# dirs_uniq = merged["director"].unique()
# print(len(dirs_uniq))

# du_ohe = OneHotEncoder(handle_unknown="ignore", sparse=True).fit_transform(dirs.to_numpy().reshape(-1, 1))
# print(du_ohe.shape, type(du_ohe))

# dirs_2 = merged["director"].copy()
# print(dirs_2.shape)
# du_tfidf = TfidfVectorizer(ngram_range=(2,2)).fit_transform(dirs_2).toarray()
# print(du_tfidf.shape, type(du_tfidf))

# print(np.array_equal(du_ohe, du_tfidf))

# %%
# print(dirs.head())
# d = dirs.copy()
# d["name_len"] = d.apply(lambda x: len(x.split()))
# d["name_len"].value_counts()

# %%
# Compare OHE and TfidfVectorizer on reviewerName column
# Note: reviewerName column has salutations like "Mr. " etc, and some names appear middle names. Therefore needs cleaning

# def name_fl(name):
#     l = name.split()
#     n = ' '.join((l[0], l[-1]))
#     return n

# reviewers = merged["reviewerName"].copy()
# reviewers = pd.DataFrame(reviewers)
# reviewers = reviewers.replace({"Mr. ": "", "Mrs. ": ""}, regex=True)
# reviewers["reviewerName"] = reviewers["reviewerName"].apply(name_fl)
# print(reviewers.shape)

# reviewers_uniq = merged["reviewerName"].unique()
# print(len(reviewers_uniq))

# reviewers_ohe = OneHotEncoder(handle_unknown="ignore", sparse_output=False).fit_transform(reviewers.to_numpy().reshape(-1, 1))
# print(reviewers_ohe.shape, type(reviewers_ohe))

# reviewers_2 = merged["reviewerName"].copy()
# reviewers_2 = pd.DataFrame(reviewers_2)
# print(reviewers_2.head())
# reviewers_2 = reviewers_2.replace({"Mr. ": "", "Mrs. ": ""}, regex=True)
# reviewers_2["reviewerName"] = reviewers_2["reviewerName"].apply(name_fl)
# reviewers_2 = reviewers_2.squeeze()
# print(reviewers_2.shape)
# print(reviewers_2.head())

# reviewers_tfidf = TfidfVectorizer(ngram_range=(2,2)).fit_transform(reviewers_2).toarray()
# print(reviewers_tfidf.shape, type(reviewers_tfidf))

# print(np.array_equal(reviewers_ohe, reviewers_tfidf))

# %%
# def name_fl(name):
#     l = name.split()
#     n = ' '.join((l[0], l[-1]))
#     return n

# %%
# print(reviewers.head())
# r = pd.DataFrame(reviewers.copy())
# r["reviewerName"] = r["reviewerName"].apply(name_fl)
# r["name_len"] = r["reviewerName"].apply(lambda x: len(x.split()))
# print(r.shape)
# print(r.head())
# print(r['name_len'].value_counts())

# %%
## Box plot audienceScore and sentiment  
# plt.figure(figsize=(6, 4))
# sns.boxplot(x="sentiment", y="audienceScore", data=merged, width=0.3)
# plt.title("Box plot audienceScore and sentiment")
# plt.show()

# %%
## Box plot runtimeMinutes and sentiment  
# plt.figure(figsize=(6, 4))
# sns.boxplot(x="sentiment", y="runtimeMinutes", data=merged, width=0.3)
# plt.title("Box plot runtimeMinutes and sentiment")
# plt.show()

# %%
## Column chart for sentiment and rating columns
# plt.figure(figsize=(6, 4))
# sns.countplot(x="sentiment", hue="rating", data=merged)
# plt.title("Column chart for sentiment and rating columns")
# plt.show()

# %%
# Correlation heatmap  
# plt.figure(figsize=(10, 8))
# sns.heatmap(merged.corr(), annot=True, cmap="coolwarm")
# plt.title("Correlation heatmap")
# plt.show()

# %% [markdown]
# ### Separate features and labels from merged dataset

# %%
merged_train_features = merged[['movieid', 'reviewerName', 'isFrequentReviewer', 'reviewText',
       'audienceScore', 'rating', 'runtimeMinutes', 'genre',
       'originalLanguage', 'director']]
merged_train_features.shape
# Out:
# (162758, 10)

# %%
merged_train_labels = merged["sentiment"]
merged_train_labels.shape
# Out:
# (162758,)

# %% [markdown]
# ### Identify variable types for different preprocessing pipes

# %%
num_vars = ["audienceScore", "runtimeMinutes"]
txt_vars = ["originalLanguage", "genre", "director", "reviewerName", "reviewText"]
cat_vars = ["rating", "isFrequentReviewer"]

# %%
num_pipe = Pipeline(steps=[
                            ("imputer", SimpleImputer(strategy="mean", missing_values=np.nan)),
                            ("scaler", MinMaxScaler())
                        ])
num_pipe
# Out:
# Pipeline(steps=[('imputer', SimpleImputer()), ('scaler', MinMaxScaler())])

# %%
txt_pipe = Pipeline(steps=[
                            ("tvec", TfidfVectorizer())
                        ])
txt_pipe
# Out:
# Pipeline(steps=[('tvec', TfidfVectorizer())])

# %%
cat_pipe = Pipeline(steps=[
                            ("ohe", OneHotEncoder(handle_unknown="ignore"))
                        ])
cat_pipe
# Out:
# Pipeline(steps=[('ohe', OneHotEncoder(handle_unknown='ignore'))])

# %%
tfidf_vec_1 = TfidfVectorizer(ngram_range=(1,2))
tfidf_vec_1
# Out:
# TfidfVectorizer(ngram_range=(1, 2))

# %%
ct_final = ColumnTransformer(transformers=[
                                        ("num", num_pipe, num_vars),
                                        ("txt1", txt_pipe, "originalLanguage"),
                                        ("txt2", txt_pipe, "genre"),
                                        ("txt3", txt_pipe, "director"),
                                        ("cat", cat_pipe, cat_vars),
                                        ("txt4a", tfidf_vec_1, "reviewText")
#                                         ("txt4", TfidfVectorizer(ngram_range=(1,2)), "reviewText"),
#                                         ("cat2", cat_pipe, ["isFrequentReviewer"])
                                        ], remainder="drop", n_jobs=1)

# Note that this transformer drops "movieid" column and "reviewerName" column  
ct_final
# Out:
# ColumnTransformer(n_jobs=1,
#                   transformers=[('num',
#                                  Pipeline(steps=[('imputer', SimpleImputer()),
#                                                  ('scaler', MinMaxScaler())]),
#                                  ['audienceScore', 'runtimeMinutes']),
#                                 ('txt1',
#                                  Pipeline(steps=[('tvec', TfidfVectorizer())]),
#                                  'originalLanguage'),
#                                 ('txt2',
#                                  Pipeline(steps=[('tvec', TfidfVectorizer())]),
#                                  'genre'),
#                                 ('txt3',
#                                  Pipeline(steps=[('tvec', TfidfVectorizer())]),
#                                  'director'),
#                                 ('cat',
#                                  Pipeline(steps=[('ohe',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  ['rating', 'isFrequentReviewer']),
#                                 ('txt4a', TfidfVectorizer(ngram_range=(1, 2)),
#                                  'reviewText')])

# %%
pipe_final = Pipeline(steps=[
                        ("preprocessor", ct_final),
                        ("model", LogisticRegression(max_iter=100000))
                    ])
pipe_final
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(n_jobs=1,
#                                    transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    MinMaxScaler())]),
#                                                   ['audienceScore',
#                                                    'runtimeMinutes']),
#                                                  ('txt1',
#                                                   Pipeline(steps=[('tvec',
#                                                                    TfidfVectorizer())]),
#                                                   'originalLanguage'),
#                                                  ('txt2',
#                                                   Pipeline(steps=[('tvec',
#                                                                    TfidfVectorizer())]),
#                                                   'genre'),
#                                                  ('txt3',
#                                                   Pipeline(steps=[('tvec',
#                                                                    TfidfVectorizer())]),
#                                                   'director'),
#                                                  ('cat',
#                                                   Pipeline(steps=[('ohe',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['rating',
#                                                    'isFrequentReviewer']),
#                                                  ('txt4a',
#                                                   TfidfVectorizer(ngram_range=(1,
#                                                                                2)),
#                                                   'reviewText')])),
#                 ('model', LogisticRegression(max_iter=100000))])

# %%
final_vars = num_vars + txt_vars + cat_vars
len(final_vars), final_vars
# Out:
# (9,
#  ['audienceScore',
#   'runtimeMinutes',
#   'originalLanguage',
#   'genre',
#   'director',
#   'reviewerName',
#   'reviewText',
#   'rating',
#   'isFrequentReviewer'])

# %%
# split_train_predict(merged_train_features, merged_train_labels, pipe_final, test_size=0.25, random_state=42)

# %% [markdown]
# ### Merge and preprocess "test.csv" and "movies.csv" files

# %%
merged_test = select_features(load_csv("test"), load_csv("movies"))
inspect(merged_test)
# Out:
# Shape of the dataframe: (55315, 13)
#
# Columns in the dataframe:
# Index(['movieid', 'reviewerName', 'isFrequentReviewer', 'reviewText',
#        'audienceScore', 'rating', 'runtimeMinutes', 'genre',
#        'originalLanguage', 'director', 'boxOffice', 'reviewYN', 'reviewWC'],
#       dtype='object')
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 55315 entries, 0 to 55314
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   movieid             55315 non-null  object
#  1   reviewerName        55315 non-null  object
#  2   isFrequentReviewer  55315 non-null  bool
#  3   reviewText          55315 non-null  object
#  4   audienceScore       55315 non-null  float64
#  5   rating              55315 non-null  object
#  6   runtimeMinutes      55315 non-null  float64
#  7   genre               55315 non-null  object
#  8   originalLanguage    55315 non-null  object
#  9   director            55315 non-null  object
#  10  boxOffice           55315 non-null  float64
#  11  reviewYN            55315 non-null  int32
#  12  reviewWC            55315 non-null  int64
# dtypes: bool(1), float64(3), int32(1), int64(1), object(7)
# memory usage: 5.3+ MB
# None
#
# Missing values:
# movieid               0
# reviewerName          0
# isFrequentReviewer    0
# reviewText            0
# audienceScore         0
# rating                0
# runtimeMinutes        0
# genre                 0
# originalLanguage      0
# director              0
# boxOffice             0
# reviewYN              0
# reviewWC              0
# dtype: int64

# %%
print(merged_test["reviewYN"].sum())
print(merged_test["reviewYN"].sum() * 100 / merged_test.shape[0])
# Out:
# 2510
# 4.537648015908886

# %%
merged_test['rating'].value_counts()
# Out:
# R          18934
# Unknown    18386
# PG-13      13220
# PG          4200
# TV14         333
# TVPG         109
# NC-17        108
# TVMA          25
# Name: rating, dtype: int64

# %%
merged_test['isFrequentReviewer'].value_counts()
# Out:
# False    38428
# True     16887
# Name: isFrequentReviewer, dtype: int64

# %%
merged_test['boxOffice'].value_counts()
# Out:
# 12200000.0    22550
# 1100000.0       311
# 1000000.0       272
# 1300000.0       263
# 2000000.0       256
#               ...
# 117100.0          1
# 174500.0          1
# 216200.0          1
# 279600.0          1
# 100600.0          1
# Name: boxOffice, Length: 3024, dtype: int64

# %% [markdown]
# ## Try the best four features obtained on local machine

# %%
tfidf_vec_2 = TfidfVectorizer(ngram_range=(1,2))
tfidf_vec_2
# Out:
# TfidfVectorizer(ngram_range=(1, 2))

# %%
ct_best4 = ColumnTransformer(transformers=[
                                            ("num", num_pipe, ["audienceScore"]),
                                            ("cat", cat_pipe, ["rating", "isFrequentReviewer"]),
                                            ("tvec", tfidf_vec_2, "reviewText")
                            ])

pipe_best4 = Pipeline(steps=[
    ("preprocessor", ct_best4),
    ("model", LogisticRegression())
])

pipe_best4.set_params(model__C=10, model__max_iter=100000)

pipe_best4
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    MinMaxScaler())]),
#                                                   ['audienceScore']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('ohe',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['rating',
#                                                    'isFrequentReviewer']),
#                                                  ('tvec',
#                                                   TfidfVectorizer(ngram_range=(1,
#                                                                                2)),
#                                                   'reviewText')])),
#                 ('model', LogisticRegression(C=10, max_iter=100000))])

# %%
# split_train_predict(merged[["audienceScore", "rating", "isFrequentReviewer", "reviewText"]], merged["sentiment"], pipe_best4, test_size=0.25)

# %% [markdown]
# ## Try only 'reviewText' column

# %%
tfidf_vec_3 = TfidfVectorizer(ngram_range=(1,2))
tfidf_vec_3
# Out:
# TfidfVectorizer(ngram_range=(1, 2))

# %%
ct_RTonly = ColumnTransformer(transformers=[
                                            ('txt', tfidf_vec_3, 'reviewText'),
                                            ], remainder='drop')
ct_RTonly
# Out:
# ColumnTransformer(transformers=[('txt', TfidfVectorizer(ngram_range=(1, 2)),
#                                  'reviewText')])

# %%
pipe_RTonly = Pipeline(steps=[
    ("preprocessor", ct_RTonly),
    ("model", LogisticRegression())
])

pipe_RTonly.set_params(model__C=10, model__max_iter=100000)

pipe_RTonly
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('txt',
#                                                   TfidfVectorizer(ngram_range=(1,
#                                                                                2)),
#                                                   'reviewText')])),
#                 ('model', LogisticRegression(C=10, max_iter=100000))])

# %% [markdown]
# ## Submit_v4 for merged file models

# %%
# Testing predictions on missing reviewtext columns  

def predict_on_missing_review_data(pipe, selected_features, merged_train):
    missing_reviews_train = merged_train.loc[merged_train['reviewYN'] == 1]
    missing_reviews_train.reset_index(drop=True)
    X_train_miss_revs = missing_reviews_train.drop('sentiment', axis = 1)
    X_train_miss_revs = X_train_miss_revs[selected_features]
    y_train_miss_revs = missing_reviews_train['sentiment']
    
    y_pred_miss_revs = pipe.predict(X_train_miss_revs)
    print('Predictions on rows which had missing reviewText')
    print(confusion_matrix(y_train_miss_revs, y_pred_miss_revs))
    return f1_score(y_train_miss_revs, y_pred_miss_revs, average='micro')

# %%
def build_pipeline(selected_model=LogisticRegression(), 
                   selected_features={'txt': ['reviewText']}, 
                   param_grid=None,
                   vocab=None):
    # Encoders  
    ohe = OneHotEncoder(sparse=False, handle_unknown='ignore')
    scaler = MinMaxScaler()
    
    # Text features ['reviewText', 'reviewerName', 'movieid', 'genre', 'director']
    tfidf_vec = TfidfVectorizer(ngram_range=(1,2))
    txt_pipe = Pipeline(steps=[
                            ("tvec", TfidfVectorizer(ngram_range=(1,2)))
                        ])
    txt_pipe_2 = Pipeline(steps=[
                            ("tvec", TfidfVectorizer(ngram_range=(2,2)))
                        ])
    txt_pipe_3 = Pipeline(steps=[
                            ("tvec", TfidfVectorizer(ngram_range=(1,1)))
                        ])
    # Basic pipes  
    TFs = []
    try:
        for c in selected_features['cat']:
            TFs.append((f"cat_{c}", ohe, [c]))
    except:
        pass
    try:
        for n in selected_features['num']:
            TFs.append((f"num_{n}", scaler, [n]))
    except:
        pass
    try:
        for t in selected_features['txt']:
            if t in ['director', 'reviewerName']:
                TFs.append((f"txt_{t}", txt_pipe_2, t))
            elif t in ['movieid', 'genre']:
                TFs.append((f"txt_{t}", txt_pipe_3, t))
            else:
                if vocab:
                    txt_pipe.set_params(tvec__vocabulary=vocab)
                    txt_pipe.set_params(tvec__stop_words='english')
                TFs.append((f"txt_{t}", txt_pipe, t))
    except:
        pass

    # Build ColumnTransformer  
    ct = ColumnTransformer(transformers=TFs, remainder='drop')

    # Build Pipeline
    pipe = Pipeline(steps=[('ct', ct), ('model', selected_model)])
    
    # GridSearchCV if param_grid provided
    if param_grid:
        pipeCV = GridSearchCV(pipe, param_grid, cv=5, scoring="f1_micro", n_jobs=-1)
        return pipeCV
    
    return pipe

# %%
def submit_v4(selected_model=LogisticRegression(C=10, max_iter=100000), 
              selected_features={'txt': ['reviewText']}, 
              param_grid=None,
              vocab=None):

    # Build Pipeline
    pipe = build_pipeline(selected_model, selected_features, param_grid=param_grid, vocab=vocab)
    print(pipe)

    # Features list
    features = []
    for item in selected_features.values():
        features.extend(item)

    # Retrain on the whole train.csv file  
    merged = select_features(load_csv("train"), load_csv("movies"))
    X_train = merged.drop(labels="sentiment", axis=1)
    y_train = merged["sentiment"]

    X_train = X_train[features]
    
    # Check1
    print(X_train.shape)
    print(X_train.head())
    
    if not param_grid:
        try:
            print(pipe.named_steps['model'].intercept_, pipe.named_steps['model'].coef_)
        except:
            print("Model not trained yet!")
    
    # Fit 
    pipe.fit(X_train, y_train)
    
    # Check2
    if not param_grid:
        print(pipe.named_steps['model'].intercept_, pipe.named_steps['model'].coef_)
        print(pipe.score(X_train, y_train))
    else:
        print(pipe.best_params_)
        print(pipe.best_score_)
    print(predict_on_missing_review_data(pipe, features, merged))    # Function defined above
    
        
        
    # Predict on test.csv file
    merged_test = select_features(load_csv("test"), load_csv("movies"))
    X_test = merged_test.copy()

    X_test = X_test[features]
    
    # Check3
    print(X_test.shape)
    print(X_test.head())
    
    y_pred = pipe.predict(X_test)
    
    # Check4
    if not param_grid:
        print(pipe.named_steps['model'].intercept_, pipe.named_steps['model'].coef_)
        print(pipe.score(X_train, y_train))
    else:
        print(pipe.best_params_)
        print(pipe.best_score_)

    
    pred_df = pd.DataFrame(y_pred)
    pred_df.columns = ["sentiment"]
    pred_df.index.name = "id"
    pred_df.to_csv("submission.csv")
    
    return "Successfully created the submission file!!!"

# %%
# submit_v4()

#Default params to this function gave a score of 0.8259 - improvement over previous score of 0.82563!

# %%
# Try out GridSearchCV
# param_grid = {
#     "model__C": [0.1, 1, 5, 10]
# }

# submit_v4(selected_features={'txt': ['genre']}, param_grid=param_grid)

# %% [markdown]
# ## Try the best 4 parameters with submit_v4 function

# %%
# best4 = ["audienceScore", "rating", "isFrequentReviewer", "reviewText"]
best4_dict = {'cat': ["rating", "isFrequentReviewer"],
             'num': ["audienceScore"],
             'txt': ['reviewText']}
best4_dict
# Out:
# {'cat': ['rating', 'isFrequentReviewer'],
#  'num': ['audienceScore'],
#  'txt': ['reviewText']}

# %%
# submit_v4(selected_features=best4_dict)

# %% [markdown]
# ## Try the best 3 parameters with submit_v4 function

# %%
# best3 = ["audienceScore", "isFrequentReviewer", "reviewText"]
best3_dict = {'cat': ["isFrequentReviewer"],
             'num': ["audienceScore"],
             'txt': ['reviewText']}
best3_dict
# Out:
# {'cat': ['isFrequentReviewer'],
#  'num': ['audienceScore'],
#  'txt': ['reviewText']}

# %%
# submit_v4(selected_features=best3_dict)

# %% [markdown]
# ## Try throwing almost everything (no boxOffice) at submit_v4!

# %%
"""Most from merged = ['movieid', 'reviewerName', 'isFrequentReviewer', 'reviewText',
       'audienceScore', 'rating', 'runtimeMinutes', 'genre', 
       'originalLanguage', 'director']"""

almost_dict = {'cat': ["isFrequentReviewer", "rating", "originalLanguage"],
             'num': ["audienceScore", "runtimeMinutes"],
             'txt': ['reviewText', 'reviewerName', 'movieid', 'genre', 'director']}
almost_dict
# Out:
# {'cat': ['isFrequentReviewer', 'rating', 'originalLanguage'],
#  'num': ['audienceScore', 'runtimeMinutes'],
#  'txt': ['reviewText', 'reviewerName', 'movieid', 'genre', 'director']}

# %%
# submit_v4(selected_features=almost_dict)

# %% [markdown]
# ## Try throwing everything possible at submit_v4!

# %%
"""All from merged = ['movieid', 'reviewerName', 'isFrequentReviewer', 'reviewText',
       'audienceScore', 'rating', 'runtimeMinutes', 'genre', 'boxOffice',
       'originalLanguage', 'director']"""

all_dict = {'cat': ["isFrequentReviewer", "rating", "originalLanguage"],
             'num': ["audienceScore", "runtimeMinutes", "boxOffice"],
             'txt': ['reviewText', 'reviewerName', 'movieid', 'genre', 'director']}
all_dict
# Out:
# {'cat': ['isFrequentReviewer', 'rating', 'originalLanguage'],
#  'num': ['audienceScore', 'runtimeMinutes', 'boxOffice'],
#  'txt': ['reviewText', 'reviewerName', 'movieid', 'genre', 'director']}

# %%
# submit_v4(selected_features=all_dict)

# %% [markdown]
# ## Try GridSearchCV on everything

# %%
# param_grid = {
#     "model__C": [0.5, 2, 5, 15]
# }

# param_grid = {
#     'model__C' : [1, 5],
#     'model__solver': ['lbfgs', 'liblinear', 'newton-cg', 'newton-cholesky', 'sag', 'saga']
# }

# param_grid = {
#     'model__C' : [1, 5],
#     'model__solver': ['lbfgs', 'liblinear', 'sag', 'saga']
# }

param_grid = {
    'model__C' : [1, 5, 10],
    'model__solver': ['lbfgs', 'liblinear', 'saga']
}

param_grid
# Out:
# {'model__C': [1, 5, 10], 'model__solver': ['lbfgs', 'liblinear', 'saga']}

# %%
# submit_v4(selected_features={'txt': ["genre"]}, param_grid=param_grid)

# %%
# submit_v4(selected_features=all_dict, param_grid=param_grid)

# Best C was 5
# Best solver was liblinear

"""Used 'groupby' function instead on 'drop_duplicates' on movies.csv file. 
It reduced the number of missing values significantly! 
Then used LogisticRegression() with GridSearchCV on submit_v4 function with 
param_grid={'model__C': [1, 5, 10], 'model__solver': ['lbfgs', 'liblinear', 'saga']}. 
The best f1_micro score in GridSearchCV was 0.8399771362056203 which is highest among 
all the versions so far. Best C was 5 and best solver was 'saga'.
Score obtained was 0.84385 which is lower than 0.84441."""
# Out:
# "Used 'groupby' function instead on 'drop_duplicates' on movies.csv file. \nIt reduced the number of missing values significantly! \nThen used LogisticRegression() with GridSearchCV on submit_v4 function with \nparam_grid={'model__C': [1, 5, 10], 'model__solver': ['lbfgs', 'liblinear', 'saga']}. \nThe best f1_micro score in GridSearchCV was 0.8399771362056203 which is highest among \nall the versions so far. Best C was 5 and best solver was 'saga'.\nScore obtained was 0.84385 which is lower than 0.84441."

# %% [markdown]
# ## Try a new feature dict

# %%
all_dict_new = {'cat': ["isFrequentReviewer", "rating", "originalLanguage"],
             'num': ["audienceScore", "runtimeMinutes", "boxOffice"],
             'txt': ['reviewText', "reviewerName", 'movieid', 'genre', 'director']}
all_dict_new
# Out:
# {'cat': ['isFrequentReviewer', 'rating', 'originalLanguage'],
#  'num': ['audienceScore', 'runtimeMinutes', 'boxOffice'],
#  'txt': ['reviewText', 'reviewerName', 'movieid', 'genre', 'director']}

# %%
# submit_v4(selected_features={'txt': ['genre']}, param_grid=param_grid)

# %%
# submit_v4(selected_features=all_dict_new, param_grid=param_grid)

# %%
# Try non-text based columns
num_cat_dict = {'cat': ['isFrequentReviewer', 'rating', 'originalLanguage'],
 'num': ['audienceScore', 'runtimeMinutes', 'boxOffice']}
num_cat_dict
# Out:
# {'cat': ['isFrequentReviewer', 'rating', 'originalLanguage'],
#  'num': ['audienceScore', 'runtimeMinutes', 'boxOffice']}

# %%
# Use num_cat_dict features
# (Update): Gets a local score of 0.7027181356991726. Not great.
# submit_v4(selected_model=LogisticRegression(max_iter=100000), selected_features=num_cat_dict, param_grid=param_grid)

# %%
# Try data other than reviewText

mov_dict = {'cat': ['rating', 'originalLanguage'],
 'num': ['audienceScore', 'runtimeMinutes', 'boxOffice'],
 'txt': ['movieid', 'genre', 'director']}
mov_dict
# Out:
# {'cat': ['rating', 'originalLanguage'],
#  'num': ['audienceScore', 'runtimeMinutes', 'boxOffice'],
#  'txt': ['movieid', 'genre', 'director']}

# %%
# Use mov_dict features
# (Update): Gets a local score of 0.7475454316469369, which is not bad at all.
# submit_v4(selected_model=LogisticRegression(max_iter=100000), selected_features=mov_dict, param_grid=param_grid)

# %% [markdown]
# # Try a new column 'reviewYN'

# %%
all_dict_3 = {'cat': ["isFrequentReviewer", "rating", "originalLanguage", "reviewYN"],
             'num': ["audienceScore", "runtimeMinutes", "boxOffice"],
             'txt': ['reviewText', "reviewerName", 'movieid', 'genre', 'director']}
all_dict_3
# Out:
# {'cat': ['isFrequentReviewer', 'rating', 'originalLanguage', 'reviewYN'],
#  'num': ['audienceScore', 'runtimeMinutes', 'boxOffice'],
#  'txt': ['reviewText', 'reviewerName', 'movieid', 'genre', 'director']}

# %%
# submit_v4(selected_model=LogisticRegression(max_iter=100000),
#          selected_features=all_dict_3, 
#           param_grid=param_grid)

# %% [markdown]
# ## Try LinearSVC with GridSearchCV

# %%
param_grid_svc = {
    "model__C": [0.1, 1, 10, 100]
}
param_grid_svc
# Out:
# {'model__C': [0.1, 1, 10, 100]}

# %%
# submit_v4(selected_model=LinearSVC(max_iter=100000, random_state=42), selected_features={'num': ["audienceScore"]}, param_grid=param_grid_svc)

# Comment: LinearSVC even on single column feature set takes too long to converge.

# %%
# Throw everything at LinearSVC and hope for it to complete!
# (Update): This took 66 mins to run and gave a public score of 0.84295 (lesser than logreg gridsearchcv wwhich gave 0.84441). Best C was 1.0.

# submit_v4(selected_model=LinearSVC(max_iter=100000, random_state=42), selected_features=all_dict, param_grid=param_grid_svc)

# %%
param_grid_svc_2 = {
    'model__C': [1.0],
    'model__loss': ['hinge', 'squared_hinge'],
    'model__class_weight': ['balanced', None]
}
param_grid_svc_2
# Out:
# {'model__C': [1.0],
#  'model__loss': ['hinge', 'squared_hinge'],
#  'model__class_weight': ['balanced', None]}

# %%
# submit_v4(selected_model=LinearSVC(max_iter=100000, random_state=42), selected_features={'num': ["audienceScore"]}, param_grid=param_grid_svc_2)

# %%
# submit_v4(selected_model=LinearSVC(max_iter=100000, random_state=42), selected_features=all_dict, param_grid=param_grid_svc_2)

# %% [markdown]
# ## Try Boosting techniques

# %%
# adc = AdaBoostClassifier(estimator=LogisticRegression(C=5, solver="saga", max_iter=100000), n_estimators=50)
# adc

# %%
# submit_v4(selected_model=adc, selected_features={'num': ["audienceScore"]}, param_grid=None)

# %%
# submit_v4(selected_model=adc, selected_features=all_dict, param_grid=None)

# Took 1 hour 15 mins to run and gave a public score of only 0.71089. Discarded.

# %% [markdown]
# ## Try LightGBM

# %%
# lgb = ltb.LGBMClassifier()
# lgb

# %%
# Try LightGBM with default settings
# (Update): Public score only 0.77713. It was fast, took less than 5 mins (without GridSearchCV)

# submit_v4(selected_model=ltb.LGBMClassifier(), selected_features=all_dict, param_grid=None)

# %% [markdown]
# # Try feature selection and vocab fine tuning of reviewText column

# %% [markdown]
# ## Plan
# * Add aa new column 'reviewWC' which has word count of 'reviewText'
#     * Check if there is any relationship between 'reviewWC' and 'sentiment'
# * Work on vocabulary
#      * Use TfidfVectorizer and find out the vocabulary of 'reviewText' column for various ngrams
#      * Use RecursiveFeatureElimination (RFE) or RFECV to select 1000 top words/vocab for each ngram
#      * Use the final vocab (1000-3000 words) in the model and see how it performs compared to whole vocab

# %%
# 'reviewWC' and 'sentiment'
# (Conclusion): 'reviewWC' is practically same as DummyClassifier (accuracy of 0.6682375059904889 on train data). It just predicts 'positive' for all columns

# reviewWC_dict = {"num": ["reviewWC"]}
# submit_v4(selected_model=LogisticRegression(),
#          selected_features=reviewWC_dict,
#          param_grid=None)

# %%
# 'reviewYN' and 'sentiment'
# (Conclusion): 'reviewYN' is practically same as DummyClassifier (accuracy of 0.6682375059904889 on train data). It just predicts 'positive' for all columns

# reviewYN_dict = {"cat": ["reviewYN"]}
# submit_v4(selected_model=LogisticRegression(),
#          selected_features=reviewYN_dict,
#          param_grid=None)

# %%
print("Let's start")
# Out:
# Let's start

# %% [markdown]
# ## Work on vocabulary

# %%
rt_senti = merged[["reviewText", "sentiment"]].copy()
rt_senti.shape, rt_senti.head()
# Out:
# ((162758, 2),
#                                            reviewText sentiment
#  0  Henry Selick’s first movie since 2009’s Corali...  POSITIVE
#  1  With a cast that reads like the Vogue Oscar pa...  NEGATIVE
#  2  Creed II does not give us anything but another...  POSITIVE
#  3  I know what you're thinking, but this is no Li...  POSITIVE
#  4  Director Fernando Meirelles tells the story wi...  POSITIVE)

# %%
def get_vocab(text_df, ngram_range=(1,1)):
    print(f"Generating vocabulary for ngram_range: {ngram_range}...")
    tvec1 = TfidfVectorizer(ngram_range=ngram_range, stop_words='english')
    tvec1.fit(text_df)
    voc_ngram = list(tvec1.vocabulary_.keys())
    return voc_ngram

# %%
voc_1gram = get_vocab(rt_senti["reviewText"], ngram_range=(1,1))
len(voc_1gram), voc_1gram[:10]
# Out:
# Generating vocabulary for ngram_range: (1, 1)...
# (64912,
#  ['henry',
#   'selick',
#   'movie',
#   '2009',
#   'coraline',
#   'fifth',
#   'stop',
#   'motion',
#   'masterpiece',
#   'cast'])

# %%
voc_2gram = get_vocab(rt_senti["reviewText"], ngram_range=(2,2))
len(voc_2gram), voc_2gram[:10]
# Out:
# Generating vocabulary for ngram_range: (2, 2)...
# (1146211,
#  ['henry selick',
#   'selick movie',
#   'movie 2009',
#   '2009 coraline',
#   'coraline fifth',
#   'fifth stop',
#   'stop motion',
#   'motion masterpiece',
#   'cast reads',
#   'reads like'])

# %%
voc_3gram = get_vocab(rt_senti["reviewText"], ngram_range=(3,3))
len(voc_3gram), voc_3gram[:10]
# Out:
# Generating vocabulary for ngram_range: (3, 3)...
# (1443939,
#  ['henry selick movie',
#   'selick movie 2009',
#   'movie 2009 coraline',
#   '2009 coraline fifth',
#   'coraline fifth stop',
#   'fifth stop motion',
#   'stop motion masterpiece',
#   'cast reads like',
#   'reads like vogue',
#   'like vogue oscar'])

# %% [markdown]
# ### Check common words between reviewText in train and test datasets

# %%
rt_test = merged_test["reviewText"].copy()
rt_test.shape, rt_test.head()
# Out:
# ((55315,),
#  0    Green slowly cranks up the dread with style an...
#  1    Philip Noyce's direction is elegant and unforc...
#  2    It wouldn't do to say what path Maria ultimate...
#  3    Pig is not exactly the arthouse John Wick that...
#  4    An imaginative no-budget musical of sorts abou...
#  Name: reviewText, dtype: object)

# %% [markdown]
# `Common unigrams`

# %%
voc_1gram_test = get_vocab(rt_test, ngram_range=(1,1))
len(voc_1gram_test), voc_1gram_test[:10]
# Out:
# Generating vocabulary for ngram_range: (1, 1)...
# (43588,
#  ['green',
#   'slowly',
#   'cranks',
#   'dread',
#   'style',
#   'occasional',
#   'shards',
#   'wit',
#   'psychological',
#   'thriller'])

# %%
common_unigrams = set(voc_1gram) & set(voc_1gram_test)
len(common_unigrams), common_unigrams
# Out:
# (35946,
#  {'heists',
#   'cans',
#   'meticulousness',
#   'unreliability',
#   'breakfast',
#   'zucchini',
#   'lavished',
#   'tideland',
#   'wandering',
#   'biker',
#   'dims',
#   'rushmore',
#   'unsteadily',
#   'marches',
#   'prodigious',
#   'fastest',
#   'hyperspace',
#   'homeboys',
#   'blind',
#   'flossing',
#   'prude',
#   'cotton',
#   'sampling',
#   'ryoo',
#   'piquing',
#   'chevalier',
#   'idiocy',
#   'inch',
#   'carrie',
#   'gravelly',
#   'backroom',
#   'brinton',
#   'greys',
#   'effect',
#   'wilde',
#   'unmoved',
#   'whisker',
#   'pains',
#   'intouchables',
#   'yucks',
#   'lelouch',
#   'merced',
#   'francis',
#   'fixed',
#   'trapped',
#   'dealin',
#   'partisan',
#   'order',
#   'theological',
#   'flabby',
#   'leni',
#   'rubbery',
#   'dramaturgy',
#   'recommendable',
#   'expiration',
#   'faultless',
#   'adhd',
#   'doubt',
#   'coins',
#   'foamy',
#   'navigate',
#   'greatest',
#   'dicey',
#   'nose',
#   'eloquently',
#   'invocation',
#   'beery',
#   'gratifying',
#   'intermittent',
#   'proximity',
#   'bloodline',
#   'ages',
#   'artistic',
#   'waterlogged',
#   'pokes',
#   'brüno',
#   'encompass',
#   'ray',
#   'interstellar',
#   'bande',
#   'mortals',
#   'dress',
#   'yawns',
#   'proselytizing',
#   'dart',
#   'cahill',
#   'tut',
#   'hackles',
#   'unheard',
#   'morosini',
#   'reflective',
#   'mountainous',
#   'throughline',
#   'lamentation',
#   'essence',
#   'flimflam',
#   'pike',
#   'rinse',
#   'tantrum',
#   'weaves',
#   'propose',
#   'grained',
#   'chipper',
#   'lazzaro',
#   'jang',
#   'pfeiffer',
#   'oakley',
#   'steadman',
#   'muddier',
#   'shredding',
#   'goldmine',
#   'sustainable',
#   'peña',
#   '3d',
#   'photographs',
#   'vasyanovych',
#   'marriages',
#   'klezmer',
#   'moll',
#   'engineer',
#   'canaries',
#   'whitesell',
#   'coherently',
#   'epps',
#   'honnold',
#   'madwoman',
#   'empathetic',
#   '22nd',
#   'peeks',
#   'flood',
#   'malcolm',
#   'nayfeh',
#   'curran',
#   'neveldine',
#   'rave',
#   'favor',
#   'amanda',
#   'likened',
#   'caveats',
#   'bernstein',
#   'dave',
#   'oblique',
#   'beasties',
#   'kusama',
#   'blows',
#   'eisner',
#   'smorgasbord',
#   'mutes',
#   'contexts',
#   'timi',
#   'berri',
#   'hued',
#   'cinders',
#   'effectiveness',
#   'rooster',
#   'hotness',
#   'levan',
#   'bolero',
#   'corneliu',
#   'italicized',
#   'trippiness',
#   'ransom',
#   'unpersuasive',
#   'vicarious',
#   'geeked',
#   'reflect',
#   'yemen',
#   'online',
#   'gravitate',
#   'halfhearted',
#   'lobes',
#   'capone',
#   'brock',
#   'soothe',
#   'cnn',
#   'obama',
#   'virgins',
#   'hype',
#   'caravaggio',
#   'bumpy',
#   'sigurðsson',
#   'underplayed',
#   'ghibli',
#   'kole',
#   'ruse',
#   'aubrey',
#   'smidgen',
#   'defective',
#   '53',
#   'furthers',
#   'braveheart',
#   'moulded',
#   'sherwood',
#   'panahi',
#   'sensibly',
#   'disposition',
#   'docu',
#   'sugarcoat',
#   'paddling',
#   'timekiller',
#   'sharper',
#   'dramatist',
#   'teplitzky',
#   'hopkins',
#   'narcisse',
#   'binaries',
#   'irrevocably',
#   'ruins',
#   'salaciousness',
#   'ones',
#   'discovers',
#   'holden',
#   'tie',
#   'havoc',
#   'hides',
#   'imagine',
#   'hitch',
#   'dips',
#   'ebullience',
#   'risqué',
#   'serial',
#   'accordingly',
#   'saoirse',
#   'terrorized',
#   'yawning',
#   'nonstop',
#   'paralleled',
#   'clooney',
#   'bechdel',
#   'ceiling',
#   'recollections',
#   'weaker',
#   'obligation',
#   'bulb',
#   'debris',
#   'robs',
#   'trot',
#   'opposites',
#   'reprising',
#   'atrocious',
#   'tucks',
#   'bends',
#   'eroded',
#   'dimensions',
#   'van',
#   'millennials',
#   'wilford',
#   'wishful',
#   'grow',
#   'fatherly',
#   'hawkins',
#   'confluence',
#   'mired',
#   'parked',
#   'plot',
#   'persuades',
#   'spattered',
#   'bjork',
#   'surreal',
#   'bequeathed',
#   'strict',
#   'verheyde',
#   'nos',
#   'yoof',
#   'forma',
#   'costumes',
#   'mount',
#   'polka',
#   'sustaining',
#   'weakly',
#   'deserve',
#   'anxious',
#   'obfuscate',
#   'shoehorns',
#   'jarnatt',
#   'aerial',
#   'warburton',
#   'confoundingly',
#   'swan',
#   'conceits',
#   'duvernay',
#   'questioned',
#   'trap',
#   'assumedly',
#   'amelia',
#   'poise',
#   'maggoty',
#   'strengthen',
#   'vanishes',
#   'enable',
#   'sponge',
#   'spierig',
#   'climes',
#   'akimbo',
#   'hughley',
#   'rubik',
#   'symphonies',
#   'huppert',
#   'knotted',
#   'tearjerker',
#   'barbaric',
#   'vibes',
#   'valentine',
#   'mistake',
#   'thompson',
#   'uproarious',
#   'bleed',
#   'orbits',
#   'scarifying',
#   'lovelier',
#   'brown',
#   'janney',
#   'lobbed',
#   'slogan',
#   'listlessness',
#   'abc',
#   'wall',
#   'smiling',
#   'frontier',
#   'riviera',
#   'hrithik',
#   'follies',
#   'shireen',
#   'plight',
#   'corazón',
#   'marcos',
#   'weixler',
#   'swallows',
#   'despising',
#   'reconciles',
#   'bowled',
#   'ramp',
#   'disgruntled',
#   'schlocky',
#   'stockings',
#   'skillful',
#   'yokohama',
#   'contributing',
#   'rickety',
#   'parade',
#   'losses',
#   'wittiest',
#   'interrupting',
#   'sparkler',
#   'grandma',
#   'comprova',
#   'vaguely',
#   'pole',
#   'bend',
#   'itis',
#   'starlet',
#   'addition',
#   'coasts',
#   'avert',
#   'lazenby',
#   'tambm',
#   'inseparable',
#   'jesmark',
#   'ferrer',
#   'bordering',
#   'fragments',
#   'emits',
#   'scatters',
#   'nordic',
#   'flat',
#   'pointedly',
#   'architects',
#   'membership',
#   'overrated',
#   'chronological',
#   'irate',
#   'skrein',
#   'stange',
#   'publisher',
#   'bikers',
#   'leder',
#   'tightrope',
#   'underling',
#   'handsomeness',
#   'mini',
#   'cavalcade',
#   'messages',
#   'regressed',
#   'meurisse',
#   'meaner',
#   'kutcher',
#   'everlasting',
#   'proportions',
#   '2022',
#   'incessant',
#   'lokita',
#   'bail',
#   'monolith',
#   'porridge',
#   'pen',
#   'ground',
#   'professional',
#   'capital',
#   'dribble',
#   'micheli',
#   'romantically',
#   '30',
#   'divertissement',
#   '125',
#   'singling',
#   'treasured',
#   'emptiness',
#   'lonergan',
#   'waaaaay',
#   'seres',
#   'deceit',
#   'quoting',
#   'bloated',
#   'extrapolate',
#   'biopsy',
#   'playboy',
#   'ideologically',
#   'potholes',
#   'completely',
#   'yau',
#   'hateship',
#   'upbringing',
#   'noir',
#   'lapses',
#   'offending',
#   'jessica',
#   'floats',
#   'marquand',
#   'flicka',
#   'dench',
#   'cochrane',
#   'drifting',
#   'expository',
#   'austin',
#   'drunken',
#   'possible',
#   'jfk',
#   'mistreated',
#   'echoing',
#   'frosted',
#   'blanchett',
#   'blindness',
#   'convictions',
#   'increase',
#   'unshakable',
#   'canvass',
#   'letizia',
#   'springs',
#   'explosion',
#   'belabored',
#   'toothpick',
#   'profess',
#   'outweighed',
#   'jollity',
#   'slugger',
#   'devlin',
#   'chanel',
#   'unaccountable',
#   'duplass',
#   'libs',
#   'dimaggio',
#   'depletes',
#   'pusher',
#   'vikram',
#   '1927',
#   'orphaned',
#   'der',
#   'jiu',
#   'capitalises',
#   'kathleen',
#   'impending',
#   'sylvie',
#   'temperament',
#   'beane',
#   'twinkling',
#   'tami',
#   'erlingsson',
#   'unconvinced',
#   'tangerine',
#   'visualizes',
#   'validating',
#   'slumberland',
#   'unhappy',
#   'forces',
#   'trickier',
#   'spiridonov',
#   'iliza',
#   'onset',
#   'steak',
#   'sours',
#   'lon',
#   'avoiding',
#   'kelley',
#   'marks',
#   'elation',
#   'hungrily',
#   'appalachia',
#   'unexplained',
#   'vietnam',
#   'reveries',
#   'dumbing',
#   'ufc',
#   'recruiting',
#   'rediscovering',
#   'cap',
#   'muni',
#   'marguerite',
#   'deste',
#   'beefy',
#   'footloose',
#   'unrolls',
#   'sixties',
#   'disarray',
#   'affectionately',
#   'oti',
#   'hundreds',
#   'viewership',
#   'disengaging',
#   'joyless',
#   'appreciably',
#   'systad',
#   'bookend',
#   'provocation',
#   'adventuring',
#   'tove',
#   'caution',
#   'buoyancy',
#   'relatability',
#   'steep',
#   'autopsy',
#   'joylessly',
#   'wanderlust',
#   'house',
#   'gross',
#   'deduce',
#   'stardom',
#   'nightmares',
#   'religious',
#   'cooking',
#   'cinéma',
#   'resource',
#   'writhing',
#   'primera',
#   'undemanding',
#   'secondhand',
#   'prepei',
#   'workday',
#   'roughest',
#   'bristol',
#   'despondent',
#   'virginia',
#   'outset',
#   'podge',
#   'ive',
#   'taints',
#   'energized',
#   'shouts',
#   'kamen',
#   'contrasts',
#   'greyhound',
#   'clout',
#   'uninteresting',
#   'gems',
#   'effusive',
#   'antiwar',
#   'multi',
#   'relays',
#   'mansour',
#   'flagellation',
#   'consoling',
#   'teenage',
#   'satirize',
#   'tinha',
#   'examine',
#   'ignorance',
#   'sanzaru',
#   'diversions',
#   'neptune',
#   'unceremoniously',
#   'discursive',
#   'greatly',
#   'hiroshima',
#   'hatchet',
#   'pluto',
#   'sadiq',
#   'doubled',
#   'taste',
#   'memorial',
#   'concise',
#   'niceness',
#   'macht',
#   'harwood',
#   'boosters',
#   'pittsburgh',
#   'sender',
#   'burgers',
#   'explores',
#   'whos',
#   'moonfall',
#   'fail',
#   'earning',
#   'alfonso',
#   'pleasantville',
#   'stifled',
#   'tambien',
#   'onetime',
#   'coordinate',
#   'absurdist',
#   'ser',
#   'obliterating',
#   'gillian',
#   'regards',
#   'cunningly',
#   'exemplifies',
#   '156',
#   'quixotic',
#   'hetero',
#   'bruges',
#   'dynamic',
#   'bewildering',
#   'ulises',
#   'spike',
#   'midsommar',
#   'monae',
#   'rewrite',
#   'crisis',
#   'resurfacing',
#   'edelstein',
#   'acreditar',
#   'sellout',
#   'purports',
#   'rigby',
#   'feisty',
#   'insignificance',
#   'sic',
#   'swath',
#   'intend',
#   'scheming',
#   'chums',
#   'zaatari',
#   'curry',
#   'kalifornia',
#   'choices',
#   'brink',
#   'clumsier',
#   'overlapping',
#   'dickens',
#   'pranks',
#   'filme',
#   'intenso',
#   'households',
#   'newsroom',
#   'executed',
#   'bergerac',
#   'carlyle',
#   'garner',
#   'nathan',
#   'jalmari',
#   'corsets',
#   'slapper',
#   'ata',
#   'diehl',
#   'zaytoun',
#   'menopausal',
#   'tremendous',
#   'zing',
#   'figure',
#   'hossein',
#   'jaguar',
#   'kato',
#   'prettily',
#   'multiply',
#   'ity',
#   'vacantly',
#   'begin',
#   'pitifully',
#   'insatiably',
#   'commentaries',
#   'collaborate',
#   'geffen',
#   'receives',
#   'generality',
#   'oversell',
#   'linear',
#   'forges',
#   'politically',
#   'snooze',
#   'unsettling',
#   'equivocal',
#   'metal',
#   'vito',
#   'inauspicious',
#   'daftness',
#   'pepper',
#   'recommendation',
#   'gathering',
#   'subject',
#   'sleek',
#   'kaufman',
#   'rylance',
#   'skewed',
#   'marseillaise',
#   'rushes',
#   'ups',
#   'disingenuous',
#   'rocker',
#   'degrees',
#   'overripe',
#   'patronize',
#   'admit',
#   'agile',
#   'personalities',
#   'abruptness',
#   'fittingly',
#   'percent',
#   'crow',
#   'margret',
#   'nigh',
#   'marsden',
#   'olympian',
#   'tono',
#   'komandarev',
#   'haitian',
#   'ellipses',
#   'pr',
#   'putters',
#   'million',
#   'propulsion',
#   'wallows',
#   'divining',
#   'evocation',
#   'cartelera',
#   'swedish',
#   'occur',
#   'marine',
#   'flipping',
#   'tomorrowland',
#   'pube',
#   'hallmark',
#   'barracks',
#   'cortez',
#   'mixed',
#   'santosh',
#   'craftsmanship',
#   'crosswalk',
#   'longo',
#   'translations',
#   'winter',
#   'ricocheting',
#   'isaiah',
#   'pitiless',
#   'suffrage',
#   'minkoff',
#   'desplat',
#   '1918',
#   'comeback',
#   'kamia',
#   'carolin',
#   'gerbase',
#   'plentiful',
#   'trussed',
#   'stat',
#   'priorities',
#   'hunky',
#   'novelties',
#   'clinics',
#   'continents',
#   'broadcasting',
#   'angourie',
#   'shaggy',
#   'duplicitous',
#   'unwashed',
#   'il',
#   'goofball',
#   'sansho',
#   'screwballs',
#   'puns',
#   'abduction',
#   'toth',
#   'whoopi',
#   'speechifying',
#   'complains',
#   'confessed',
#   'robbed',
#   'defender',
#   'belo',
#   'mindgame',
#   'purr',
#   'games',
#   'systematically',
#   'briski',
#   'dynasty',
#   'fatboy',
#   'cressida',
#   'snooki',
#   'modified',
#   'telling',
#   'yerzhanov',
#   'lecarr',
#   'amorous',
#   'anatomical',
#   'vapidity',
#   'scrambling',
#   'filming',
#   'foer',
#   'amalgamation',
#   'collette',
#   'husbands',
#   'sara',
#   'letitia',
#   'rapport',
#   'mythically',
#   'winner',
#   'propels',
#   'doff',
#   'hile',
#   'dury',
#   'visiting',
#   'dates',
#   'polemics',
#   'supernaturally',
#   'furrowed',
#   'specialness',
#   'briskness',
#   'walled',
#   'transitions',
#   'fights',
#   'brilliance',
#   'oui',
#   'radnor',
#   'hysteria',
#   'ponderous',
#   'coordinated',
#   'bind',
#   'fizzle',
#   'ruler',
#   'genius',
#   'plunge',
#   'ultimate',
#   'agreed',
#   'distort',
#   'parallelism',
#   'marte',
#   'excrement',
#   'thirteen',
#   'nicotine',
#   'broadened',
#   'articulate',
#   'meathead',
#   'quixotically',
#   'barley',
#   'press',
#   'dear',
#   'talked',
#   'evacuation',
#   'subjugated',
#   'interviewer',
#   'humorlessness',
#   'daniels',
#   'intricacies',
#   'americana',
#   'baker',
#   'discover',
#   'trolls',
#   'outrages',
#   'melodramas',
#   'easing',
#   'monstrous',
#   'bewilderingly',
#   'elfin',
#   'forsaking',
#   'corelli',
#   'outclassed',
#   'gish',
#   'benn',
#   'interessante',
#   'mcgregor',
#   'points',
#   'cheated',
#   'paraplegic',
#   'tactics',
#   'affectingly',
#   'violette',
#   'anyday',
#   'sheen',
#   'annually',
#   'hk',
#   'kail',
#   'windbag',
#   'sporadic',
#   'painter',
#   'daily',
#   'camels',
#   'chanda',
#   'ohio',
#   'jayanti',
#   'reeking',
#   'displace',
#   'creeps',
#   'dark',
#   'predictable',
#   'aesthetically',
#   'graduating',
#   'toronto',
#   'neck',
#   'curator',
#   'beshir',
#   'induced',
#   'interlude',
#   'wurst',
#   'kieslowski',
#   'walsch',
#   'sewell',
#   'questions',
#   'echelon',
#   'relato',
#   'formed',
#   'oppressors',
#   'markers',
#   'undine',
#   'specialist',
#   'collectively',
#   'hamer',
#   'increasingly',
#   'yummy',
#   'toho',
#   'zandi',
#   'brugger',
#   'moans',
#   'arrangement',
#   'aki',
#   'reminding',
#   'punishable',
#   'mama',
#   'nonsense',
#   'yard',
#   'coarse',
#   'otan',
#   'keepsake',
#   'rorschach',
#   'acquits',
#   'dilemmas',
#   'dearest',
#   'soiled',
#   'excised',
#   'accrues',
#   'eclipsing',
#   'lariat',
#   'ilk',
#   'reruns',
#   'colbert',
#   'predatory',
#   'diction',
#   'carly',
#   'housebound',
#   'battled',
#   'haggis',
#   'cubs',
#   'synonymous',
#   'split',
#   '10',
#   'resolutions',
#   'filmic',
#   'twilight',
#   '62',
#   'crudity',
#   'graver',
#   'sync',
#   'prostate',
#   'anchors',
#   'watching',
#   'zone',
#   'assumption',
#   'accountable',
#   'exploratory',
#   'adorably',
#   'preferences',
#   'nines',
#   'lamp',
#   'mention',
#   'frontrunners',
#   'juicy',
#   'venerable',
#   'kolker',
#   'harding',
#   'departed',
#   'cinematically',
#   'shymalan',
#   'rungs',
#   'schaefer',
#   'cintas',
#   'libris',
#   'translator',
#   'corio',
#   'armenian',
#   'terrifically',
#   'fartsy',
#   'jieho',
#   'supreme',
#   'engaged',
#   ...})

# %% [markdown]
# `common bigrams`

# %%
voc_2gram_test = get_vocab(rt_test, ngram_range=(2,2))
len(voc_2gram_test), voc_2gram_test[:10]
# Out:
# Generating vocabulary for ngram_range: (2, 2)...
# (442876,
#  ['green slowly',
#   'slowly cranks',
#   'cranks dread',
#   'dread style',
#   'style occasional',
#   'occasional shards',
#   'shards wit',
#   'wit psychological',
#   'psychological thriller',
#   'thriller previous'])

# %%
common_bigrams = set(voc_2gram) & set(voc_2gram_test)
len(common_bigrams), common_bigrams
# Out:
# (115420,
#  {'past years',
#   'plotless story',
#   'turns bust',
#   'narrowly misses',
#   'living legend',
#   'satisfy adults',
#   'feels shallow',
#   'apos need',
#   'virtuoso film',
#   'director phyllida',
#   'nonsensical ideas',
#   'simple profound',
#   'people gorgeous',
#   'crafted love',
#   'lack jokes',
#   'expertly shot',
#   'viewer presumptions',
#   'complex relationship',
#   'entertaining movies',
#   'neatest trick',
#   'thanks del',
#   'alessandro carloni',
#   'short films',
#   'brought time',
#   'provide great',
#   'indiana jones',
#   'avoid eternals',
#   'persona sure',
#   'moral tidiness',
#   'delves deeper',
#   'love family',
#   'spark humor',
#   'beats good',
#   'finds focus',
#   'company miss',
#   'murky depths',
#   'performance film',
#   'fans cinema',
#   'bad news',
#   'tension real',
#   'crisply directed',
#   'powerful uneven',
#   'desperate efforts',
#   'time ll',
#   'linney ruffalo',
#   'violence black',
#   'bad thought',
#   'action pic',
#   'slow paced',
#   'excellent balance',
#   'bright future',
#   'watch 46',
#   'bargain bin',
#   'thing bad',
#   'mood love',
#   'nice believe',
#   'like cautionary',
#   'considerable talents',
#   'movies crammed',
#   'doesn chops',
#   'scenes lit',
#   'lives matter',
#   'story boxing',
#   'makes filmmakers',
#   'quality product',
#   'evaporate quickly',
#   'rewarding journey',
#   'son father',
#   'longest running',
#   'good christmas',
#   'lack chemistry',
#   'audience recoil',
#   'sci fi',
#   'films 2014',
#   'new information',
#   'performance stands',
#   'beautiful poetic',
#   'beauty shop',
#   'urgency makes',
#   'screenplay real',
#   'protagonists deeply',
#   'spectator sport',
#   '44 island',
#   'provide family',
#   'attract new',
#   'movie weird',
#   'feel missing',
#   'right hands',
#   '44 special',
#   'depends solely',
#   'bella edward',
#   'likely frighten',
#   'filmmaking debut',
#   'don reflect',
#   'convince better',
#   'art human',
#   'thoughtful film',
#   'clever witty',
#   'profanity nudity',
#   'parent child',
#   'feeling disappointed',
#   'touches hot',
#   'actress singer',
#   'neil maskell',
#   'adamma ebo',
#   'closer characters',
#   'contrived nature',
#   'right film',
#   'like list',
#   'powdermilk biscuits',
#   'long possibly',
#   'left long',
#   'love benefit',
#   'truly deserves',
#   'comedy 44',
#   'alfonso cuarón',
#   'little details',
#   'avert eyes',
#   'cast simply',
#   'moment real',
#   'thank god',
#   '44 amusing',
#   'genius sort',
#   'taste say',
#   'presentation does',
#   'real breakthrough',
#   'film corny',
#   'exciting tale',
#   'funny lively',
#   'outcome isn',
#   'presenting fine',
#   'story wonder',
#   'lot jokes',
#   'time game',
#   'directed brilliantly',
#   'minutes outstays',
#   'rewrite history',
#   'fi series',
#   'maximum tension',
#   'ghost story',
#   'collaborators talk',
#   'footage engaging',
#   'absorbing disturbing',
#   'interesting final',
#   'unnecessary film',
#   'passion filmmaking',
#   'directly indirectly',
#   'suspenseful final',
#   'like visionary',
#   'man films',
#   'apparently add',
#   'troubling film',
#   'help smile',
#   'step streets',
#   'quite convinces',
#   'right wrongs',
#   '11 movie',
#   'sales pitch',
#   'really close',
#   'mcu films',
#   'style director',
#   'ain funny',
#   'life enhancing',
#   'pretty amazing',
#   'focus solely',
#   'slightly heavy',
#   'wise exploration',
#   'age romance',
#   'lighter air',
#   'director actors',
#   'bit melancholy',
#   'aimed children',
#   'needs tone',
#   'drama kind',
#   'american ultra',
#   'certainly gets',
#   'overall experience',
#   'finds footing',
#   'coming weeks',
#   'falls prey',
#   'like star',
#   'premise promised',
#   'time british',
#   'certainly intriguing',
#   'subtle writing',
#   'barely entertaining',
#   'gut clenching',
#   'fare bad',
#   'funny truly',
#   'expect want',
#   'loses emotional',
#   'life service',
#   'job investing',
#   'gag 46',
#   'thing let',
#   'murphy brings',
#   'just vehicle',
#   'leads appealing',
#   'modern action',
#   'manages surpass',
#   'brain heart',
#   'subtle downright',
#   'great depression',
#   'cast headed',
#   'shortcomings 46',
#   'especially large',
#   'darkness send',
#   'kill messenger',
#   'interviews people',
#   'begs deeper',
#   'displayed entire',
#   'office sensation',
#   'played central',
#   'performance boy',
#   'awake large',
#   'proud tradition',
#   'passionately film',
#   'movie tells',
#   'eccentric characters',
#   'brilliant beautifully',
#   'short really',
#   'apos dull',
#   'mouthed funny',
#   'gripping moments',
#   'wuxia genre',
#   'action icon',
#   'far exceeding',
#   'wilson plays',
#   'termina por',
#   'factory chengdu',
#   'courtroom scenes',
#   'gender fluid',
#   'echoes film',
#   'simply greatest',
#   'weighty material',
#   'words make',
#   'work generic',
#   'large screen',
#   'really couple',
#   'demands 46',
#   'cesc gay',
#   'depth humanity',
#   'scott frank',
#   'mike barker',
#   'http www',
#   'forced movie',
#   'patton oswalt',
#   'classic book',
#   'empathetic touch',
#   'understands appeal',
#   'self acceptance',
#   'actors bond',
#   'holds sheer',
#   'effort date',
#   'outstanding cast',
#   'like better',
#   '8217 feel',
#   'enjoyed time',
#   'best little',
#   '44 gross',
#   'playing field',
#   'entertaining genre',
#   'passing resemblance',
#   'frontier surrealism',
#   'wish little',
#   'doesn favors',
#   'mean dreams',
#   'scale 44',
#   'movie indicates',
#   'actor capable',
#   'extremely acted',
#   'bollywood superstar',
#   'isn cinematic',
#   'certain points',
#   'fanciest sauce',
#   'narrative structural',
#   'round trip',
#   'semblance reality',
#   'sure remembered',
#   'swedish art',
#   'look talking',
#   '44 love',
#   'psychological nuance',
#   'hell did',
#   'adaptation thomas',
#   'kind mess',
#   'familiar tropes',
#   'software program',
#   'scripted action',
#   'new orleans',
#   'shows restraint',
#   'film twist',
#   'motivation character',
#   'film average',
#   'fun just',
#   'impossible appreciate',
#   'wolfman abominable',
#   'superficial review',
#   'titular heroine',
#   'does belong',
#   'virtues distinct',
#   'inspiring imagine',
#   'dead dare',
#   'nostalgia british',
#   'power lines',
#   'fills heart',
#   'time age',
#   'thanks wonderfully',
#   'shattering performance',
#   'better better',
#   'shape film',
#   'delivers counts',
#   'key drama',
#   'dark gloomy',
#   'seeking friend',
#   'tribute movie',
#   'children movie',
#   'worthy spectacle',
#   'little remember',
#   'hoffman film',
#   'red dog',
#   'terrifying world',
#   'comes dead',
#   'films especially',
#   'entirely absorbing',
#   'feels effortlessly',
#   'musical theater',
#   'hildur guðnadóttir',
#   'forgive movie',
#   'interested character',
#   'answers war',
#   'care content',
#   'director christopher',
#   'western civilization',
#   'biopic 44',
#   'sharp look',
#   'caine keitel',
#   'zellweger performance',
#   'fact filled',
#   'inspired film',
#   'le jour',
#   'music good',
#   'quietly determined',
#   'look come',
#   'age movie',
#   'know ve',
#   'film sci',
#   'sing praises',
#   'finding new',
#   'entertaining portrait',
#   'unique special',
#   'king plays',
#   'way bank',
#   'told review',
#   'movie supposedly',
#   'invention insight',
#   'remake new',
#   'earth feels',
#   'troubled souls',
#   'game reboot',
#   'old school',
#   'wrong love',
#   'kid flick',
#   'worth story',
#   'right lost',
#   'chandler esque',
#   'pirates caribbean',
#   'look aging',
#   'll smile',
#   '8220 glass',
#   'powerful gripping',
#   'day means',
#   'best bits',
#   'conclusively proves',
#   'alex honnold',
#   'favreau jungle',
#   'implausible movie',
#   'time moves',
#   'defining trait',
#   'manages breathe',
#   'animated children',
#   'smart tale',
#   'adaptation nicholas',
#   'important timely',
#   'finds little',
#   'credits run',
#   'emotional strokes',
#   'turned effective',
#   'close personal',
#   'purpose film',
#   'fuzzy brain',
#   'knuckle thriller',
#   '18 months',
#   'thematically rich',
#   'aimed young',
#   'handsome production',
#   'vulgar like',
#   'sex comedies',
#   'heavenly kings',
#   'composed entirely',
#   'russell like',
#   'new animation',
#   'brings old',
#   'darn thing',
#   'class modern',
#   'shimmering black',
#   'attention span',
#   'plane movie',
#   'characters charm',
#   'water shows',
#   'movies choose',
#   'efficient movie',
#   'disjointed collection',
#   'theaters year',
#   'tricks trade',
#   'queer love',
#   'night lights',
#   'franchise grow',
#   'head repeatedly',
#   'things possible',
#   'pacing lot',
#   'requisite late',
#   '44 mystery',
#   'widely regarded',
#   'previous pixar',
#   'com formula',
#   'upbeat passable',
#   'high concentration',
#   'raises lot',
#   'tremendous skill',
#   'incompatible people',
#   'party isn',
#   'does increasingly',
#   'candid sex',
#   'exceptional moments',
#   'director chan',
#   'characters motivations',
#   'writer sally',
#   'understanding empathy',
#   '500 days',
#   'brushes past',
#   'moms walks',
#   'life extraordinary',
#   'think kids',
#   'playing american',
#   'ugly dolls',
#   'discovery review',
#   'movie invested',
#   'important short',
#   'gay lives',
#   'original paddington',
#   'andrew lloyd',
#   'complex look',
#   'roles finest',
#   'house set',
#   'predictable act',
#   'brutal reality',
#   'experience watching',
#   'overwhelming sense',
#   'inner struggle',
#   'reveal doesn',
#   'trying blend',
#   'likely embrace',
#   'thanks inventive',
#   'death time',
#   'ask grandparent',
#   'lot life',
#   'solidly funny',
#   'smart setup',
#   'lonely spaces',
#   'open honest',
#   'just ride',
#   'performance make',
#   'kind raunchy',
#   'designed tear',
#   'close love',
#   'despite cartoonishly',
#   'unsettling especially',
#   'impulse makes',
#   'pretty doubtful',
#   'faces screen',
#   'precisely kind',
#   'cinematic equivalent',
#   'ashley judd',
#   'genre fiction',
#   'touch bloody',
#   'comes pretty',
#   'realism king',
#   'hits familiar',
#   'gimme shelter',
#   'tries hard',
#   'good script',
#   'neil simon',
#   'case arrested',
#   '8220 rodeo',
#   'old anthony',
#   'patient character',
#   'emerge organically',
#   'movie teetering',
#   'look impressive',
#   'essence characters',
#   'movies pull',
#   'based political',
#   'think did',
#   'features 44',
#   'lot logic',
#   'hanna fails',
#   'director levan',
#   'duck soup',
#   'largely confined',
#   'best old',
#   'shares far',
#   'bits humor',
#   'told tales',
#   'audience probably',
#   'young right',
#   'better think',
#   'raid redemption',
#   'film behold',
#   'getting wiser',
#   'flick main',
#   'inherent irony',
#   'outer space',
#   'witch hunt',
#   'flashes creativity',
#   'watch soon',
#   'basic story',
#   'like woody',
#   'inspired 44',
#   've far',
#   'clocking just',
#   'twists way',
#   'hokey dialogue',
#   'ways fails',
#   'budget zombie',
#   'sweet natured',
#   'lets main',
#   'going going',
#   'generic genre',
#   'stop watching',
#   'vista social',
#   'details lives',
#   'seriously entertaining',
#   'interesting acted',
#   'nth degree',
#   'way lacking',
#   'ways retell',
#   'material makes',
#   'bring brand',
#   'realize film',
#   'magdalena kole',
#   'epic big',
#   'lukas moodysson',
#   'deal common',
#   'won 8217',
#   'primarily comes',
#   'musical soundtrack',
#   'contemporary feminist',
#   'america does',
#   'time talking',
#   'deathly hallows',
#   'beating heart',
#   'watching dvd',
#   'films kids',
#   'crazy world',
#   'astronaut farmer',
#   'movie suffers',
#   'joan arc',
#   'villains good',
#   'menace charm',
#   'darkly hilarious',
#   'performances creepy',
#   'familial anxiety',
#   'nasty business',
#   'mujer mi',
#   'crazy eyes',
#   'wuxia films',
#   'exemplary piece',
#   'edward scissorhands',
#   'using trappings',
#   'modern morality',
#   'underwritten characters',
#   'dismissed people',
#   'understand deep',
#   'gone awry',
#   'usually small',
#   'hollywood films',
#   '46 ironic',
#   '46 burns',
#   'visionary filmmaker',
#   'probably stay',
#   'best pic',
#   'melodramatic flourishes',
#   '8217 novel',
#   'film extraordinary',
#   'opposite directions',
#   'gregory peck',
#   'delivering emotional',
#   'thoroughly worthwhile',
#   'death day',
#   'jeff barnaby',
#   'bad actress',
#   'demands attention',
#   'fluff isn',
#   'women marvel',
#   'sequel doctor',
#   'film sweet',
#   'lingering shots',
#   'mistress evil',
#   'continues story',
#   'frustrated desire',
#   'men 44',
#   'decay rotting',
#   'artistic creation',
#   'early 1960s',
#   'just isnt',
#   'public eye',
#   'imaginative cinema',
#   'direction predictable',
#   'story deserved',
#   'idi amin',
#   'suspense genre',
#   'entertainment come',
#   'film remarkable',
#   'wants cake',
#   'mcu review',
#   'life especially',
#   'concocted frothy',
#   'romantic comedic',
#   'films franchise',
#   'peter jackson',
#   'animated films',
#   'jokes land',
#   'aliens come',
#   'vu plot',
#   'delightfully acerbic',
#   'heavy screenplay',
#   'women young',
#   'astonishingly confident',
#   'canadian director',
#   'fun appreciate',
#   'complexity makes',
#   'characters center',
#   'characters breezy',
#   'complete documentary',
#   'inevitably leaves',
#   'apos pretty',
#   'level wit',
#   'work important',
#   'heart surgery',
#   'characters apart',
#   'mileage left',
#   'considerably interesting',
#   'earns stripes',
#   'works goes',
#   'focusing characters',
#   'like jimmy',
#   'marvel unlike',
#   'movie hell',
#   'boden fleck',
#   'character past',
#   'surprise surprise',
#   'touching times',
#   'absolutely wild',
#   'real warmth',
#   'stoner poet',
#   'extremely uncomfortable',
#   'charlie chan',
#   'shaking head',
#   'cherry picked',
#   'discordant music',
#   'escalates film',
#   'similar better',
#   'resonant film',
#   'deal charm',
#   'isild le',
#   'coming soon',
#   'thriller touch',
#   'action thrillers',
#   'finds horror',
#   'story spielberg',
#   'wasp quantumania',
#   'dan brown',
#   'calling card',
#   'corporate sexism',
#   'charm stars',
#   'throwback action',
#   'austere film',
#   'trying cash',
#   'gonzlez rubio',
#   'sidelines starts',
#   'heavy metal',
#   'days kill',
#   'making mind',
#   'mind boggling',
#   'movies hulu',
#   'woman country',
#   'artist game',
#   'winn dixie',
#   'camp value',
#   'day america',
#   'got stinking',
#   'story adults',
#   'um dos',
#   'visual pleasures',
#   'york state',
#   'aspects screenplay',
#   'decent people',
#   'offer cool',
#   'berman robert',
#   'palpable emotional',
#   'folk hero',
#   'sweat tears',
#   'lifts movie',
#   'interesting likable',
#   'barely passes',
#   'patience testing',
#   'effects add',
#   'sense immediacy',
#   'movies hard',
#   'greatest romantic',
#   'count make',
#   'like gimmick',
#   'actors precise',
#   'sophia takal',
#   'funny refreshingly',
#   'theater don',
#   'death small',
#   'human relations',
#   'exactly set',
#   'amazing best',
#   'editing room',
#   'film heart',
#   'actors onscreen',
#   'zone ish',
#   'does low',
#   'tonal control',
#   'beloved disney',
#   'leaves bit',
#   'handsomely shot',
#   'said ll',
#   'cake eaten',
#   'ultimately final',
#   'story filmed',
#   'conventional way',
#   'subject admirable',
#   'clearly know',
#   'ambiguity screenplay',
#   'real dirt',
#   'joplin actually',
#   'average year',
#   'pacino walken',
#   'eyes just',
#   'works perfectly',
#   'cheesily entertaining',
#   'romantic 44',
#   'hopeful enduring',
#   'stuck inside',
#   'wesley snipes',
#   'emotional moment',
#   'universal appeal',
#   'film signature',
#   'universe creates',
#   'leaves hungry',
#   'interesting scenes',
#   'movies ought',
#   'popcorn movies',
#   'norman rockwell',
#   'sad reminder',
#   'spirit old',
#   'people overcome',
#   'screenplay adaptation',
#   'garfield stone',
#   'look screen',
#   'fewer fewer',
#   'story sharp',
#   'spielberg comes',
#   'tv host',
#   '300 million',
#   'best james',
#   'end intelligent',
#   'finished watching',
#   'starts stale',
#   'quest happiness',
#   'feels far',
#   'movie screen',
#   'true importance',
#   'ground breaking',
#   'cut editing',
#   'dumb dumberer',
#   'heavy artillery',
#   'surprisingly wistful',
#   'boring story',
#   'film loses',
#   'raiders lost',
#   'uses advantage',
#   'gets tedious',
#   'game gets',
#   'humorous moments',
#   'holds movie',
#   'british comedies',
#   'determined avoid',
#   'ability fantasy',
#   'genre cynicism',
#   'message working',
#   'power fantasy',
#   'funny satirical',
#   'follow superlative',
#   'quot ant',
#   'monster doesn',
#   'talent movie',
#   'fifth element',
#   'like neighbors',
#   'lends weight',
#   'crisp style',
#   'look closer',
#   'thriller let',
#   'film aspirations',
#   'worse things',
#   'gory moments',
#   'reminds world',
#   'perception reality',
#   'average entry',
#   'story coherence',
#   'mix sadness',
#   'help guide',
#   'ronstadt sound',
#   '44 thematic',
#   'perfectly enjoyable',
#   'momentum movie',
#   'absolutely make',
#   'america mythic',
#   'hollywood hasn',
#   'works movie',
#   'scene minutes',
#   'persistence hope',
#   'threaded semblance',
#   'fi fantasy',
#   'hollywood remakes',
#   'student film',
#   'film franchise',
#   'performances subtle',
#   'hotel room',
#   '44 unsentimental',
#   'giant step',
#   'wonderful 46',
#   'ownership art',
#   'meaning number',
#   'like glove',
#   'enjoyable campy',
#   'intended little',
#   'range emotion',
#   'cast giving',
#   'qualify holiday',
#   'way camera',
#   'thriller riveting',
#   'film wit',
#   'seen gave',
#   'fact won',
#   'parts interesting',
#   'dances desire',
#   'days entebbe',
#   'note rant',
#   'scarlet letter',
#   'end certainly',
#   'genuinely upsetting',
#   'movie perils',
#   'franchise fatigue',
#   'fresh contemporary',
#   'drama father',
#   'jackson scenery',
#   'american relations',
#   'lack wit',
#   'folk art',
#   'really really',
#   'continuing story',
#   'questions clear',
#   'lead actresses',
#   'comes apart',
#   'brooks wrote',
#   'original gone',
#   'trying way',
#   'computer chess',
#   'plot total',
#   'school genre',
#   'film audition',
#   'scenes feels',
#   'new teen',
#   'una esas',
#   'small role',
#   'singularly strange',
#   'surprises review',
#   'probably love',
#   'able actors',
#   'moore pierce',
#   'really small',
#   'ocean 11',
#   'got brains',
#   'wondering time',
#   'different ideas',
#   'entertaining effort',
#   'philip roth',
#   'maybe different',
#   'popular entertainment',
#   'hard impressed',
#   'avoiding usual',
#   'doesn fit',
#   'indictment broken',
#   'sagging middle',
#   'life 8221',
#   'act audience',
#   'cross section',
#   'life despite',
#   'remains poignant',
#   'western dead',
#   'cliches makes',
#   'potty training',
#   'fake world',
#   'worse second',
#   'film horror',
#   'downright boring',
#   'job singing',
#   'encounters kind',
#   'attention movie',
#   'melancholic mystery',
#   '58 fun',
#   'proceedings letting',
#   'leaves imagination',
#   'documentary detailing',
#   'nagging little',
#   'hearing raven',
#   'hitting stride',
#   'emotional storm',
#   'viewer forgive',
#   'heartwarming story',
#   'unless fan',
#   'horror stories',
#   'fresh thrilling',
#   'nonsensical plot',
#   'harmlessly amusing',
#   'effective entertainment',
#   'limbo displacement',
#   'movie chief',
#   'timeless fairy',
#   'considered film',
#   'artist lot',
#   'physical violence',
#   'james mangold',
#   'middling melodrama',
#   'nearly enthralling',
#   'hood knows',
#   'visual component',
#   'images haunting',
#   'larger events',
#   'food eat',
#   'cycling team',
#   'taken time',
#   'entertainment just',
#   'dark emotionally',
#   'meets boy',
#   '18 year',
#   'actors big',
#   'quality feels',
#   'emerges solid',
#   'intermittently funny',
#   '44 fantasy',
#   'largely falls',
#   'black hawk',
#   '44 feminine',
#   'ellen burstyn',
#   'final fade',
#   'properly thrilling',
#   'episode 24',
#   'young girls',
#   'single bound',
#   'moments looks',
#   'wise man',
#   'way fun',
#   'shuck jive',
#   'welcome respite',
#   'begging told',
#   'bored single',
#   'howlingly awful',
#   'perfectly matched',
#   'tension built',
#   'hit funny',
#   'thoroughly pleasant',
#   'generate chemistry',
#   'overbearing sense',
#   'mixing humor',
#   'netflix film',
#   'meanders bit',
#   'new testament',
#   'visceral journey',
#   'short laughs',
#   'series rises',
#   'bit lazy',
#   'experience star',
#   'graham moore',
#   'try things',
#   ...})

# %%
len(common_unigrams | common_bigrams)
# Out:
# 151366

# %% [markdown]
# `common trigrams`

# %%
voc_3gram_test = get_vocab(rt_test, ngram_range=(3,3))
len(voc_3gram_test), voc_3gram_test[:10]
# Out:
# Generating vocabulary for ngram_range: (3, 3)...
# (498850,
#  ['green slowly cranks',
#   'slowly cranks dread',
#   'cranks dread style',
#   'dread style occasional',
#   'style occasional shards',
#   'occasional shards wit',
#   'shards wit psychological',
#   'wit psychological thriller',
#   'psychological thriller previous',
#   'thriller previous films'])

# %%
common_trigrams = set(voc_3gram) & set(voc_3gram_test)
len(common_trigrams), common_trigrams
# Out:
# (23768,
#  {'earnest lovable hero',
#   'girls just want',
#   'drama tangled taut',
#   'latest animated feature',
#   'film does live',
#   'given gorgeously animated',
#   'viewing experience film',
#   'movie isn just',
#   'film clint eastwood',
#   'screw u2013 movie',
#   'story absurdly outlandish',
#   'film play emotions',
#   'late heath ledger',
#   'apos ll enjoy',
#   'filmed black white',
#   'homegrown movie ll',
#   'little horror film',
#   '44 good person',
#   'film completely different',
#   'proving right hands',
#   '44 8217 quite',
#   'version things recovered',
#   '8217 worry darling',
#   'emmerich old hand',
#   'romantic comedy year',
#   'taut tense thriller',
#   'bond mothers daughters',
#   'jaume collet serra',
#   'look human relationships',
#   'film great 8217',
#   'heartwarming coming age',
#   'version casablanca porcine',
#   'director taylor hackford',
#   'indiana jones crusade',
#   'fall love lust',
#   'white noise funny',
#   'better things come',
#   'john woo movie',
#   'sleepwalk dreary nonsensical',
#   'screen 44 solidifying',
#   'directed teenage audience',
#   'spend 109 minutes',
#   'season characterized heavy',
#   'sam elliott performance',
#   'unsurprising need great',
#   'movie brain heart',
#   'larry david sour',
#   'kind film come',
#   'better popcorn movie',
#   'kids certain age',
#   'despite film obvious',
#   'cries seen described',
#   'language film oscar',
#   'compelling anatomy grief',
#   'doesn quite know',
#   'preposterous bet 2012',
#   'movie spends time',
#   'gothic horror story',
#   'make great films',
#   'offers chance catch',
#   'president men post',
#   'feel little rushed',
#   'filmmaking inherently bad',
#   'kittredge american girl',
#   'multi layered visual',
#   'dark chapter american',
#   'material doesn help',
#   'real story real',
#   'barely 90 minutes',
#   'typical hollywood fare',
#   'director jeff nichols',
#   'roiling beneath surface',
#   'study team building',
#   'life affirming watch',
#   'don quite understand',
#   'like john wick',
#   'road paved good',
#   'frozen ii doesn',
#   'easily better films',
#   'numerous plot holes',
#   'like tone poem',
#   'hard swallow moments',
#   'classe tous risques',
#   'feels like outline',
#   'ralph breaks internet',
#   'hour long tv',
#   'director santosh sivan',
#   'plastic george hamilton',
#   'approaches considered alternative',
#   'works like short',
#   'hour 45 minutes',
#   'works like charm',
#   'saga review spanish',
#   'drama comedy comes',
#   'appeal young viewers',
#   'helen mirren ryan',
#   'year best movie',
#   'director jeremiah zagar',
#   '86 minute cosmic',
#   'beauty worst kind',
#   'average year old',
#   'come understand parents',
#   'important short film',
#   'actors zero chemistry',
#   'jeff bridges oscar',
#   'let eat cake',
#   'fan appreciation exuberant',
#   'good good bad',
#   'worst film series',
#   'despite plot holes',
#   'ass female action',
#   'staff benda bilili',
#   'lot fun watching',
#   'martin scorsese george',
#   'music video trained',
#   'good way review',
#   'bite refuse let',
#   'don know watching',
#   'assness 151 better',
#   'stylish psychological thriller',
#   'doc makes feel',
#   'horror movies review',
#   'thriller strong performances',
#   'kubrick pretty covered',
#   'like feature length',
#   'making obvious point',
#   'chemistry young actors',
#   'eye opening look',
#   'real world logic',
#   '90 minutes feels',
#   'brand thing altogether',
#   'does manage achieve',
#   'capturing real life',
#   'makes film worth',
#   'captain america civil',
#   'pretense shock tactics',
#   'overwritten dialogues review',
#   'dwayne johnson kevin',
#   'struggles right tone',
#   'african american man',
#   'fantastically ridiculous title',
#   'usual ambitions genre',
#   'long 44 strange',
#   'know things going',
#   'director john stockwell',
#   'dated rom com',
#   'fraqussimos filme ainda',
#   'mia hansen løve',
#   'comic book adventure',
#   'james bond like',
#   'mother preteen daughter',
#   'allure powdermilk biscuits',
#   'superb central performances',
#   'playing straight man',
#   'simply isn funny',
#   'modern science fiction',
#   'numerous tense situations',
#   'generous running time',
#   'just don know',
#   'minds company decor',
#   'thriller dark comedy',
#   'cast uniformly excellent',
#   'background hunnam hedlund',
#   'story young man',
#   'credits background music',
#   'promise better future',
#   'writer director neil',
#   'dreadfully contrived artificial',
#   'like looks like',
#   'subject matter dramatic',
#   'mins truly succinct',
#   'real world comforting',
#   'familiar tale mistakenly',
#   'metaphors review spanish',
#   'theater jittery anticipation',
#   'second civil war',
#   'offstage ferocious work',
#   'pushes right buttons',
#   'laughs 44 astonishing',
#   'film really isn',
#   'really use right',
#   'assault tear ducts',
#   'nigh epic proportions',
#   'story science fiction',
#   'life blue warmest',
#   'summer review spanish',
#   'pays homage japan',
#   'feels like natural',
#   'time going does',
#   'really best taken',
#   'watch impossible ignore',
#   'perfect example hollywood',
#   'people fall love',
#   'les vampires thrill',
#   'real life war',
#   'sound hand clapping',
#   'suzanne collins final',
#   'wins ben kingsley',
#   'films year far',
#   'like filmmakers bored',
#   'comes short emotion',
#   'saif ali khan',
#   'high octane action',
#   '20th century women',
#   'director gavin hood',
#   'year old effects',
#   'road trip flick',
#   'peter mackie burns',
#   'action movies year',
#   'feel like comes',
#   'plastic action figures',
#   'genre ve seen',
#   'writing 44 directing',
#   'hart political world',
#   'performances talented cast',
#   'hardcore protagonist prepared',
#   'quot little quot',
#   'far interesting titular',
#   'good news sequel',
#   'smart funny sweet',
#   'away worse movie',
#   'entire 96 minutes',
#   'little bit little',
#   'ocean confinement abyss',
#   'buoyant film spielberg',
#   'fans money worth',
#   'inventive impressive visuals',
#   'makes film work',
#   'time big screen',
#   'meanders propaganda mighty',
#   'leaving little room',
#   'matter fact approach',
#   'make thought provoking',
#   'overall just don',
#   'little time travel',
#   'boss james whitey',
#   'parisian decadence sumptuous',
#   'warms bit second',
#   'self indulgent piece',
#   'girls just wanna',
#   'jobs man machine',
#   'just like rest',
#   'spy kids time',
#   'performance danielle deadwyler',
#   'movies think just',
#   'writer director anders',
#   'ask tough questions',
#   'better writer director',
#   'dynamic comic duo',
#   'given perry snowballing',
#   'really really ridiculously',
#   'dead things eat',
#   'film fans film',
#   'released major studio',
#   'government views film',
#   'star crossed lovers',
#   'uplifting account elderly',
#   'greatest hits collection',
#   'low key satire',
#   'intelligent emotionally satisfying',
#   'movie just gets',
#   'clive owen gives',
#   'just make sure',
#   'like machine gun',
#   'conceived message movie',
#   'considered best american',
#   'prize winning play',
#   'big screen possible',
#   'screen screen radio',
#   'samberg cristin milioti',
#   'fallen hard times',
#   'applauded resisting temptation',
#   'self consciously tricky',
#   'fight sequences staged',
#   'films 2016 review',
#   '8217 right 46',
#   'best men film',
#   'mean old school',
#   'year old boy',
#   'ry russo young',
#   'low key slapstick',
#   'stadium lights west',
#   'movie rests squarely',
#   'writing directing duo',
#   'veteran lai kuo',
#   'big budget movies',
#   'time travel plot',
#   'obvious heavy handed',
#   'typical sci fi',
#   'just big dumb',
#   'lives 46 10',
#   'thriller quite satisfying',
#   'late summer movie',
#   'family friendly entertainment',
#   'truly great film',
#   'don say word',
#   'pretentious tolkien influence',
#   'hero color city',
#   'film start finish',
#   'plot review spanish',
#   'sitcom masquerading feature',
#   'old fashioned drama',
#   'hollywood turned effective',
#   'looks like knows',
#   'father daughter relationship',
#   'hand combat scenes',
#   'running time half',
#   'true life subject',
#   'discernable point view',
#   'films come hollywood',
#   'exuberant musical numbers',
#   'milk far laughs',
#   'rain man far',
#   'film works levels',
#   'amusing thought provoking',
#   'best romantic comedy',
#   'fight good evil',
#   '44 8220 ant',
#   'making ant man',
#   'damn good actor',
#   'family focused relationship',
#   'premise employed middling',
#   'won able eyes',
#   'watch ensure 8217',
#   'blades musician 46',
#   'sense epic adventure',
#   'action comedy review',
#   'performance kristen stewart',
#   'exciting work watchable',
#   'real brian banks',
#   'love simon feels',
#   'superbly acted ultimately',
#   'really fun movie',
#   'hard look dubious',
#   'writer director adamma',
#   'definitely lost translation',
#   'director latest film',
#   'tom cruise action',
#   'strong cast directed',
#   '80s sci fi',
#   'solely sell inside',
#   'good hearted film',
#   'zombieland double tap',
#   'll blue warmest',
#   'old fashioned film',
#   'road trip old',
#   'movie delivers goods',
#   'film good deal',
#   'best film date',
#   'captivating thoroughly enjoyable',
#   'fun turn brain',
#   'seemingly foolproof premise',
#   '10 cloverfield lane',
#   'unless fan autobiographical',
#   'new passionately realized',
#   'emotional connection characters',
#   'essential stoic loneliness',
#   'tour neighborhoods actual',
#   'fan autobiographical comics',
#   '44 uh 44',
#   'young woman powerful',
#   'quot feels like',
#   'science fiction movies',
#   'best performances careers',
#   'family friendly fare',
#   'movie bit letdown',
#   'figurative literal supremely',
#   'transcends delicate intricacies',
#   'left sour taste',
#   'tries desperately hard',
#   'improved special effects',
#   'studios don make',
#   'thinly veiled meditation',
#   'times hit miss',
#   'journey self discovery',
#   'great lead character',
#   'low key action',
#   'cash grab sequel',
#   'levels review spanish',
#   'film does offer',
#   'emotional drama terrific',
#   'worth look film',
#   'monty python esque',
#   'wall street money',
#   'shows lot potential',
#   'movie bright spots',
#   'latest movie worth',
#   'let count ways',
#   'heart warming film',
#   'film falls short',
#   'star making lead',
#   'textbook example director',
#   'just barely good',
#   'really cries seen',
#   '8220 black phone',
#   'likely movie theater',
#   'routine espionage canvass',
#   'plays like long',
#   'blandness execution makes',
#   'science fiction storytelling',
#   'voice cast does',
#   'engaging lead performance',
#   'long time spend',
#   '1987 original 46',
#   'movie trying hard',
#   'like seasoned veteran',
#   'beautifully designed acted',
#   'luminescent ellen burstyn',
#   'make kind movie',
#   '44 8217 makes',
#   'film gives unique',
#   'holland original vampire',
#   'genuine belly laughs',
#   'film school 101',
#   'scouts guide zombie',
#   'good bad weird',
#   'hiding plain sight',
#   'happy ending story',
#   'talented filmmakers working',
#   'est le film',
#   'kind movie gives',
#   'farce plays like',
#   'debates advocating media',
#   '58 ruse guerre',
#   'like movie 44',
#   'script flat performances',
#   'schizophrenic tonal shifts',
#   'like fairy tales',
#   'marcel shell shoes',
#   'doesn really hold',
#   'smart writing 44',
#   'eye roll moments',
#   'soviet republic georgia',
#   'wondering ve watching',
#   'cat returns moves',
#   'desired review spanish',
#   'cowboy really cries',
#   'edge seat film',
#   'feature debut handles',
#   'splendid visual effects',
#   'works best comes',
#   'british costume drama',
#   'developing characters possibly',
#   'dazzling special effects',
#   'intriguing case study',
#   'neighborhoods actual metaphoric',
#   'feels lot like',
#   'happens feels like',
#   'wordplay scalpel precise',
#   'impressive directorial debut',
#   'supporting cast just',
#   'dig little deeper',
#   'channing godfrey peoples',
#   '20th century art',
#   'film grows dull',
#   'intimate portrait man',
#   'doesn come surprise',
#   'big screen far',
#   'fear loathing las',
#   'film dreadfully contrived',
#   'ensemble comedy feels',
#   'revisits themes predecessors',
#   'attention look away',
#   'fun promise children',
#   'bad horror movie',
#   'shorts linked doesn',
#   'point actually want',
#   'mid 20th century',
#   'worthy rom com',
#   'beauty exposure human',
#   'easily best work',
#   'insecure teenagers comes',
#   'relationship drama rare',
#   'pixar disney animation',
#   'makes ludicrous project',
#   'big emotional punch',
#   'charms owen wilson',
#   'film good natured',
#   'raises questions answers',
#   'silly occasionally funny',
#   'given time place',
#   'greatest living filmmakers',
#   'play like standard',
#   'golden age hollywood',
#   'alexandre aja remake',
#   'brooks young frankenstein',
#   'school age kids',
#   'cruelty death penalty',
#   'just familiar face',
#   'version familiar tale',
#   'characters brought life',
#   'good action movie',
#   've loved long',
#   'healing power empathy',
#   'director michael bay',
#   'just want good',
#   'ways busy shredding',
#   'ferocious oh vulnerable',
#   'violence scary scenes',
#   'small time crooks',
#   'dismissed people obsessively',
#   'shouldn 8217 shot',
#   'action flick delivers',
#   'origin story beautiful',
#   'impressive special effects',
#   'screens big small',
#   'characters richer human',
#   'teen angle opens',
#   'infinity pool 8221',
#   'breaks new ground',
#   'history review spanish',
#   'movie trades heavily',
#   'remaining fixed sense',
#   'comedy loosely based',
#   'vietnamese director tran',
#   'minutes feel like',
#   'cast fusion classic',
#   'new york times',
#   'laugh loud riot',
#   'hand drawn 2d',
#   'american popular culture',
#   'perry snowballing small',
#   'deadpan sense humor',
#   'day earth stood',
#   'ari aster sophomore',
#   'modern day morality',
#   'just niggling flaws',
#   'po faced fantasy',
#   'feels like matrix',
#   '20 minute short',
#   'sense minute comes',
#   'film pop culture',
#   'goes certainly won',
#   'things review spanish',
#   'history cinema 46',
#   'plot twists just',
#   'dreary dull tale',
#   'just story telling',
#   'narrative unrolls song',
#   'new computer animated',
#   'won remember movie',
#   'predictable plot turns',
#   'action laced humor',
#   'nominated best picture',
#   'performance austin butler',
#   'dig deep surface',
#   'real life people',
#   'clever half clever',
#   'making bollywood police',
#   'increasingly ridiculous plot',
#   'want hours film',
#   'shock tactics torture',
#   'political review spanish',
#   'struggles young man',
#   'excellent cast review',
#   'll probably fine',
#   'apart unnecessary profusion',
#   'harry potter sorcerer',
#   'compelling thrill ride',
#   'screenwriter todd komarnicki',
#   'performance felicity jones',
#   'cinema greatest performances',
#   'liam neeson action',
#   'like old fashioned',
#   'jazzes proceedings match',
#   'set working class',
#   'given extra heft',
#   'animada por atractivo',
#   'director 8217 signature',
#   'love tv series',
#   'blend live action',
#   'cooking premises absurd',
#   'true coen brothers',
#   'drama lot say',
#   'say human condition',
#   'starts come focus',
#   'just doesn make',
#   'adaptation jane austen',
#   'frank langella plays',
#   'social issue drama',
#   'main character interesting',
#   'skarsgrd rescue complete',
#   'school age children',
#   'new ground paints',
#   'waste 78 minutes',
#   'epic movie does',
#   'expect underdog sports',
#   'smart step opening',
#   'hasn figured make',
#   'ego review spanish',
#   'seen thousand times',
#   'movie sophisticated adults',
#   'sucked life film',
#   'gets old timeless',
#   'like bruce lee',
#   'sartre facial close',
#   'visceral 44 8217',
#   '46 46 46',
#   'presents man prisoner',
#   'gets skin feels',
#   'short fast film',
#   'happened night 1934',
#   'imagination review spanish',
#   'film self consciously',
#   'really really fast',
#   '47 year old',
#   'focused dimaggio chatting',
#   'high energy adaptation',
#   'action hero 46',
#   'telling story character',
#   'gets blood boiling',
#   'easier recommend like',
#   'drags bit middle',
#   'tight little thriller',
#   'quick witted dialogue',
#   'gives tour force',
#   'didn want need',
#   'good film feels',
#   'good era long',
#   'surprisingly dark film',
#   'star wars films',
#   'gives career defining',
#   'origin story 44',
#   'giving film spark',
#   'straightforwardness doesn allow',
#   'better comic book',
#   'contender film year',
#   'duly impressive point',
#   '20th century history',
#   'direct dvd quality',
#   'good job balancing',
#   'loses focus way',
#   '44 just like',
#   'like lasts hours',
#   'ground paints revealing',
#   'best stephen king',
#   'film dull politically',
#   'modestly entertaining diversion',
#   'great camera work',
#   'doesn bring new',
#   'horror films 44',
#   'film festival movie',
#   'cavernous plot holes',
#   'good looking girls',
#   'remarkable film worse',
#   'movie think frank',
#   'films recent years',
#   'comedy painfully earnest',
#   'rock em sock',
#   'thriller 44 8217',
#   'falls short vintage',
#   'succeeds main goal',
#   '90s hip hop',
#   'good children film',
#   'little light shed',
#   'american films year',
#   'snappy fast paced',
#   'anthony mccarten script',
#   'film tries hard',
#   'far better suited',
#   '44 8221 isn',
#   'valeria bruni tedeschi',
#   'think know movie',
#   'charm tongue cheek',
#   'action movies just',
#   'frenetically edited action',
#   'merry friggin christmas',
#   'wick chapter parabellum',
#   'hecht page mark',
#   'coen brothers best',
#   'ago feels like',
#   'budget adult drama',
#   'vista social club',
#   'script superb performances',
#   'gives audience credit',
#   'does wonderful job',
#   'source material 44',
#   'stature chimpanzees apes',
#   'title subject tragic',
#   'films thoroughly entertaining',
#   'pleasing comic book',
#   'minute movie stretched',
#   'soap opera treatment',
#   'make cinematic charismatic',
#   'message really matters',
#   'turns pretty good',
#   'director nimrod antal',
#   'decent cast assembled',
#   'shocking review spanish',
#   'donk scor zay',
#   'enjoyable way spend',
#   'new meaning phrase',
#   'far far better',
#   'lower middle class',
#   'dysfunctional mother daughter',
#   'beginning middle end',
#   'story leaves viewers',
#   'film timely relevant',
#   'escapist fun like',
#   'rich sense place',
#   'like romantic comedy',
#   'good intentions just',
#   'tough rewarding watch',
#   'ordinary human beings',
#   'crafted spooky scenarios',
#   'identity social status',
#   'interviews archival footage',
#   'marx brothers second',
#   'thoroughly satisfying drama',
#   'make great movie',
#   'writer director jake',
#   'point plot point',
#   'views film subjects',
#   'characters sound like',
#   'wide screen cinematography',
#   'strikingly underreported mainstream',
#   'noir unfolds detailed',
#   'unengaging utterly devoid',
#   'hard tell time',
#   'makes teeth itch',
#   'second rate goods',
#   'pop rock songs',
#   'interesting characters movies',
#   'toddler set translate',
#   'acaba soando mais',
#   '46 world building',
#   'short running time',
#   'alike satisfying payoff',
#   'camera review spanish',
#   'movies comic book',
#   'friedberg aaron seltzer',
#   'don come away',
#   'feeling déjà vu',
#   '46 just niggling',
#   'feels familiar perspective',
#   'good film great',
#   'let muster reason',
#   'possibly want blockbuster',
#   '8217 ll wish',
#   'worked better short',
#   'pg 13 rating',
#   'lot better decade',
#   'best chapter entire',
#   'far better right',
#   'screenplay tedious direction',
#   'dreamworks better efforts',
#   'world gone mad',
#   'disturbing affecting cinematic',
#   'peg square hole',
#   'ryan reynolds great',
#   'characters interesting premise',
#   'represented horizon tragic',
#   'apparent treats female',
#   'writer armando iannucci',
#   'comedy real life',
#   'debut director screenwriter',
#   'era long past',
#   'kumar escape guantanamo',
#   'hope charming buoyant',
#   'uplift promised title',
#   'film makes abundantly',
#   '8217 doing 44',
#   'repeatedly seen cinema',
#   'moments instead thrown',
#   'right place comes',
#   'solid young actor',
#   'roles prequel jackson',
#   'thriller run time',
#   'treatment review spanish',
#   'supporting cast including',
#   'worst films ve',
#   'shock new film',
#   '46 46 8217',
#   'doesn quite knock',
#   'ensure 8217 ll',
#   'long credits roll',
#   'quite clever thinks',
#   'father son drama',
#   'horror fans film',
#   'devil wears prada',
#   'capture magic original',
#   'cold realization story',
#   'style fine sense',
#   'like quentin tarantino',
#   'fans strong stomachs',
#   'offers audiences chance',
#   'repetitive review spanish',
#   'falls short delivering',
#   '44 past lives',
#   'franchise review spanish',
#   'make em like',
#   '44 smooth 44',
#   'luminous black white',
#   'potent moral tale',
#   'low budget western',
#   'doesn mind playing',
#   'date movie year',
#   '8220 don 8217',
#   'scott thomas performance',
#   'devastated tornado 20',
#   'series feels like',
#   'entire supporting cast',
#   'film distinctive look',
#   'urgency real life',
#   'coming age classic',
#   'fascinating biographical documentary',
#   'high tension fast',
#   'performance gordon levitt',
#   'beasts southern wild',
#   'don believe hype',
#   'romantic comedy right',
#   'dealing heavy themes',
#   'feature length version',
#   'kriegman elyse steinberg',
#   'instantly iconic performance',
#   '1940s future 38',
#   'version 44 8217',
#   'displacement ocean confinement',
#   'grace notes make',
#   'spent 15 years',
#   'good bad ugly',
#   'changing mother daughter',
#   'smarter usual action',
#   'buddy action movies',
#   'leading man status',
#   'black messiah best',
#   'doesn know quite',
#   'time spent watching',
#   'heart proves athletic',
#   'life big screen',
#   'dramatic action packed',
#   'film sight behold',
#   'crowd pleaser just',
#   'feature film 44',
#   'action movie fans',
#   'kids leave theater',
#   'james whitey bulger',
#   'enjoyable film review',
#   'actor wig hair',
#   'proudly old fashioned',
#   'film makes great',
#   'directs tremendous skill',
#   'film fun moments',
#   '60 year old',
#   'immersive viewing experience',
#   'news daddy day',
#   'hold special place',
#   'film indulgences missteps',
#   'global audiences parable',
#   'plays viewers game',
#   'joy film comes',
#   'people getting shot',
#   'hollywood guts deliver',
#   '44 heavy handed',
#   'sci fi fun',
#   'direction spare canvas',
#   'hard overstate just',
#   'touches hot button',
#   'film manages entertaining',
#   'alice looking glass',
#   'action film year',
#   'close quarters fighting',
#   'keeps going going',
#   'does mean good',
#   'filmmaker sarah polley',
#   'sad teeming music',
#   'don make great',
#   '8217 pain 46',
#   'character development make',
#   'brantley rick reilly',
#   'abdul mateen ii',
#   'slipping end good',
#   'movie care characters',
#   'like disney channel',
#   'mary stuart masterson',
#   'performances daniel kaluuya',
#   'crazy samurai musashi',
#   'rah sports movie',
#   'need great actor',
#   'plays like finely',
#   'outsiders suffers performances',
#   'humanidade falha atrapalhada',
#   'movie hankering watch',
#   'works film advantage',
#   'material elmore leonard',
#   'best films richly',
#   'man smart funny',
#   'humanity review spanish',
#   'avoid eternals like',
#   'tell review spanish',
#   'time travel make',
#   'director james brooks',
#   'children movie just',
#   'cinematic universe damian',
#   'hunger games catching',
#   'family drama really',
#   'simply exists ordinary',
#   'hans zimmer score',
#   'realized later princess',
#   'feels like second',
#   'certain kind satisfaction',
#   'images review spanish',
#   'assault precinct 13',
#   'spend time movies',
#   'high school films',
#   'second half story',
#   'powerful little film',
#   'real breath fresh',
#   'best films marvel',
#   'social media thriller',
#   'chemistry leads review',
#   'set record straight',
#   'bad company like',
#   'keeps getting better',
#   'family comedy drama',
#   'plus hour running',
#   'director finest work',
#   'film isn nearly',
#   'good vampire tale',
#   'characters particularly plausible',
#   '44 unfocused 44',
#   'feel like just',
#   'good movie isn',
#   'purely cinematic terms',
#   'ely displays surprisingly',
#   'lou diamond phillips',
#   'left cutting room',
#   'andrei tarkovsky solaris',
#   'make good bad',
#   'time travel movies',
#   'fun amusement park',
#   'bad film benefited',
#   'simply life film',
#   'major studio film',
#   'nightmare elm street',
#   'lowered expectations don',
#   'role reduced carrying',
#   'justify feature length',
#   'family film enjoy',
#   'allowing hear happened',
#   'kids adults alike',
#   'funny moving story',
#   'lo fi indie',
#   'anchored outstanding performances',
#   'character study strong',
#   'lead actors make',
#   'real head scratcher',
#   'sant applauded resisting',
#   'welsh poet dylan',
#   'gordon green early',
#   'films far year',
#   'amy berg insightful',
#   'tremendously entertaining film',
#   'cinematic form pure',
#   'edifying interesting twist',
#   'hard watch film',
#   'doesn offer real',
#   'waste time money',
#   'weapon review spanish',
#   'simply don care',
#   'american high school',
#   'great sight gags',
#   'does things right',
#   'white camera work',
#   'good character development',
#   'make difference 46',
#   'strikes gold 46',
#   'doesn necessarily mean',
#   'hard make like',
#   'offers easy answers',
#   'provides intimate look',
#   'scenes play like',
#   'piece work time',
#   'delivers thought provoking',
#   'films easily best',
#   'writer director eliza',
#   'film post war',
#   '44 reality missing',
#   'sci fi classic',
#   'subtle affecting long',
#   'tezz dull derivative',
#   'little star power',
#   'intriguing feature debut',
#   'russ meyer movies',
#   'really want make',
#   'south korean director',
#   'heart plenty laughs',
#   'shy ely displays',
#   'power performer desperate',
#   'form content comes',
#   'masterful command humor',
#   'unique vision 46',
#   'interesting things say',
#   'man best friend',
#   'new film director',
#   'barometer responds positive',
#   'thought provoking sci',
#   'eric walter rehashes',
#   'feeling review spanish',
#   'film interesting film',
#   ...})

# %%
len(common_unigrams | common_bigrams | common_trigrams)
# Out:
# 175134

# %% [markdown]
# ## Baseline performance of 'reviewText' column

# %%
rt_dict = {'txt': ['reviewText']}
rt_dict
# Out:
# {'txt': ['reviewText']}

# %%
# submit_v4(selected_model=LogisticRegression(C=5, solver="saga", max_iter=100000),
#           selected_features=rt_dict,
#           param_grid=None,
#           vocab=None)

# %% [markdown]
# ## RFE

# %%
def fs_rfe(selector, text_df, labels, ngram_range=(1,1)):
    text_df_ngram = TfidfVectorizer(ngram_range=ngram_range, stop_words='english').fit_transform(text_df)
    print("text_df was vectorized using TF-IDF vectorizer with ngram_range: ", ngram_range)
    print("text_df.shape: ", text_df.shape)
    print("labels.shape: ", labels.shape)
    print("text_df_ngram.shape: ", text_df_ngram.shape)
    print()

    print("Starting RFE fit...")
    selector.fit(text_df_ngram, labels)
    print("RFE fit complete.\n")
    
    print("selector.n_features_: ", selector.n_features_)   
    print("selector.n_features_in_: ", selector.n_features_in_)
    print("selector.support_.shape: ", selector.support_.shape)

    return selector.support_

# %% [markdown]
# `RFE for unigrams`

# %%
estimator_rfe_1 = LogisticRegression(solver='saga', max_iter=100000)
selector_rfe_1 = RFE(estimator_rfe_1, step=0.1, n_features_to_select=30000)

# %%
rfe_1_feat_mask = fs_rfe(selector_rfe_1, rt_senti["reviewText"], rt_senti["sentiment"], ngram_range=(1,1))
rfe_1_feat_mask
# Out:
# text_df was vectorized using TF-IDF vectorizer with ngram_range:  (1, 1)
# text_df.shape:  (162758,)
# labels.shape:  (162758,)
# text_df_ngram.shape:  (162758, 64912)
#
# Starting RFE fit...
# RFE fit complete.
#
# selector.n_features_:  30000
# selector.n_features_in_:  64912
# selector.support_.shape:  (64912,)
# array([False, False,  True, ..., False,  True, False])

# %%
voc_1gram_rfe = list(compress(voc_1gram, rfe_1_feat_mask))
len(voc_1gram_rfe), voc_1gram_rfe[:10]
# Out:
# (30000,
#  ['movie',
#   'cast',
#   'like',
#   'party',
#   'guest',
#   'list',
#   'cinema',
#   'standard',
#   'schmaltz',
#   'creed'])

# %% [markdown]
# `RFE for bigrams`

# %%
estimator_rfe_2 = LogisticRegression(solver='saga', max_iter=100000)
selector_rfe_2 = RFE(estimator_rfe_2, step=0.1, n_features_to_select=50000)

# %%
rfe_2_feat_mask = fs_rfe(selector_rfe_2, rt_senti["reviewText"], rt_senti["sentiment"], ngram_range=(2,2))
rfe_2_feat_mask
# Out:
# text_df was vectorized using TF-IDF vectorizer with ngram_range:  (2, 2)
# text_df.shape:  (162758,)
# labels.shape:  (162758,)
# text_df_ngram.shape:  (162758, 1146211)
#
# Starting RFE fit...
# RFE fit complete.
#
# selector.n_features_:  50000
# selector.n_features_in_:  1146211
# selector.support_.shape:  (1146211,)
# array([False,  True, False, ..., False, False, False])

# %%
voc_2gram_rfe = list(compress(voc_2gram, rfe_2_feat_mask))
len(voc_2gram_rfe), voc_2gram_rfe[:10]
# Out:
# (50000,
#  ['selick movie',
#   'ii does',
#   'washed cinematography',
#   'cinematography ooze',
#   'just refreshing',
#   'unfussy form',
#   'story year',
#   '13 assassins',
#   'brown bag',
#   'quirky script'])

# %% [markdown]
# ## Final RFE-derived vocabulary

# %%
rfe_vocab = voc_1gram_rfe + voc_2gram_rfe
len(rfe_vocab), rfe_vocab[:10], rfe_vocab[-10:]
# Out:
# (80000,
#  ['movie',
#   'cast',
#   'like',
#   'party',
#   'guest',
#   'list',
#   'cinema',
#   'standard',
#   'schmaltz',
#   'creed'],
#  ['versus true',
#   'premise revels',
#   'wreak mindless',
#   'sort metaphor',
#   'tone danielle',
#   'danielle sleazy',
#   'meet properly',
#   'shaggy prairie',
#   'home class',
#   'families easily'])

# %%
## Test RFE obtained vocabulary in final pipeline (only with reviewText)  
# submit_v4(selected_model=LogisticRegression(C=5, solver="saga", max_iter=100000),
#           selected_features=rt_dict,
#           param_grid=None,
#           vocab=rfe_vocab)

# %% [markdown]
# ## Use rfe_vocab in final pipeline with all params

# %%
# submit_v4(selected_model=LogisticRegression(max_iter=100000),
#           selected_features=all_dict,
#           param_grid=param_grid,
#           vocab=rfe_vocab)

# %% [markdown]
# ## Submit_v2 for merged file models

# %%
# def submit_v2(selected_model=pipe_final, selected_features=None):
#     '''
#     Note that "selected_preprocessor" is already used within selected_model or pipeline
#     '''
#     # Retrain on the whole train.csv file  
#     merged = select_features(load_csv("train"), load_csv("movies"))
#     X_train = merged.drop(labels="sentiment", axis=1)
#     y_train = merged["sentiment"]
    
#     #Use selected features
#     if selected_features:
#         X_train = X_train[selected_features]
    
#     # Check1
#     print(X_train.shape)
#     print(X_train.head())
#     try:
#         print(selected_model.named_steps['model'].intercept_, selected_model.named_steps['model'].coef_)
#     except:
#         print("Model not trained yet!")
    
#     # Fit 
#     selected_model.fit(X_train, y_train)
    
#     # Check2
#     print(selected_model.named_steps['model'].intercept_, selected_model.named_steps['model'].coef_)
    
#     # Predict on test.csv file
#     merged_test = select_features(load_csv("test"), load_csv("movies"))
#     X_test = merged_test.copy()
#     if selected_features:
#         X_test = X_test[selected_features]
    
#     # Check3
#     print(X_test.shape)
#     print(X_test.head())
    
#     y_pred = selected_model.predict(X_test)
    
#     pred_df = pd.DataFrame(y_pred)
#     pred_df.columns = ["sentiment"]
#     pred_df.index.name = "id"
#     pred_df.to_csv("submission.csv")
    
#     return "Successfully created the submission file!!!"

# %%
#     X_test = merged_test.copy()
    
#     y_pred = pipe_best4.predict(X_test)
# #     np.unique(y_pred, return_counts=True)
#     pred_df = pd.DataFrame(y_pred)
#     pred_df.columns = ["sentiment"]
#     pred_df.index.name = "id"
#     pred_df.value_counts()

# %%
# X_test.columns

# %% [markdown]
# ### Uncomment to submit using v2 of submit function

# %%
# best4 = ["audienceScore", "rating", "isFrequentReviewer", "reviewText"]
# best4

# %%
# submit_v2(selected_model=pipe_RTonly, selected_features=['reviewText'])

# %% [markdown]
# ### Inspect the submission.csv file

# %%
# sub = pd.read_csv('submission.csv')
# sub.shape, sub.head()

# %%
# sub['sentiment'].value_counts()

# %% [markdown]
# ## submit_v3 for merged file models - does not retrain on whole data

# %%
# def submit_v3(selected_model=pipe_final):
#     '''
#     Note that "selected_preprocessor" is already used within selected_model or pipeline
#     '''
      
#     # Predict on test.csv file
#     merged_test = select_features(load_csv("test"), load_csv("movies"))
#     X_test = merged_test.copy()
    
#     X_test = X_test[["audienceScore", "rating", "isFrequentReviewer", "reviewText"]]    # This is a new line

    
#     y_pred = selected_model.predict(X_test)
    
#     pred_df = pd.DataFrame(y_pred)
#     pred_df.columns = ["sentiment"]
#     pred_df.index.name = "id"
#     pred_df.to_csv("submission.csv")
    
#     return "Successfully created the submission file!!!"

# %% [markdown]
# ### Uncomment to submit using v3 of submit function

# %%
# submit_v3(selected_model=pipe_best4)

# %% [markdown]
# ## Rough work

# %%
    # Predict on test.csv file
    merged_test = select_features(load_csv("test"), load_csv("movies"))
    X_test = merged_test.copy()
    
    X_test = X_test[["audienceScore", "rating", "isFrequentReviewer", "reviewText"]]    # This is a new line

# %%
# X_test.head()

# %%
# X_test['audienceScore'].describe()

# %%
# X_test['rating'].value_counts()

# %%
# X_test['isFrequentReviewer'].value_counts()

# %% [markdown]
# ## Implement KNN classifier

# %%
# from sklearn.neighbors import KNeighborsClassifier

# %%
# Note that we are borrowing "ct_final" column transformer from above

# %%
# pipe_knn = Pipeline(steps=[
#                         ("preprocessor", ct_final),
#                         ("model", KNeighborsClassifier())
#                     ])
# pipe_knn

# %%
# Train and predict on merged training data  
# split_train_predict(merged_train_features, merged_train_labels, pipe_knn, test_size=0.25, random_state=42)
