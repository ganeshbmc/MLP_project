# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

print('Imported')
# Out:
# Imported

# %%
with open('dummy_reviews.txt', 'r') as f:
    reviews = f.read()
type(reviews), len(reviews)
# Out:
# (str, 8277)

# %%
tfidf = TfidfVectorizer(ngram_range=(1,3), stop_words='english')
reviews_transformed = tfidf.fit_transform([reviews])
reviews_transformed.shape
# Out:
# (1, 1324)

# %%
sorted(list(tfidf.vocabulary_))
# Out:
# ['absolute',
#  'absolute masterpiece',
#  'absolute masterpiece plot',
#  'absolutely',
#  'absolutely incredible',
#  'absolutely incredible movie',
#  'absolutely loved',
#  'absolutely loved movie',
#  'absorbed',
#  'absorbed movie',
#  'absorbed movie plot',
#  'absorbed start',
#  'absorbed start finish',
#  'accents',
#  'accents special',
#  'accents special characters',
#  'accolades',
#  'accolades receiving',
#  'accolades receiving ve',
#  'achieve',
#  'achieve desired',
#  'achieve desired length',
#  'acting',
#  'acting amazing',
#  'acting amazing plot',
#  'acting incredible',
#  'acting incredible la',
#  'acting notch',
#  'acting notch plot',
#  'acting sorprendente',
#  'acting sorprendente la',
#  'action',
#  'action sequences',
#  'action sequences breathtaking',
#  'action sequences movie',
#  'action sequences pulse',
#  'action sequences simply',
#  'actors',
#  'actors delivered',
#  'actors delivered outstanding',
#  'added',
#  'added depth',
#  'added depth scene',
#  'added emoción',
#  'added emoción scenes',
#  'added emotion',
#  'added emotion scenes',
#  'admiration',
#  'admiration movies',
#  'admiration movies employing',
#  'amazing',
#  'amazing acting',
#  'amazing acting amazing',
#  'amazing acting incredible',
#  'amazing acting notch',
#  'amazing acting sorprendente',
#  'amazing plot',
#  'amazing plot simply',
#  'arcs',
#  'arcs deeply',
#  'arcs deeply moving',
#  'arcs profoundly',
#  'arcs profoundly moving',
#  'art',
#  'art narrative',
#  'art narrative captivating',
#  'aspect',
#  'aspect set',
#  'aspect set design',
#  'astonishing',
#  'astonishing film',
#  'astonishing film storytelling',
#  'astonishing musical',
#  'astonishing musical score',
#  'astute',
#  'astute special',
#  'astute special effects',
#  'astuto',
#  'astuto special',
#  'astuto special effects',
#  'atmosphere',
#  'atmosphere completely',
#  'atmosphere completely absorbed',
#  'attention',
#  'attention aspect',
#  'attention aspect set',
#  'attention evident',
#  'attention evident en',
#  'attention evident shot',
#  'authentic',
#  'authentic direction',
#  'authentic direction flawless',
#  'away',
#  'away film',
#  'away film storytelling',
#  'awe',
#  'awe inspiring',
#  'awe inspiring film',
#  'awe plot',
#  'awe plot intricacies',
#  'beginning',
#  'beginning end',
#  'beginning end unbelievable',
#  'beginning wow',
#  'beginning wow astonishing',
#  'believe',
#  'believe amazing',
#  'believe amazing acting',
#  'believe outstanding',
#  'believe outstanding movie',
#  'bending',
#  'bending character',
#  'bending character arcs',
#  'bending character development',
#  'bit',
#  'bit escéptico',
#  'bit escéptico movie',
#  'bit skeptical',
#  'bit skeptical movie',
#  'blowing',
#  'blowing couldn',
#  'blowing couldn high',
#  'blowing movie',
#  'blowing movie left',
#  'blowing music',
#  'blowing music created',
#  'blowing visuals',
#  'blowing visuals stunning',
#  'blown',
#  'blown away',
#  'blown away film',
#  'boggling',
#  'boggling character',
#  'boggling character arcs',
#  'breathtaking',
#  'breathtaking movie',
#  'breathtaking movie cinematic',
#  'breathtaking soundtrack',
#  'breathtaking soundtrack elevated',
#  'brilliance',
#  'brilliance movie',
#  'brilliance movie left',
#  'brilliant',
#  'brilliant dialogue',
#  'brilliant dialogue sharp',
#  'captivated',
#  'captivated movie',
#  'captivated movie kept',
#  'captivating',
#  'captivating characters',
#  'captivating characters real',
#  'captivating direction',
#  'captivating direction flawless',
#  'captivating emotionally',
#  'captivating emotionally resonant',
#  'captivating performances',
#  'captivating performances cast',
#  'cast',
#  'cast delivered',
#  'cast delivered powerful',
#  'cast exceptional',
#  'cast exceptional visual',
#  'cast performances',
#  'cast performances exceptional',
#  'cast performances outstanding',
#  'character',
#  'character arcs',
#  'character arcs deeply',
#  'character arcs profoundly',
#  'character depth',
#  'character depth remarkable',
#  'character development',
#  'character development impeccable',
#  'character development remarkable',
#  'character dynamics',
#  'character dynamics captivating',
#  'characters',
#  'characters developed',
#  'characters developed direction',
#  'characters felt',
#  'characters felt authentic',
#  'characters felt real',
#  'characters make',
#  'characters make emotionally',
#  'characters make feel',
#  'characters multi',
#  'characters multi dimensional',
#  'characters real',
#  'characters real direction',
#  'characters real felt',
#  'characters repetition',
#  'characters repetition achieve',
#  'characters vivid',
#  'characters vivid direction',
#  'choreography',
#  'choreography action',
#  'choreography action sequences',
#  'cinema',
#  'cinema storytelling',
#  'cinema storytelling gripping',
#  'cinema years',
#  'cinema years meticulous',
#  'cinematic',
#  'cinematic experience',
#  'cinematic experience narrative',
#  'cinematic marvel',
#  'cinematic marvel plot',
#  'cinematic masterpiece',
#  'cinematic masterpiece storyline',
#  'cinematography',
#  'cinematography stunning',
#  'cinematography stunning music',
#  'clever',
#  'clever astute',
#  'clever astute special',
#  'clever astuto',
#  'clever astuto special',
#  'clever special',
#  'clever special effects',
#  'compelling',
#  'compelling cast',
#  'compelling cast performances',
#  'completely',
#  'completely absorbed',
#  'completely absorbed movie',
#  'completely enganchado',
#  'completely enganchado start',
#  'completely engrossed',
#  'completely engrossed start',
#  'completely hooked',
#  'completely hooked desde',
#  'completely hooked start',
#  'completely immersed',
#  'completely immersed beginning',
#  'completely impresionado',
#  'completely impresionado writing',
#  'completely movie',
#  'completely movie true',
#  'completely won',
#  'completely won writing',
#  'complexity',
#  'complexity accents',
#  'complexity accents special',
#  'continue',
#  'continue replicate',
#  'continue replicate modify',
#  'contributes',
#  'contributes overall',
#  'contributes overall narrative',
#  'costume',
#  'costume remarkable',
#  'costume remarkable thoroughly',
#  'couldn',
#  'couldn action',
#  'couldn action sequences',
#  'couldn high',
#  'couldn high octane',
#  'count',
#  'crafted',
#  'crafted film',
#  'crafted film en',
#  'crafted piece',
#  'crafted piece cinema',
#  'crafted precision',
#  'crafted precision meticulous',
#  'craftsmanship',
#  'craftsmanship evident',
#  'craftsmanship evident frame',
#  'created',
#  'created perfect',
#  'created perfect atmosphere',
#  'dedication',
#  'dedication invested',
#  'dedication invested start',
#  'deeply',
#  'deeply moving',
#  'deeply moving visual',
#  'degrees',
#  'degrees language',
#  'degrees language complexity',
#  'delivered',
#  'delivered outstanding',
#  'delivered outstanding performances',
#  'delivered powerful',
#  'delivered powerful performances',
#  'depth',
#  'depth remarkable',
#  'depth remarkable direction',
#  'depth scene',
#  'depth scene hooked',
#  'desde',
#  'desde el',
#  'desde el principio',
#  'deserves',
#  'deserves accolades',
#  'deserves accolades receiving',
#  'deserves praise',
#  'deserves praise getting',
#  'deserves praise receiving',
#  'design',
#  'design costume',
#  'design costume remarkable',
#  'desired',
#  'desired length',
#  'desired length continue',
#  'developed',
#  'developed direction',
#  'developed direction impeccable',
#  'development',
#  'development impeccable',
#  'development impeccable direction',
#  'development remarkable',
#  'development remarkable cinematography',
#  'dialogue',
#  'dialogue clever',
#  'dialogue clever astute',
#  'dialogue clever astuto',
#  'dialogue sharp',
#  'dialogue sharp clever',
#  'dialogue sharp witty',
#  'dimensional',
#  'dimensional direction',
#  'dimensional direction masterful',
#  'direction',
#  'direction excellent',
#  'direction excellent scene',
#  'direction flawless',
#  'direction flawless scene',
#  'direction impeccable',
#  'direction impeccable scene',
#  'direction masterful',
#  'direction masterful scene',
#  'direction notch',
#  'direction notch scene',
#  'direction stunning',
#  'direction stunning scene',
#  'director',
#  'director vision',
#  'director vision shines',
#  'dropping',
#  'dropping soundtrack',
#  'dropping soundtrack enhanced',
#  'dynamics',
#  'dynamics captivating',
#  'dynamics captivating direction',
#  'eager',
#  'eager experience',
#  'eager experience initially',
#  'edge',
#  'edge characters',
#  'edge characters real',
#  'edge seat',
#  'edge seat blown',
#  'edge seat completely',
#  'edge seat start',
#  'effects',
#  'effects astonishing',
#  'effects astonishing musical',
#  'effects breathtaking',
#  'effects breathtaking soundtrack',
#  'effects jaw',
#  'effects jaw dropping',
#  'effects mind',
#  'effects mind blowing',
#  'effects otherworldly',
#  'effects otherworldly execution',
#  'effects short',
#  'effects short spectacular',
#  'effects world',
#  'effects world choreography',
#  'effects world couldn',
#  'el',
#  'el final',
#  'el final excitement',
#  'el principio',
#  'el principio hasta',
#  'elevated',
#  'elevated emotional',
#  'elevated emotional impact',
#  'emoción',
#  'emoción scenes',
#  'emoción scenes encantó',
#  'emotion',
#  'emotion scenes',
#  'emotion scenes absolutely',
#  'emotion scenes loved',
#  'emotional',
#  'emotional impact',
#  'emotional impact scene',
#  'emotional journey',
#  'emotional journey took',
#  'emotional resonance',
#  'emotional resonance scene',
#  'emotional rollercoaster',
#  'emotional rollercoaster like',
#  'emotionally',
#  'emotionally invested',
#  'emotionally invested direction',
#  'emotionally resonant',
#  'emotionally resonant director',
#  'emphasizes',
#  'emphasizes excitement',
#  'emphasizes excitement admiration',
#  'employing',
#  'employing varying',
#  'employing varying degrees',
#  'en',
#  'en frame',
#  'en frame performances',
#  'en mucho',
#  'en mucho tiempo',
#  'encantó',
#  'encantó completely',
#  'encantó completely movie',
#  'encountered',
#  'encountered crafted',
#  'encountered crafted piece',
#  'end',
#  'end unbelievable',
#  'end unbelievable movie',
#  'engaging',
#  'engaging los',
#  'engaging los characters',
#  'engaging visual',
#  'engaging visual effects',
#  'enganchado',
#  'enganchado start',
#  'enganchado start finish',
#  'engrossed',
#  'engrossed start',
#  'engrossed start finish',
#  'engrossed story',
#  'engrossed story incredible',
#  'engrossing',
#  'engrossing character',
#  'engrossing character development',
#  'enhanced',
#  'enhanced emotional',
#  'enhanced emotional resonance',
#  'enthralled',
#  'enthralled start',
#  'enthralled start wow',
#  'enthralling',
#  'enthralling characters',
#  'enthralling characters developed',
#  'escéptico',
#  'escéptico movie',
#  'escéptico movie left',
#  'evident',
#  'evident en',
#  'evident en frame',
#  'evident frame',
#  'evident frame cast',
#  'evident shot',
#  'evident shot performances',
#  'exceeded',
#  'exceeded expectations',
#  'exceeded expectations writing',
#  'excellent',
#  'excellent scene',
#  'excellent scene keeps',
#  'exceptional',
#  'exceptional completely',
#  'exceptional completely immersed',
#  'exceptional dialogue',
#  'exceptional dialogue sharp',
#  'exceptional planning',
#  'exceptional planning multiple',
#  'exceptional visual',
#  'exceptional visual effects',
#  'excitement',
#  'excitement admiration',
#  'excitement admiration movies',
#  'excitement movie',
#  'excitement movie unparalleled',
#  'execution',
#  'execution action',
#  'execution action sequences',
#  'expectations',
#  'expectations writing',
#  'expectations writing brilliant',
#  'experience',
#  'experience initially',
#  'experience initially unsure',
#  'experience narrative',
#  'experience narrative captivating',
#  'experienced',
#  'experienced emotional',
#  'experienced emotional rollercoaster',
#  'feel',
#  'feel like',
#  'feel like know',
#  'felt',
#  'felt authentic',
#  'felt authentic direction',
#  'felt like',
#  'felt like knew',
#  'felt real',
#  'felt real direction',
#  'fenomenal',
#  'fenomenal dialogue',
#  'fenomenal dialogue clever',
#  'film',
#  'film crafted',
#  'film crafted precision',
#  'film en',
#  'film en mucho',
#  'film hard',
#  'film hard words',
#  'film storytelling',
#  'film storytelling compelling',
#  'film storytelling superb',
#  'film true',
#  'film true gem',
#  'film true triumph',
#  'film true work',
#  'filmmakers',
#  'filmmakers dedication',
#  'filmmakers dedication invested',
#  'final',
#  'final excitement',
#  'final excitement movie',
#  'finish',
#  'finish absolutely',
#  'finish absolutely incredible',
#  'finish believe',
#  'finish believe outstanding',
#  'finish guau',
#  'finish guau movie',
#  'finish incredible',
#  'finish incredible movie',
#  'finish mind',
#  'finish mind blowing',
#  'finish wow',
#  'finish wow incredible',
#  'flawless',
#  'flawless scene',
#  'flawless scene invested',
#  'flawless scene testament',
#  'frame',
#  'frame cast',
#  'frame cast delivered',
#  'frame cast performances',
#  'frame performances',
#  'frame performances outstanding',
#  'gem',
#  'gem narrative',
#  'gem narrative spellbinding',
#  'gem plot',
#  'gem plot captivating',
#  'getting',
#  'getting haven',
#  'getting haven seen',
#  'glued',
#  'glued seat',
#  'glued seat completely',
#  'grabs',
#  'grabs characters',
#  'grabs characters make',
#  'gripping',
#  'gripping character',
#  'gripping character depth',
#  'gripping characters',
#  'gripping characters felt',
#  'guau',
#  'guau movie',
#  'guau movie believe',
#  'guessing',
#  'guessing character',
#  'guessing character dynamics',
#  'hard',
#  'hard words',
#  'hard words amazing',
#  'hasta',
#  'hasta el',
#  'hasta el final',
#  'haven',
#  'haven encountered',
#  'haven encountered crafted',
#  'haven seen',
#  'haven seen crafted',
#  'heightened',
#  'heightened emotional',
#  'heightened emotional impact',
#  'high',
#  'high octane',
#  'high octane action',
#  'honestly',
#  'honestly bit',
#  'honestly bit escéptico',
#  'honestly bit skeptical',
#  'hooked',
#  'hooked beginning',
#  'hooked beginning wow',
#  'hooked desde',
#  'hooked desde el',
#  'hooked opening',
#  'hooked opening scene',
#  'hooked start',
#  'hooked start finish',
#  'immersed',
#  'immersed beginning',
#  'immersed beginning end',
#  'impact',
#  'impact scene',
#  'impact scene planning',
#  'impact scene wait',
#  'impeccable',
#  'impeccable direction',
#  'impeccable direction masterful',
#  'impeccable scene',
#  'impeccable scene captivated',
#  'impresionado',
#  'impresionado writing',
#  'impresionado writing fenomenal',
#  'impresionantes',
#  'impresionantes la',
#  'impresionantes la music',
#  'incredible',
#  'incredible cinematic',
#  'incredible cinematic experience',
#  'incredible la',
#  'incredible la plot',
#  'incredible movie',
#  'incredible movie believe',
#  'incredible movie deserves',
#  'incredible plot',
#  'incredible plot grabs',
#  'incredible visuals',
#  'incredible visuals impresionantes',
#  'incredible visuals stunning',
#  'incredibly',
#  'incredibly engaging',
#  'incredibly engaging visual',
#  'increíble',
#  'increíble believe',
#  'increíble believe amazing',
#  'initially',
#  'initially unsure',
#  'initially unsure movie',
#  'inspiring',
#  'inspiring film',
#  'inspiring film true',
#  'intricacies',
#  'intricacies mind',
#  'intricacies mind boggling',
#  'intricacies plot',
#  'intricacies plot mind',
#  'intricate',
#  'intricate characters',
#  'intricate characters multi',
#  'intrigued',
#  'intrigued characters',
#  'intrigued characters make',
#  'intriguing',
#  'intriguing characters',
#  'intriguing characters vivid',
#  'invested',
#  'invested direction',
#  'invested direction masterful',
#  'invested emotional',
#  'invested emotional journey',
#  'invested start',
#  'invested start finish',
#  'jaw',
#  'jaw dropping',
#  'jaw dropping soundtrack',
#  'journey',
#  'journey took',
#  'journey took unforgettable',
#  'keeps',
#  'keeps edge',
#  'keeps edge seat',
#  'keeps glued',
#  'keeps glued seat',
#  'keeps intrigued',
#  'keeps intrigued characters',
#  'keeps suspense',
#  'keeps suspense totally',
#  'kept',
#  'kept edge',
#  'kept edge characters',
#  'kept edge seat',
#  'kept guessing',
#  'kept guessing character',
#  'knew',
#  'knew honestly',
#  'knew honestly bit',
#  'know',
#  'know direction',
#  'know direction stunning',
#  'la',
#  'la music',
#  'la music added',
#  'la plot',
#  'la plot mind',
#  'la plot simply',
#  'language',
#  'language complexity',
#  'language complexity accents',
#  'left',
#  'left awe',
#  'left awe plot',
#  'left completely',
#  'left completely impresionado',
#  'left speechless',
#  'left speechless experienced',
#  'left speechless intricacies',
#  'left speechless writing',
#  'length',
#  'length continue',
#  'length continue replicate',
#  'like',
#  'like knew',
#  'like knew honestly',
#  'like know',
#  'like know direction',
#  'like twists',
#  'like twists turns',
#  'los',
#  'los characters',
#  'los characters felt',
#  'loved',
#  'loved completely',
#  'loved completely movie',
#  'loved movie',
#  'loved movie masterpiece',
#  'make',
#  'make emotionally',
#  'make emotionally invested',
#  'make feel',
#  'make feel like',
#  'marvel',
#  'marvel plot',
#  'marvel plot engrossing',
#  'masterful',
#  'masterful scene',
#  'masterful scene contributes',
#  'masterful scene keeps',
#  'masterful scene masterpiece',
#  'masterpiece',
#  'masterpiece edge',
#  'masterpiece edge seat',
#  'masterpiece plot',
#  'masterpiece plot captivating',
#  'masterpiece plot keeps',
#  'masterpiece story',
#  'masterpiece story engaging',
#  'masterpiece storyline',
#  'masterpiece storyline enthralling',
#  'masterpiece storytelling',
#  'masterpiece storytelling plot',
#  'meaningful',
#  'meaningful way',
#  'meaningful way hooked',
#  'meticulous',
#  'meticulous attention',
#  'meticulous attention evident',
#  'meticulous craftsmanship',
#  'meticulous craftsmanship evident',
#  'mind',
#  'mind bending',
#  'mind bending character',
#  'mind blowing',
#  'mind blowing couldn',
#  'mind blowing movie',
#  'mind blowing music',
#  'mind blowing visuals',
#  'mind boggling',
#  'mind boggling character',
#  'modify',
#  'modify patterns',
#  'modify patterns reach',
#  'movie',
#  'movie absolute',
#  'movie absolute masterpiece',
#  'movie believe',
#  'movie believe amazing',
#  'movie cinematic',
#  'movie cinematic marvel',
#  'movie completely',
#  'movie completely won',
#  'movie deserves',
#  'movie deserves accolades',
#  'movie deserves praise',
#  'movie exceeded',
#  'movie exceeded expectations',
#  'movie incredible',
#  'movie incredible plot',
#  'movie kept',
#  'movie kept edge',
#  'movie left',
#  'movie left awe',
#  'movie left completely',
#  'movie left speechless',
#  'movie masterpiece',
#  'movie masterpiece story',
#  'movie plot',
#  'movie plot intricate',
#  'movie proved',
#  'movie proved wrong',
#  'movie story',
#  'movie story gripping',
#  'movie true',
#  'movie true gem',
#  'movie true masterpiece',
#  'movie unparalleled',
#  'movie unparalleled plot',
#  'movies',
#  'movies employing',
#  'movies employing varying',
#  'moving',
#  'moving visual',
#  'moving visual effects',
#  'mucho',
#  'mucho tiempo',
#  'mucho tiempo attention',
#  'multi',
#  'multi dimensional',
#  'multi dimensional direction',
#  'multiple',
#  'multiple viewings',
#  'multiple viewings brilliance',
#  'music',
#  'music added',
#  'music added depth',
#  'music added emoción',
#  'music added emotion',
#  'music created',
#  'music created perfect',
#  'musical',
#  'musical score',
#  'musical score heightened',
#  'narrative',
#  'narrative captivating',
#  'narrative captivating emotionally',
#  'narrative captivating performances',
#  'narrative meaningful',
#  'narrative meaningful way',
#  'narrative significant',
#  'narrative significant way',
#  'narrative spellbinding',
#  'narrative spellbinding performances',
#  'notch',
#  'notch plot',
#  'notch plot incredibly',
#  'notch scene',
#  'notch scene contributes',
#  'notch scene edge',
#  'notch scene keeps',
#  'octane',
#  'octane action',
#  'octane action sequences',
#  'opening',
#  'opening scene',
#  'opening scene film',
#  'oscar',
#  'oscar worthy',
#  'oscar worthy attention',
#  'otherworldly',
#  'otherworldly execution',
#  'otherworldly execution action',
#  'outstanding',
#  'outstanding movie',
#  'outstanding movie story',
#  'outstanding performances',
#  'outstanding performances visual',
#  'outstanding planning',
#  'outstanding planning watch',
#  'outstanding visual',
#  'outstanding visual effects',
#  'overall',
#  'overall narrative',
#  'overall narrative meaningful',
#  'overall narrative significant',
#  'patterns',
#  'patterns reach',
#  'patterns reach target',
#  'película',
#  'película increíble',
#  'película increíble believe',
#  'perfect',
#  'perfect atmosphere',
#  'perfect atmosphere completely',
#  'performances',
#  'performances cast',
#  'performances cast exceptional',
#  'performances exceptional',
#  'performances exceptional completely',
#  'performances exceptional planning',
#  'performances oscar',
#  'performances oscar worthy',
#  'performances outstanding',
#  'performances outstanding planning',
#  'performances outstanding visual',
#  'performances planning',
#  'performances planning second',
#  'performances visual',
#  'performances visual effects',
#  'phenomenal',
#  'phenomenal dialogue',
#  'phenomenal dialogue clever',
#  'piece',
#  'piece cinema',
#  'piece cinema years',
#  'planning',
#  'planning film',
#  'planning film true',
#  'planning multiple',
#  'planning multiple viewings',
#  'planning second',
#  'planning second viewing',
#  'planning watch',
#  'planning watch honestly',
#  'planning watch wow',
#  'plot',
#  'plot captivating',
#  'plot captivating characters',
#  'plot engrossing',
#  'plot engrossing character',
#  'plot grabs',
#  'plot grabs characters',
#  'plot incredibly',
#  'plot incredibly engaging',
#  'plot intricacies',
#  'plot intricacies mind',
#  'plot intricate',
#  'plot intricate characters',
#  'plot intriguing',
#  'plot intriguing characters',
#  'plot keeps',
#  'plot keeps intrigued',
#  'plot kept',
#  'plot kept edge',
#  'plot mind',
#  'plot mind bending',
#  'plot mind blowing',
#  'plot simply',
#  'plot simply incredible',
#  'plot twists',
#  'plot twists kept',
#  'plot twists mind',
#  'pounding',
#  'pounding special',
#  'pounding special effects',
#  'powerful',
#  'powerful performances',
#  'powerful performances planning',
#  'praise',
#  'praise getting',
#  'praise getting haven',
#  'praise receiving',
#  'praise receiving haven',
#  'precision',
#  'precision meticulous',
#  'precision meticulous attention',
#  'principio',
#  'principio hasta',
#  'principio hasta el',
#  'profoundly',
#  'profoundly moving',
#  'profoundly moving visual',
#  'proved',
#  'proved wrong',
#  'proved wrong plot',
#  'pulse',
#  'pulse pounding',
#  'pulse pounding special',
#  'reach',
#  'reach target',
#  'reach target word',
#  'real',
#  'real direction',
#  'real direction notch',
#  'real felt',
#  'real felt like',
#  'receiving',
#  'receiving haven',
#  'receiving haven encountered',
#  'receiving ve',
#  'receiving ve seen',
#  'remarkable',
#  'remarkable cinematography',
#  'remarkable cinematography stunning',
#  'remarkable direction',
#  'remarkable direction notch',
#  'remarkable thoroughly',
#  'remarkable thoroughly engrossed',
#  'repetition',
#  'repetition achieve',
#  'repetition achieve desired',
#  'replicate',
#  'replicate modify',
#  'replicate modify patterns',
#  'resonance',
#  'resonance scene',
#  'resonance scene eager',
#  'resonant',
#  'resonant director',
#  'resonant director vision',
#  ...]
