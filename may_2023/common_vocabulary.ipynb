# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
from itertools import compress

from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.compose import ColumnTransformer
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.preprocessing import FunctionTransformer
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OneHotEncoder, LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.svm import LinearSVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.decomposition import PCA, TruncatedSVD
from sklearn.feature_selection import RFECV
from sklearn.feature_selection import RFE

import scipy.stats as stats
print("Imports done.")
# Out:
# Imports done.

# %% [markdown]
# ### Custom functions

# %%
def load_csv(filename: str):
    df = pd.read_csv(f"data/{filename}.csv")
    return df

# %%
def inspect(df: pd.DataFrame):
    print(f"Shape of the dataframe: {df.shape}")
    print()
    print(f"Columns in the dataframe:\n{df.columns}")
    print()
    print(f"{df.info()}")
    print()
    # print(f"Summary: {df.describe()}")
    print(f"Missing values:\n{df.isna().sum()}")
    return

# %%
def name_fl(name):
    l = name.split()
    n = ' '.join((l[0], l[-1]))
    return n

# %%
def select_features(df: pd.DataFrame, moviesdf: pd.DataFrame):
    '''
    This function merges the given dataframes. Note that the first df must be "train" or "test" and
    the second df should be "movies".
    Note: Sentiment column is present only in "train.csv" file and not "test.csv" file.
    '''
    
    # Drop duplicates from moviesdf
#     movies_unique = moviesdf.drop_duplicates(subset=["movieid"])
    # Drop duplicates using groupby - clubs similar rows and fills in missing values better
    movies_unique = moviesdf.fillna(value=np.nan).groupby("movieid").first()

    # Merge df and movies_unique
    df_merged = pd.merge(df, movies_unique, on="movieid", how='left')
    
    # Rename "isTopCritic" column, if it exists, to "isFrequentReviewer"
    df_merged.rename(columns={"isTopCritic": "isFrequentReviewer"}, inplace=True)
    
    # Drop columns
    df_merged = df_merged.drop(columns=["title", "ratingContents", "releaseDateTheaters", "releaseDateStreaming", "distributor", "soundType"])

    # Fill missing values in "reviewText" with empty string
    final = df_merged.copy()
    final["reviewYN"] = np.where(final["reviewText"].isnull(), 1, 0)    # Feature engineering - adding a new column
    final["reviewWC"] = final.apply(lambda x: len(str(x["reviewText"]).split()), axis=1)    # Feature engineering - adding second new column
    final["reviewText"] = final["reviewText"].fillna("neutral")
    
    # Fill missing values in "rating", "genre", original columns with the word "Unknown"
    final["rating"] = final["rating"].fillna("Unknown")
    final["genre"] = final["genre"].fillna("Unknown")
    final["originalLanguage"] = final["originalLanguage"].fillna("Unknown")

    # Impute missing values for "audienceScore" and "runtimeMinutes" columns
    final["audienceScore"] = final["audienceScore"].fillna(final["audienceScore"].mean())
    final["runtimeMinutes"] = final["runtimeMinutes"].fillna(final["runtimeMinutes"].median())
    
    # Preprocess and impute missing values in "boxOffice" column
    final["boxOffice"] = final["boxOffice"].str[1:]
    final["boxOffice"] = final["boxOffice"].replace(to_replace={"M": "*1000000", "K": "*1000"}, regex=True)
    final["boxOffice"] = final["boxOffice"].loc[final["boxOffice"].notnull()].apply(lambda x: eval(str(x)))
    final["boxOffice"] = final["boxOffice"].fillna(final["boxOffice"].median())
    # (Optional) Replace outliers in boxOffice with median
    median = final["boxOffice"].describe()['50%']
    iqr = final["boxOffice"].describe()['75%'] - final["boxOffice"].describe()['25%']
    ll = median - (1.5*iqr)
    ul = median + (1.5*iqr)
    final.loc[final["boxOffice"] > ul, "boxOffice"] = median
    
    # Clean language names
    final["originalLanguage"].replace({"English (United Kingdom)": "English", 
                                            "English (Australia)" : "English",
                                            "French (France)": "French", 
                                            "French (Canada)": "French",
                                            "Portuguese (Brazil)": "Portuguese",
                                            "Spanish (Spain)": "Spanish"},                                         
                                            inplace=True)
    
    # Clean reviewerName column
    pre_post_fixes = {"Mr. ": "", "Mrs. ": "", "Ms. ": "", "Dr. ": "", 
                      " MD": "", " DDS": "", " DVM": "", " Jr.": "", " PhD": "", " II": "", " IV": ""}
    final["reviewerName"] = final["reviewerName"].replace(pre_post_fixes, regex=True)
    final["reviewerName"] = final["reviewerName"].apply(name_fl)

    return final

# %%
merged = select_features(load_csv("train"), load_csv("movies"))
inspect(merged)
# Out:
# Shape of the dataframe: (162758, 14)
#
# Columns in the dataframe:
# Index(['movieid', 'reviewerName', 'isFrequentReviewer', 'reviewText',
#        'sentiment', 'audienceScore', 'rating', 'runtimeMinutes', 'genre',
#        'originalLanguage', 'director', 'boxOffice', 'reviewYN', 'reviewWC'],
#       dtype='object')
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 162758 entries, 0 to 162757
# Data columns (total 14 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   movieid             162758 non-null  object
#  1   reviewerName        162758 non-null  object
#  2   isFrequentReviewer  162758 non-null  bool
#  3   reviewText          162758 non-null  object
#  4   sentiment           162758 non-null  object
#  5   audienceScore       162758 non-null  float64
#  6   rating              162758 non-null  object
#  7   runtimeMinutes      162758 non-null  float64
#  8   genre               162758 non-null  object
#  9   originalLanguage    162758 non-null  object
#  10  director            162758 non-null  object
#  11  boxOffice           162758 non-null  float64
#  12  reviewYN            162758 non-null  int32
#  13  reviewWC            162758 non-null  int64
# dtypes: bool(1), float64(3), int32(1), int64(1), object(8)
# memory usage: 16.9+ MB
# None
#
# Missing values:
# movieid               0
# reviewerName          0
# isFrequentReviewer    0
# reviewText            0
# sentiment             0
# audienceScore         0
# rating                0
# runtimeMinutes        0
# genre                 0
# originalLanguage      0
# director              0
# boxOffice             0
# reviewYN              0
# reviewWC              0
# dtype: int64

# %%
merged_test = select_features(load_csv("test"), load_csv("movies"))
inspect(merged_test)
# Out:
# Shape of the dataframe: (55315, 13)
#
# Columns in the dataframe:
# Index(['movieid', 'reviewerName', 'isFrequentReviewer', 'reviewText',
#        'audienceScore', 'rating', 'runtimeMinutes', 'genre',
#        'originalLanguage', 'director', 'boxOffice', 'reviewYN', 'reviewWC'],
#       dtype='object')
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 55315 entries, 0 to 55314
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   movieid             55315 non-null  object
#  1   reviewerName        55315 non-null  object
#  2   isFrequentReviewer  55315 non-null  bool
#  3   reviewText          55315 non-null  object
#  4   audienceScore       55315 non-null  float64
#  5   rating              55315 non-null  object
#  6   runtimeMinutes      55315 non-null  float64
#  7   genre               55315 non-null  object
#  8   originalLanguage    55315 non-null  object
#  9   director            55315 non-null  object
#  10  boxOffice           55315 non-null  float64
#  11  reviewYN            55315 non-null  int32
#  12  reviewWC            55315 non-null  int64
# dtypes: bool(1), float64(3), int32(1), int64(1), object(7)
# memory usage: 5.3+ MB
# None
#
# Missing values:
# movieid               0
# reviewerName          0
# isFrequentReviewer    0
# reviewText            0
# audienceScore         0
# rating                0
# runtimeMinutes        0
# genre                 0
# originalLanguage      0
# director              0
# boxOffice             0
# reviewYN              0
# reviewWC              0
# dtype: int64

# %% [markdown]
# ## Work on vocabulary

# %%
rt_senti = merged[["reviewText", "sentiment"]].copy()
rt_senti.shape, rt_senti.head()
# Out:
# ((162758, 2),
#                                            reviewText sentiment
#  0  Henry Selick’s first movie since 2009’s Corali...  POSITIVE
#  1  With a cast that reads like the Vogue Oscar pa...  NEGATIVE
#  2  Creed II does not give us anything but another...  POSITIVE
#  3  I know what you're thinking, but this is no Li...  POSITIVE
#  4  Director Fernando Meirelles tells the story wi...  POSITIVE)

# %%
# Duplicate reviewText column to reviewText_2
# rt22 = rt_senti.copy()
# rt22['reviewText_2'] = rt22['reviewText']
# rt22.head()
# Out:
#                                           reviewText sentiment  \
# 0  Henry Selick’s first movie since 2009’s Corali...  POSITIVE
# 1  With a cast that reads like the Vogue Oscar pa...  NEGATIVE
# 2  Creed II does not give us anything but another...  POSITIVE
# 3  I know what you're thinking, but this is no Li...  POSITIVE
# 4  Director Fernando Meirelles tells the story wi...  POSITIVE
#
#                                         reviewText_2
# 0  Henry Selick’s first movie since 2009’s Corali...
# 1  With a cast that reads like the Vogue Oscar pa...
# 2  Creed II does not give us anything but another...
# 3  I know what you're thinking, but this is no Li...
# 4  Director Fernando Meirelles tells the story wi...

# %%
rt_test = pd.DataFrame(merged_test["reviewText"].copy())
rt_test.shape, rt_test.head()
# Out:
# ((55315, 1),
#                                            reviewText
#  0  Green slowly cranks up the dread with style an...
#  1  Philip Noyce's direction is elegant and unforc...
#  2  It wouldn't do to say what path Maria ultimate...
#  3  Pig is not exactly the arthouse John Wick that...
#  4  An imaginative no-budget musical of sorts abou...)

# %%
def get_vocab(text_df, ngram_range=(1,1), strip_accents='unicode'):
    print(f"Generating vocabulary for ngram_range: {ngram_range}...")
    tvec1 = TfidfVectorizer(ngram_range=ngram_range, stop_words='english')
    tvec1.fit(text_df)
    voc_ngram = list(tvec1.vocabulary_.keys())
    return voc_ngram

# %%
def get_common_vocab(df_list: list, ngram_range_list: list, strip_accents='unicode'):
    """
    Get common vocabulary from a list of dataframes.
    """
    # Get vocabulary from each dataframe for a given ngram-range
    for ngram_range in ngram_range_list:
        vocab_ngram = set()
        for df in df_list:
            vocab_ngram_df = set(get_vocab(df['reviewText'], ngram_range))
            print(f"Vocabulary for ngram-range {ngram_range} in df: {len(vocab_ngram_df)}")
            if vocab_ngram:
                vocab_ngram = vocab_ngram.intersection(vocab_ngram_df)
            else:
                vocab_ngram = vocab_ngram_df
        print(f"Common vocabulary for ngram-range {ngram_range}: {len(vocab_ngram)}")   
    return vocab_ngram

# %%
common_unigrams = get_common_vocab([rt_senti, rt_test], ngram_range_list=[(1,1)])
common_unigrams
# Out:
# Generating vocabulary for ngram_range: (1, 1)...
# Vocabulary for ngram-range (1, 1) in df: 64912
# Generating vocabulary for ngram_range: (1, 1)...
# Vocabulary for ngram-range (1, 1) in df: 43588
# Common vocabulary for ngram-range (1, 1): 35946
# {'bikers',
#  'antidote',
#  'starry',
#  'honored',
#  'frantic',
#  'adding',
#  'steinbauer',
#  'downton',
#  'toilets',
#  'pictorial',
#  'rothman',
#  'longings',
#  'robson',
#  'discourage',
#  'sasquatch',
#  'ooey',
#  'subconscious',
#  'awakening',
#  'narrating',
#  'retrieval',
#  'lensed',
#  'undistinguished',
#  'amazing',
#  'abyss',
#  'doubled',
#  'looksee',
#  'streetdance',
#  'progenitor',
#  'uninterested',
#  'reductio',
#  'kasper',
#  'gram',
#  'ersatz',
#  'voiceover',
#  'criminalizing',
#  'nazi',
#  'wigs',
#  'floating',
#  'tinha',
#  'blossom',
#  'mobius',
#  'ec',
#  'purview',
#  'babe',
#  'alps',
#  'rooftops',
#  'mueller',
#  'loftiest',
#  'crammed',
#  'krieger',
#  'hellraiser',
#  'docu',
#  'appropriating',
#  'addled',
#  'lumbers',
#  'chai',
#  'fresno',
#  'distribution',
#  'modernized',
#  'orcas',
#  'desk',
#  'goldsworthy',
#  'clique',
#  'bombast',
#  'iliza',
#  'athletes',
#  'immortals',
#  'daylights',
#  'ss',
#  'mercedes',
#  'kyle',
#  'komandarev',
#  'amarrar',
#  'presently',
#  'mackenzie',
#  'obstreperous',
#  'alphabet',
#  'agreed',
#  'servicing',
#  'sassoon',
#  'roiling',
#  'organized',
#  'contributes',
#  'solidarity',
#  'gallo',
#  'gawk',
#  'erasure',
#  'conversion',
#  'scrambling',
#  'huff',
#  'diverse',
#  'contexts',
#  'wheelers',
#  'interminable',
#  'bolton',
#  'nanosecond',
#  'bosoms',
#  'afterglow',
#  'lavished',
#  'fennell',
#  'northam',
#  'overplay',
#  'joke',
#  'golfer',
#  'mrs',
#  'squirt',
#  'pitts',
#  'dreading',
#  'beane',
#  'gosnell',
#  'yuletide',
#  'endgame',
#  'decapitation',
#  'favorite',
#  'palo',
#  'upstate',
#  'colombia',
#  'debated',
#  'legitimacy',
#  'sulks',
#  'boneheaded',
#  'internationally',
#  'bening',
#  'limitation',
#  'feistiness',
#  'grates',
#  'modigliani',
#  'lures',
#  'researched',
#  'pumpkin',
#  'spiffy',
#  'collusion',
#  'projected',
#  'looniness',
#  'euphoria',
#  'surefire',
#  'ahadi',
#  'messaging',
#  'bravura',
#  'pentagon',
#  'afflictions',
#  'scarlet',
#  'fetishism',
#  'swingin',
#  'scanlon',
#  'pinpricks',
#  'bodycount',
#  'pressing',
#  'scooters',
#  'adversary',
#  'portman',
#  'poof',
#  'rejuvenation',
#  'geometry',
#  'quinton',
#  'troubles',
#  'gaspar',
#  'sept',
#  'democracy',
#  'bets',
#  'flipping',
#  '17',
#  'cannily',
#  'flavored',
#  'burrowing',
#  'últimos',
#  'balthazar',
#  'slogan',
#  'asian',
#  'visibility',
#  'hiatus',
#  'jigsaw',
#  'transformer',
#  'interfaith',
#  'grandiosely',
#  'splendors',
#  'lymelife',
#  'buttress',
#  'intrusions',
#  'sentimentality',
#  'clausen',
#  'thurber',
#  'habitat',
#  'cedar',
#  'bonding',
#  'banality',
#  'breakthroughs',
#  'conformar',
#  'masochists',
#  'traveled',
#  'snazzy',
#  'maja',
#  'manipulation',
#  'member',
#  '1990',
#  'twee',
#  'eliminated',
#  'angrily',
#  'contributions',
#  'independent',
#  'packet',
#  'rushed',
#  'eminem',
#  'unreliability',
#  'barmy',
#  'scariness',
#  'aforementioned',
#  'dubya',
#  'observed',
#  'focal',
#  'tambien',
#  'tem',
#  'purge',
#  'value',
#  'snug',
#  'accessorized',
#  'uncorks',
#  'saloum',
#  'undiminished',
#  'changer',
#  'mitchum',
#  'myles',
#  'tammy',
#  'depth',
#  'countdown',
#  'cleavage',
#  'klute',
#  'dario',
#  'szifrón',
#  'soiled',
#  'kiarostami',
#  'cozily',
#  'complain',
#  'inexperience',
#  '231',
#  '2016',
#  'void',
#  'trans',
#  'hire',
#  'empress',
#  'helpfully',
#  'crystallize',
#  'signposts',
#  'dyed',
#  'answering',
#  'achieve',
#  'animator',
#  'demeaning',
#  'cops',
#  'punchy',
#  'glows',
#  'irt',
#  'derki',
#  'com',
#  'scratchingly',
#  'petey',
#  'hüller',
#  'earliest',
#  'costa',
#  'saks',
#  'juste',
#  'operating',
#  'hoists',
#  'swoon',
#  'hefty',
#  'benefits',
#  'bromides',
#  'brainwashing',
#  'crankiest',
#  'windfall',
#  'schneider',
#  'carnation',
#  'margot',
#  'newbie',
#  'marte',
#  '1989',
#  'eric',
#  'woundingly',
#  'debauched',
#  'planes',
#  'idiotically',
#  'flimflam',
#  'napoleonic',
#  'bombay',
#  'takeshi',
#  'contemporaneous',
#  'bogdanovich',
#  'rosendahl',
#  'messiahs',
#  'hot',
#  'wobbly',
#  'bacurau',
#  'presidency',
#  'spectators',
#  'debuts',
#  'applauded',
#  'superfans',
#  'kassim',
#  'sock',
#  'gibran',
#  'eulogize',
#  'capstone',
#  'historian',
#  'shed',
#  'catastrophe',
#  'abashed',
#  'truffault',
#  'duvall',
#  'impressionistic',
#  'launching',
#  'twinkie',
#  'sheik',
#  'zodiac',
#  'fatuous',
#  'cutouts',
#  'baran',
#  'rear',
#  'scale',
#  'inconsistent',
#  'cloth',
#  'tweedy',
#  'cult',
#  'intertwines',
#  'popped',
#  'southpaw',
#  'industrious',
#  'gen',
#  'robards',
#  'oy',
#  'miscreants',
#  'hate',
#  'microscopic',
#  'gobs',
#  'scor',
#  'sane',
#  'governance',
#  'gauging',
#  'novella',
#  'andie',
#  'toting',
#  'varied',
#  'snatchers',
#  'tao',
#  'india',
#  'aspiration',
#  'fully',
#  'brad',
#  'bailed',
#  'acres',
#  'loyal',
#  'hitman',
#  'vrias',
#  'afterschool',
#  'thugs',
#  'harrelson',
#  'babadook',
#  'hue',
#  'harrill',
#  'intimidation',
#  'warning',
#  'pluck',
#  'cylinders',
#  'crackerjack',
#  'outfoxed',
#  'farmhouse',
#  'zippiest',
#  'warming',
#  'sorte',
#  'amazement',
#  'bader',
#  'chair',
#  'untainted',
#  'miniscule',
#  'hideout',
#  'duplicity',
#  'maximilian',
#  'editions',
#  'agitated',
#  'quieter',
#  'mandalorian',
#  'apathetic',
#  'xander',
#  'concocts',
#  'synchronicity',
#  'papadimitropoulos',
#  'semblance',
#  'hurl',
#  'witness',
#  'conduit',
#  'poptimist',
#  'camalier',
#  'apace',
#  'personable',
#  'niceness',
#  'mayer',
#  '47',
#  'institutions',
#  'zay',
#  'unintentional',
#  'communal',
#  'potency',
#  'sir',
#  'sf',
#  'reverberations',
#  'ridiculously',
#  '2001',
#  'colours',
#  'variables',
#  'selby',
#  'claude',
#  'decay',
#  'deodato',
#  'attuned',
#  'bites',
#  'miners',
#  'kitaen',
#  'digitized',
#  'horsemen',
#  'peak',
#  'objective',
#  'bats',
#  'spectacle',
#  'cameras',
#  'invoked',
#  'soldier',
#  'alain',
#  'signal',
#  'reminds',
#  'baroque',
#  'boulevard',
#  'reclaiming',
#  'lunge',
#  'doting',
#  'messy',
#  'hitchhiker',
#  'drifting',
#  'inessential',
#  'send',
#  'policemen',
#  'nations',
#  'ferencz',
#  'stephenson',
#  'surface',
#  'sterile',
#  'translucent',
#  'tittering',
#  'ranking',
#  'credo',
#  'heisserer',
#  'undermining',
#  'depraved',
#  'interested',
#  'fabulists',
#  'identified',
#  'broadcasting',
#  'suspiciously',
#  'ritualized',
#  'ivlev',
#  'rarified',
#  'mined',
#  'cg',
#  'erin',
#  'unquestioning',
#  'acquaintances',
#  'scalp',
#  'landed',
#  'caribbean',
#  'exorcised',
#  'fulfilment',
#  'patiently',
#  'charade',
#  'chaturvedi',
#  'flint',
#  'sternly',
#  'whirlwind',
#  'uma',
#  'weimar',
#  'lavishes',
#  'carson',
#  'splotchy',
#  'spandex',
#  'nocebo',
#  'crayons',
#  'grizzled',
#  'confection',
#  'remark',
#  'jannings',
#  'forthcoming',
#  'teeters',
#  '1937',
#  'pretense',
#  'ponderousness',
#  'curtailed',
#  'macht',
#  'realización',
#  'outfit',
#  'cria',
#  'convencional',
#  'earwig',
#  'rumination',
#  'daydreaming',
#  'buried',
#  'lothario',
#  'relays',
#  'blunder',
#  'wholeheartedly',
#  'slovenly',
#  'propels',
#  'spell',
#  'hotel',
#  'hater',
#  'shaping',
#  'velvet',
#  'need',
#  'misbehaving',
#  'suspended',
#  'cowering',
#  'bowling',
#  'richest',
#  'lifelessly',
#  'eficaz',
#  'exit',
#  'article',
#  'constructions',
#  'leni',
#  'latin',
#  'trainspotting',
#  'sadder',
#  'hallstrom',
#  'edson',
#  'mcg',
#  'captions',
#  'intimations',
#  'impressively',
#  'hanssen',
#  'powerless',
#  'loathes',
#  'gleize',
#  'contained',
#  'amateurishly',
#  'revivalist',
#  'bergman',
#  'raucously',
#  'tosh',
#  'calming',
#  'commitments',
#  'improbable',
#  'operated',
#  'eclipsed',
#  'popularized',
#  'channing',
#  'crowbars',
#  'schulberg',
#  'civility',
#  'summery',
#  'shark',
#  'degradation',
#  'cinematographic',
#  'gruesomeness',
#  'iq',
#  'protesters',
#  'brisseau',
#  'imposed',
#  'ings',
#  'indoor',
#  'inclination',
#  'instructor',
#  'navarone',
#  'warcraft',
#  'oda',
#  'hired',
#  'voluminous',
#  'lpez',
#  'leaden',
#  'arrogance',
#  'kazakhstan',
#  'splashing',
#  'honour',
#  'murkiness',
#  'privileged',
#  'comprehend',
#  'sandra',
#  '8mm',
#  'bartha',
#  'practically',
#  'surgery',
#  'auto',
#  'unconcerned',
#  'mucho',
#  'crimson',
#  'conformity',
#  'mcclure',
#  'infernal',
#  'duncan',
#  'resonantly',
#  'solitude',
#  'eileen',
#  'outcomes',
#  'zootopia',
#  'puzzler',
#  'rivals',
#  'succumbing',
#  'seductively',
#  'julianne',
#  'plummets',
#  'wizard',
#  'emo',
#  'sappiest',
#  'sub',
#  'continual',
#  'stunningly',
#  'thorny',
#  'disintegrating',
#  'repulsiveness',
#  'fearful',
#  'homaging',
#  'christine',
#  'afro',
#  'piada',
#  'stupider',
#  'steals',
#  'bulges',
#  'cameramen',
#  'tax',
#  'packaging',
#  'ma',
#  'decisions',
#  'physique',
#  'nerve',
#  'trolling',
#  'gautier',
#  'congratulations',
#  'environmentalism',
#  'godzilla',
#  'contrivance',
#  'tel',
#  'balance',
#  'riklis',
#  'eccleston',
#  'robotic',
#  'instruct',
#  'said',
#  'politicking',
#  'por',
#  'broccoli',
#  'synopsis',
#  'farfetched',
#  'bypass',
#  'colossal',
#  'buscemi',
#  'townsend',
#  'newsreels',
#  'mid90s',
#  'conservatism',
#  'unafraid',
#  'filmmaking',
#  'expeditions',
#  'bargains',
#  'lina',
#  'patina',
#  'nosy',
#  'advance',
#  'compilation',
#  'yield',
#  'legendarily',
#  'ernest',
#  'observances',
#  'recluse',
#  'subterranean',
#  'conveys',
#  'cordiality',
#  'punishingly',
#  'servitude',
#  'furry',
#  'everybody',
#  'signalling',
#  'menos',
#  'resigns',
#  'fockers',
#  'rangers',
#  '1942',
#  'whiffs',
#  '12',
#  'dito',
#  'honours',
#  'obit',
#  'pearl',
#  'orion',
#  'stag',
#  'advent',
#  'armie',
#  'candidates',
#  'obscenity',
#  'childers',
#  'relatability',
#  'enjoys',
#  'nineties',
#  'splatters',
#  'men',
#  'qala',
#  'aviad',
#  'shirtless',
#  'lulu',
#  'roommate',
#  'audience',
#  'abilities',
#  'inauthenticity',
#  'simmer',
#  'minneapolis',
#  'nebraska',
#  'quite',
#  'aviation',
#  'retiree',
#  'killing',
#  'barely',
#  'vivacity',
#  'inept',
#  'undoubtedly',
#  'unerring',
#  'prolific',
#  'moonlight',
#  'meager',
#  'personalities',
#  'honoré',
#  'obviously',
#  'challenging',
#  'sagas',
#  'lazier',
#  'tocante',
#  'tony',
#  'squeal',
#  'say',
#  'spotlighted',
#  '2011',
#  'flings',
#  'lighted',
#  'dominoes',
#  'quasi',
#  'platinum',
#  'outkast',
#  'crackle',
#  'eyes',
#  'geysers',
#  'condescension',
#  'jacquot',
#  'steam',
#  'grandest',
#  'perfectionism',
#  'bootleggers',
#  'naught',
#  'icon',
#  'bourboulon',
#  'karina',
#  'terrifies',
#  'attica',
#  'thyberg',
#  'moan',
#  'veber',
#  'geeks',
#  'klown',
#  'llorona',
#  'commercials',
#  'hidalgo',
#  'fakeness',
#  'freaky',
#  'blitzkrieg',
#  'homosexuals',
#  'vine',
#  'lemon',
#  'employees',
#  'provost',
#  'elm',
#  'shying',
#  'aimee',
#  'shallower',
#  'nomads',
#  'sanitized',
#  'dismaying',
#  'babble',
#  'cheap',
#  'linden',
#  'pesky',
#  'outer',
#  'passing',
#  'lampooning',
#  'cleanliness',
#  'improvising',
#  'manners',
#  'dramas',
#  'mowed',
#  'discernible',
#  'underdevelopment',
#  'presided',
#  'crowd',
#  'enlarged',
#  'surfer',
#  'comparison',
#  'trinity',
#  'grabby',
#  'conan',
#  'cane',
#  'posted',
#  'adroitly',
#  'complexly',
#  'slugfest',
#  'crowds',
#  'undo',
#  'bandit',
#  'antebellum',
#  'commandments',
#  'gonzlez',
#  'memphis',
#  'raiff',
#  'coyote',
#  'untraceable',
#  'foibles',
#  'encanto',
#  'unquestionable',
#  'delineated',
#  'duet',
#  'sparsely',
#  'godard',
#  'prods',
#  'contents',
#  'changeling',
#  'judith',
#  'doozy',
#  'intellect',
#  'barrymore',
#  'monologues',
#  'possessions',
#  'horner',
#  'inter',
#  'frightening',
#  'eccentricity',
#  'chumps',
#  'unyielding',
#  'factly',
#  'fashioned',
#  'terry',
#  'flattening',
#  'fancies',
#  'stitch',
#  'lindon',
#  'summarily',
#  'background',
#  'goer',
#  'leopard',
#  'truffle',
#  'dolittle',
#  'piazza',
#  'withheld',
#  'heroically',
#  'reared',
#  'notte',
#  'filho',
#  'miserabilism',
#  'gnaw',
#  'majority',
#  'magical',
#  'colorado',
#  'flares',
#  'dishevelled',
#  'thespian',
#  'horde',
#  'cockeyed',
#  'restrict',
#  'bayou',
#  'creeped',
#  'workforce',
#  'begrudgingly',
#  'inflatable',
#  'threequels',
#  'toffs',
#  'viscerally',
#  'argo',
#  'chew',
#  'nilson',
#  'buys',
#  'strident',
#  'ceaseless',
#  'henry',
#  'yin',
#  'florid',
#  'night',
#  'vin',
#  'fuck',
#  'bullet',
#  'crunches',
#  'generated',
#  'allegedly',
#  'specious',
#  'humiliating',
#  'najafi',
#  'unconvinced',
#  'mystifications',
#  'varieties',
#  'trains',
#  'produo',
#  'machoian',
#  'ways',
#  'genitalia',
#  'unequalled',
#  'dmx',
#  'sammy',
#  'cause',
#  'autumn',
#  'questionably',
#  'policing',
#  'arousing',
#  'swash',
#  'artwork',
#  'consulted',
#  'eszterhas',
#  'russians',
#  'establishing',
#  'individually',
#  'chipper',
#  'epicenter',
#  'ticked',
#  'froseth',
#  'chopper',
#  'palatable',
#  'bisexual',
#  'kedarnath',
#  'slipping',
#  'esas',
#  'plunked',
#  'firm',
#  'word',
#  'ambivalence',
#  'detectives',
#  'polk',
#  'finale',
#  'fassbinder',
#  'abetted',
#  'worthy',
#  'recreates',
#  'shipment',
#  'nasties',
#  'verité',
#  'toothed',
#  'creed',
#  'unified',
#  'paucity',
#  'definitions',
#  'sociopolitical',
#  'checking',
#  'morelli',
#  'traumatize',
#  'promotes',
#  'pounder',
#  'actors',
#  'theatrical',
#  'overwhelmed',
#  'sway',
#  'kung',
#  'hooting',
#  'mike',
#  'unforgettable',
#  'arrival',
#  'latent',
#  'mischievous',
#  'educates',
#  'barrel',
#  'motivating',
#  'malaise',
#  'craggily',
#  'sica',
#  'hollowness',
#  'jogging',
#  'jeanne',
#  'taxing',
#  'clark',
#  'dammit',
#  'introspective',
#  'timelessly',
#  'puppet',
#  'lifted',
#  'protected',
#  'blaze',
#  'politeness',
#  'success',
#  '2007',
#  'sift',
#  'ducasse',
#  'hector',
#  'realize',
#  'tavern',
#  'dotage',
#  'zachariah',
#  'dion',
#  'honeyed',
#  'sailors',
#  'measuring',
#  'hp',
#  'payoff',
#  'appreciation',
#  'builds',
#  'sheepish',
#  ...}

# %%
common_bigrams = get_common_vocab([rt_senti, rt_test], ngram_range_list=[(2,2)])
common_bigrams
# Out:
# Generating vocabulary for ngram_range: (2, 2)...
# Vocabulary for ngram-range (2, 2) in df: 1146211
# Generating vocabulary for ngram_range: (2, 2)...
# Vocabulary for ngram-range (2, 2) in df: 442876
# Common vocabulary for ngram-range (2, 2): 115420
# {'inspired feature',
#  'career changer',
#  'like minded',
#  'audiences think',
#  'jim gaffigan',
#  'bittersweet note',
#  'debates advocating',
#  'narrative loses',
#  'like superhero',
#  'deserve having',
#  'context shooting',
#  'una experiencia',
#  'new heights',
#  'value systems',
#  'like johnny',
#  'funny fierce',
#  'unflinching slice',
#  'stick long',
#  'watch seen',
#  'bad word',
#  'epic war',
#  'performances universally',
#  'searchers 1956',
#  'style pure',
#  'lacking spectacle',
#  'stand ground',
#  'like actually',
#  'acted study',
#  'place american',
#  'gory gift',
#  'roadrunner film',
#  'attempts blend',
#  'dramatic effect',
#  'refreshingly adult',
#  'taking inspiration',
#  'winsome characters',
#  'don surprised',
#  'able resist',
#  'viewers need',
#  'epic tragedy',
#  'surface level',
#  'formula succeeds',
#  'budget time',
#  'preposterous story',
#  'dark blue',
#  'valentine genre',
#  'brothers latest',
#  'victory lap',
#  'viewer ends',
#  'result fun',
#  'especially love',
#  'camera eye',
#  'feels disjointed',
#  'paced outrageously',
#  'recognize film',
#  'lame jokes',
#  'good naturedly',
#  'memorably moving',
#  'fated love',
#  'guitar nation',
#  'provides heartbreaking',
#  'mounted drama',
#  'story italy',
#  'flaws ultimately',
#  'best harry',
#  'story middle',
#  'screenplay make',
#  '44 reality',
#  'jack thorne',
#  'charisma goes',
#  'slowly steadily',
#  'putting good',
#  'return home',
#  'matter life',
#  'new breed',
#  'don gel',
#  'mind numbing',
#  'exciting moment',
#  'leaves anxious',
#  'euzhan palcy',
#  'hilarious life',
#  'unsatisfying ending',
#  'film sign',
#  'merely underlines',
#  'ultimately audiences',
#  'pleasant surprises',
#  'cheap scares',
#  'city review',
#  'travel world',
#  'mark ruffalo',
#  'girl isn',
#  'entire movie',
#  'rushed incoherent',
#  'close proximity',
#  'bring brand',
#  'score 46',
#  '44 gentle',
#  'just note',
#  'movie potential',
#  'art 44',
#  'film similarly',
#  'simon pegg',
#  'broken lives',
#  'tension suspense',
#  'immediacy intimacy',
#  'right alongside',
#  'sean patrick',
#  'presence eventual',
#  'thriller continues',
#  'lacks bit',
#  'attempt revive',
#  'raw uncompromising',
#  'truth beauty',
#  'funny spots',
#  '8217 takes',
#  'sleepless seattle',
#  'time martin',
#  'filmmaker does',
#  'simon rex',
#  'way celebrate',
#  'emotionally unsatisfying',
#  'laughing 46',
#  'elements story',
#  'movie taut',
#  'chest instead',
#  'later year',
#  'tale tales',
#  'fair isn',
#  'vanessa hudgens',
#  'just guilty',
#  'good moment',
#  'prison pipeline',
#  'gripping adaptation',
#  'liev schreiber',
#  'meet real',
#  'end got',
#  'great director',
#  'true joy',
#  'pleasing comedy',
#  'realism just',
#  'like invited',
#  'buddy movies',
#  'job delivering',
#  'end credits',
#  'performance felicity',
#  'people feeling',
#  'conventional biopic',
#  'feels effortless',
#  'heartbreaking documentary',
#  'mean man',
#  'herzog created',
#  'british woman',
#  'basic fundamentals',
#  'intriguing complex',
#  'little rum',
#  'year greatest',
#  'impressive stunt',
#  'try hardest',
#  'isn cynical',
#  'spectacle display',
#  'footage past',
#  'act entertaining',
#  'world biggest',
#  'experience tedious',
#  'plot year',
#  'ellis does',
#  'wwii combat',
#  'rorschach test',
#  'job makes',
#  'beta test',
#  'film sustain',
#  'probably forget',
#  'ugly digital',
#  'obvious early',
#  'los dos',
#  'happen film',
#  'lovely performance',
#  'obvious screenplay',
#  'director fred',
#  'attempts political',
#  'succeeds putting',
#  'like original',
#  'visionary filmmaker',
#  'great power',
#  'quot fright',
#  'themes love',
#  'movie intended',
#  'stan gives',
#  'kept interested',
#  'drama trying',
#  'prodigal son',
#  '44 meaningful',
#  'hours screen',
#  'cold clinical',
#  'picture loves',
#  'sex ego',
#  'bloody minded',
#  'marvel unlike',
#  'women sexuality',
#  'movies terrific',
#  'love makes',
#  'bent hamer',
#  'movie apos',
#  'rock history',
#  'protagonists deeply',
#  'nick hamm',
#  '44 familiar',
#  'people moral',
#  'excuse film',
#  'marvel canon',
#  'performances supporting',
#  'movie bonnie',
#  'saying goes',
#  'movie elegance',
#  'quite accomplishment',
#  'finally hits',
#  'jolie brings',
#  'great classic',
#  'based title',
#  'dizzying strength',
#  'fairly watchable',
#  'jordan foxx',
#  'regret seeing',
#  'costs war',
#  'textured film',
#  'characters believe',
#  'debut suffers',
#  'couldn aided',
#  'little elephant',
#  'kill zone',
#  'child 8217',
#  'week year',
#  'watchable film',
#  'splendid work',
#  '8220 8221',
#  'fight club',
#  'performances marvelous',
#  'family saga',
#  'street obvious',
#  'time decades',
#  'kids adult',
#  'acting adds',
#  'love pixar',
#  'animated 3d',
#  'fun smart',
#  'unengaging utterly',
#  'contempt humanity',
#  'false step',
#  'sight goal',
#  'dirty dancing',
#  'elijah wood',
#  'kermit frog',
#  'emotionally heavy',
#  'tropes era',
#  'easy categorization',
#  'freedom loss',
#  'funny review',
#  'women enjoy',
#  'environmental changes',
#  'cast real',
#  'don say',
#  'indie production',
#  'night comedy',
#  'pretty spectacular',
#  'director howard',
#  'big city',
#  'elizabeth wood',
#  'plot impressive',
#  'justify existence',
#  'allen poe',
#  'originally intended',
#  'weaker films',
#  'twist arrives',
#  'serve great',
#  'fully loaded',
#  'greatest anti',
#  'moments overall',
#  'material taken',
#  'sprawling cast',
#  'care protagonists',
#  'long possibly',
#  'drama sinks',
#  'whiny insecure',
#  'cuddly animal',
#  'movie stakes',
#  'awkward repetitive',
#  'synopsis suggest',
#  'superficial look',
#  'emmerich finally',
#  'entire world',
#  'tick tock',
#  'matter imperfect',
#  'lack pace',
#  'non sequiturs',
#  'worse time',
#  'thing clear',
#  'wives club',
#  'best stand',
#  'performances olivia',
#  'minutes history',
#  'logic keeps',
#  'story care',
#  'strictly grade',
#  'repeatedly threatens',
#  'moments despite',
#  'makes house',
#  'real genre',
#  'don entirely',
#  'leigh film',
#  'ambitious vision',
#  'villains makes',
#  'dog food',
#  'great middle',
#  'cast unique',
#  'failed watch',
#  'streak film',
#  'smart ending',
#  'far concerned',
#  'story initially',
#  'utterly insane',
#  'totally unique',
#  'erratic rewarding',
#  'unwieldy title',
#  'screen talent',
#  'doesn know',
#  'big reason',
#  'musician 46',
#  'fuller wild',
#  'fans ignore',
#  'honestly good',
#  'late 50s',
#  'game changing',
#  'intense horror',
#  'marriage story',
#  'stands relatively',
#  'cut loose',
#  'guys coming',
#  'satisfying manner',
#  'appealing story',
#  'born director',
#  'bring film',
#  'story screen',
#  'film settles',
#  'zombi child',
#  'really fresh',
#  'sort funny',
#  'singular achievement',
#  'flaws overall',
#  'escapist treat',
#  'jam session',
#  'll 46',
#  'monkey paw',
#  'time intriguing',
#  'offer lot',
#  'dark horse',
#  'hair raising',
#  'derivative sci',
#  'film numerous',
#  'movie abomination',
#  'head head',
#  'actor brendan',
#  'comedy woman',
#  'pays respect',
#  'true wonder',
#  'ecological themes',
#  'revenge fallen',
#  'just surprised',
#  'motion masterpiece',
#  'film recent',
#  'summer 1993',
#  'nearly unrecognizable',
#  've boring',
#  'long ride',
#  'rest running',
#  'scare scare',
#  'funny deadly',
#  'sketch comedy',
#  'wild hilarious',
#  'harry macqueen',
#  'character portrayals',
#  'satire doesn',
#  'refreshing new',
#  'received best',
#  'element doesn',
#  'biggest laugh',
#  'time writer',
#  'known outcome',
#  'remake 1977',
#  'columbine massacre',
#  'certain circles',
#  'florence foster',
#  'just computer',
#  'probably play',
#  'computer images',
#  'torn hearts',
#  'performance men',
#  'revelation just',
#  'good elevate',
#  'approach just',
#  'patient girlfriend',
#  'manages suspense',
#  'material girl',
#  'climax genuinely',
#  'understand makes',
#  'need sequel',
#  '44 making',
#  'graham greene',
#  'perfectly executed',
#  'image management',
#  'scenes pretty',
#  'simply reiterating',
#  'film dour',
#  'change thing',
#  'best left',
#  'greatness 46',
#  'like dime',
#  'delivers magnetic',
#  'enjoyable delightful',
#  'nonsensical ideas',
#  'weird wonderful',
#  'life elvis',
#  'anderson takes',
#  'syrian refugee',
#  'empathy hope',
#  'achieved goal',
#  'doesn stuff',
#  'satire subject',
#  'succeeds 46',
#  'bit long',
#  'perfect balance',
#  'movie transformers',
#  'animated war',
#  'glory film',
#  'tony curtis',
#  'daring audience',
#  'life flash',
#  'given script',
#  'does hollywood',
#  'striking cinematography',
#  'light years',
#  'animation technique',
#  'familiar material',
#  'satirical bent',
#  'director hollywood',
#  'textured visually',
#  'foster jenkins',
#  'comes harry',
#  'jus ao',
#  'quirky emotional',
#  'film ways',
#  'saturday night',
#  'credit movie',
#  've traveled',
#  'tremendously important',
#  'small screen',
#  'formulaic plot',
#  'film finally',
#  'achingly tender',
#  'eerie score',
#  'doesn live',
#  'rider movie',
#  'better paper',
#  'sinks like',
#  'watchable ll',
#  'requires patience',
#  'treat people',
#  'character audience',
#  'absolute knockout',
#  'wit charm',
#  'lot grown',
#  'think think',
#  'cultural gender',
#  'story relevant',
#  'slow intriguing',
#  'horror classic',
#  'people american',
#  'eye eye',
#  'schmaltzy manipulative',
#  'feel actors',
#  'grows cold',
#  'things admire',
#  'feels phoned',
#  'pretty stupid',
#  'movie horrifying',
#  'cruel film',
#  'case bad',
#  'actually cared',
#  'visual storytelling',
#  'direction accomplished',
#  'movie uses',
#  'seat 44',
#  'driven culture',
#  'creatures film',
#  'suspense fails',
#  'natural wonders',
#  'drama clichés',
#  'catherine called',
#  'heavy handedness',
#  'recent work',
#  'deep film',
#  'course story',
#  'competent filmmaking',
#  'james creates',
#  'refreshingly unpretentious',
#  'entertainment designed',
#  'capture human',
#  'fun thriller',
#  'successful portrayal',
#  'audience lap',
#  'robin hood',
#  'upbeat note',
#  'strike funny',
#  'novel high',
#  'red state',
#  'kids know',
#  'crafting action',
#  'battle good',
#  'years blue',
#  'hecht page',
#  'twisty terrific',
#  'characters mention',
#  'satisfied end',
#  'par effort',
#  'ocean film',
#  'films remains',
#  'frequently charming',
#  'act menacing',
#  'sublime act',
#  'random like',
#  'bit escapism',
#  'entirely convincing',
#  'scene features',
#  'cartoon based',
#  'naturalistic dialogue',
#  'tale redemption',
#  'piece black',
#  'pretty great',
#  'fashioned detective',
#  'think frank',
#  '8220 thing',
#  'shake life',
#  'damaged goods',
#  'little smarter',
#  'movies paul',
#  'art memory',
#  'color money',
#  'story fate',
#  'horrifying 44',
#  'mix action',
#  'rules cinema',
#  'intense times',
#  'audience fully',
#  'like cinemax',
#  'maker make',
#  'feeling awe',
#  'picture story',
#  'don understand',
#  'american government',
#  'challenges audiences',
#  'point new',
#  'welcome change',
#  'make drama',
#  'comes horror',
#  'makes stand',
#  'message feels',
#  'beneath action',
#  'spirit authentic',
#  'intended children',
#  'attraction watching',
#  'hyper stylish',
#  'remembered dream',
#  'day like',
#  'forget watching',
#  'personal assistant',
#  'kind shrug',
#  'stage life',
#  'picture stars',
#  'iii works',
#  'nifty 44',
#  'quite manages',
#  'strength visceral',
#  '91 director',
#  'script plot',
#  'lovely tribute',
#  've benefited',
#  'lure great',
#  'movie choppy',
#  'minute run',
#  'shoots foot',
#  'nasty hilarious',
#  'art important',
#  'generations women',
#  'visually gorgeous',
#  'picture entertaining',
#  'chilling way',
#  'movie eye',
#  'result mess',
#  'absent 46',
#  'false note',
#  'mix sports',
#  'remains curiously',
#  'history intimate',
#  'interesting case',
#  'sound design',
#  'true pleasure',
#  'fluff film',
#  'hoped film',
#  'winds predictable',
#  'thanks unabashed',
#  'small steps',
#  'fun certainly',
#  'look reveals',
#  'loose funny',
#  'does nail',
#  'scream know',
#  'eighties slasher',
#  'letters iwo',
#  'memory identity',
#  'shape just',
#  'kind raucous',
#  'films absorbing',
#  'country movie',
#  'teens tweens',
#  'ending likely',
#  'care film',
#  'perfect sequel',
#  'murky depths',
#  'year just',
#  'friends just',
#  'issues way',
#  'class community',
#  'suggest filmmakers',
#  'action instead',
#  'hair trigger',
#  'tough efficient',
#  'sayles manages',
#  'united kingdom',
#  'day smith',
#  'annoying title',
#  '8221 worth',
#  'real movie',
#  'appear having',
#  'latest exercise',
#  'movies case',
#  'classic chinese',
#  'emotional depth',
#  'uncertain future',
#  'really history',
#  'filmmaking ll',
#  'movie female',
#  'modest premise',
#  'portrait teenager',
#  'change minds',
#  'makes far',
#  'ultimate value',
#  'ken jeong',
#  'peter mackie',
#  '44 pain',
#  'worth checking',
#  'fashion like',
#  'book series',
#  'writer hanif',
#  'student video',
#  'hold doesn',
#  'holidays life',
#  '2014 film',
#  'ferocious intensity',
#  'comic edge',
#  'merely repeating',
#  'self importance',
#  'liberating flamboyance',
#  'concept promises',
#  'audience unless',
#  'modest entertainment',
#  'love rarely',
#  'ominous atmosphere',
#  'steps right',
#  'end david',
#  'note comes',
#  'alita battle',
#  'moral historical',
#  'bitter funny',
#  'war melodrama',
#  'perfectly embodies',
#  'job presenting',
#  'general audiences',
#  'archival footage',
#  'movie details',
#  'premise turns',
#  'good day',
#  'angle comes',
#  'film longing',
#  'wasn expecting',
#  'french town',
#  'classic family',
#  'worthy life',
#  'lot fun',
#  'love child',
#  'desert sands',
#  'zsa zsa',
#  'crime comedy',
#  'lightly charming',
#  'hilarious sex',
#  'tense action',
#  'nominated best',
#  'run nice',
#  'doesn stretch',
#  'witches eastwick',
#  'release given',
#  'long odds',
#  'action decent',
#  'visually atmospheric',
#  'marks return',
#  'pro wrestling',
#  'disney story',
#  'remarkably moving',
#  'singing make',
#  'keeping distance',
#  'terrific time',
#  'really sets',
#  'fantasy films',
#  'say death',
#  'authentic 44',
#  'kieran evans',
#  'fills role',
#  'comedy kids',
#  'make apos',
#  'rolling stones',
#  'film rated',
#  'counter culture',
#  'plenty family',
#  'wish dead',
#  'novels short',
#  'family reunion',
#  'complete story',
#  'original memorable',
#  'movie quickly',
#  'make journey',
#  'body like',
#  'person job',
#  '44 fell',
#  'acting production',
#  'driven remarkably',
#  'obvious seams',
#  'able fully',
#  'like especially',
#  'trauma mental',
#  'considerably darker',
#  'heart classic',
#  'characters didn',
#  'kind drag',
#  'best animated',
#  'laughter heart',
#  'courage stand',
#  'film refreshing',
#  'little stolid',
#  'funny fascinating',
#  'consistent clever',
#  'queen elizabeth',
#  'dull romance',
#  'bleak morality',
#  'realistic film',
#  'raises timely',
#  'christian slater',
#  'brow laughs',
#  'cast amazing',
#  'continent sized',
#  'jokes gags',
#  'themes challenge',
#  'really final',
#  'rich exploration',
#  'daughter dylan',
#  'animation crisp',
#  'decision makes',
#  'animation techniques',
#  'skid row',
#  'takes audiences',
#  'like parade',
#  'performance goes',
#  'actor jeff',
#  'cinema silent',
#  'blume love',
#  'proves difficult',
#  'gives premise',
#  'work director',
#  'stewart makes',
#  'big battle',
#  'runtime just',
#  'delightful heartfelt',
#  'letting audience',
#  'talent filmmaker',
#  'comedy history',
#  'end run',
#  'play grown',
#  'grand design',
#  'written impressively',
#  'explodes screen',
#  'film boys',
#  'film police',
#  'crafts gripping',
#  'night short',
#  'wider exposure',
#  'nutty professor',
#  'fight democracy',
#  'world seen',
#  'provides tense',
#  'performance footage',
#  'dutch angles',
#  'production crew',
#  'effort make',
#  'relatively unknown',
#  'horribly misguided',
#  'tourist board',
#  'nice production',
#  'peanuts big',
#  'bore viewers',
#  'really step',
#  'main issue',
#  'las vegas',
#  'power empathy',
#  'manners light',
#  'draw attention',
#  'performance charlize',
#  'performance unlike',
#  'honestly earns',
#  'blend suspense',
#  'just bit',
#  'style fable',
#  'waster 46',
#  'mad men',
#  'story count',
#  'good character',
#  'enlightening exploration',
#  'hypocrisy 44',
#  'powerful action',
#  'right choice',
#  'gangster cinema',
#  'fair plays',
#  'family fable',
#  'big daddy',
#  'early influences',
#  'shows man',
#  'city doesn',
#  'real kick',
#  'looks prescient',
#  'goes mainstream',
#  'moscow belgium',
#  'named director',
#  'dismiss movie',
#  'action barely',
#  'serviceable movie',
#  'interesting social',
#  'portrait personal',
#  'film delicately',
#  'growing pains',
#  'like elaborate',
#  'aspect character',
#  'emmy award',
#  'apos movies',
#  'feel consistent',
#  'paranoid nightmare',
#  'fresh scares',
#  'pretty sight',
#  'spark missing',
#  'effectively states',
#  'end director',
#  'fred flarsky',
#  'connery makes',
#  'ability understand',
#  'performance 8217',
#  'visual realism',
#  'war battling',
#  'comedy college',
#  'stays away',
#  'scenes powerful',
#  'murphy actually',
#  'absolute joy',
#  'mission statement',
#  'way friendship',
#  'intriguing absorbing',
#  'circle comedy',
#  'make consider',
#  'exist 46',
#  'viewers inevitably',
#  'invasion flick',
#  'wreck lot',
#  'final segment',
#  '46 work',
#  'feast eye',
#  'especially revelatory',
#  'imaginative silly',
#  'mean going',
#  'story threadbare',
#  'quite dark',
#  'political debate',
#  'merely meant',
#  'beginning 44',
#  'moments action',
#  'genre original',
#  'fashioned charm',
#  '8217 modern',
#  '1991 film',
#  'premise utilized',
#  'spell lingers',
#  'afraid fully',
#  'ad absurdum',
#  'delicious concoction',
#  'nearly years',
#  'great slasher',
#  'like miracle',
#  'purely entertaining',
#  'promising calling',
#  'independent female',
#  'drips authenticity',
#  'trust instincts',
#  'getting ripped',
#  'makes generic',
#  'isn normally',
#  'humpback whales',
#  'just begging',
#  '96 minute',
#  'satirical bite',
#  'thriller right',
#  'just feels',
#  'highly amusing',
#  'power predecessor',
#  'historical perspective',
#  'se7en animal',
#  'personagens como',
#  'hard cute',
#  'transition leaving',
#  'aging dementia',
#  'play 44',
#  'act delivers',
#  'darkly hilarious',
#  'reality emotionally',
#  'fi piece',
#  'wars apos',
#  'mcewan work',
#  'underdog formula',
#  'film regarded',
#  'realize just',
#  '44 morality',
#  'finally win',
#  'blow mind',
#  'key moments',
#  'entertainment review',
#  'digital trickery',
#  'isn picture',
#  'unlike sequels',
#  'works biopic',
#  'movie delivered',
#  'portrait pimp',
#  'rings false',
#  'visceral horror',
#  'just things',
#  'direction way',
#  'use special',
#  'little events',
#  'uncomfortable doing',
#  'movie family',
#  '44 guilt',
#  'best viewed',
#  'silent film',
#  'things like',
#  'stay interested',
#  'chamber secrets',
#  'vocal talent',
#  'recent animated',
#  'great soundtrack',
#  'does ruin',
#  'film unforgettable',
#  'creates memorable',
#  'times message',
#  'immediate predecessor',
#  'movie missed',
#  'thrills entertain',
#  'point hard',
#  'work especially',
#  'resonance story',
#  'buckaroo banzai',
#  'kind confidence',
#  'movie given',
#  'thoughts emotions',
#  'house crowd',
#  'manages unpredictable',
#  'individual identity',
#  'moments actually',
#  'ancient folk',
#  'don spend',
#  'political film',
#  'photo realistic',
#  'true substance',
#  'planes trains',
#  'gone mad',
#  '44 heart',
#  'rainfall serve',
#  'marry naturalistic',
#  'older teens',
#  'excellent netflix',
#  ...}

# %%
common_trigrams = get_common_vocab([rt_senti, rt_test], ngram_range_list=[(3,3)])
common_trigrams
# Out:
# Generating vocabulary for ngram_range: (3, 3)...
# Vocabulary for ngram-range (3, 3) in df: 1443939
# Generating vocabulary for ngram_range: (3, 3)...
# Vocabulary for ngram-range (3, 3) in df: 498850
# Common vocabulary for ngram-range (3, 3): 23768
# {'hero color city',
#  'original film enjoyable',
#  'mishmash styles genres',
#  'emmerich old hand',
#  'para merecer uma',
#  'man climbed window',
#  'moments visual splendor',
#  'little coming age',
#  'best battle scenes',
#  'bad taste fun',
#  'dark places film',
#  'review parents available',
#  'command humor pathos',
#  'self contained self',
#  'funny romantic comedy',
#  'good time movie',
#  'sci fi extravaganza',
#  'designed maximum impact',
#  'drama comedic moments',
#  'funny film invites',
#  'coming age dramedy',
#  'apos star wars',
#  'movie wants make',
#  'clever little film',
#  'falls short character',
#  'uses overused word',
#  'comic book adaptation',
#  'nice mix comedy',
#  'indiana jones temple',
#  'rendition 8220 ant',
#  'ballad ricky bobby',
#  'direction peter jackson',
#  'prevents viewer connecting',
#  'best films 2018',
#  'fast moving thriller',
#  'nicely paced struggles',
#  'social issue drama',
#  'handsomely mounted highly',
#  'destined cult classic',
#  'best thing say',
#  'makes better use',
#  'set pieces sense',
#  'smooth rough edges',
#  'easy look past',
#  'jodie foster anthony',
#  'director steven caple',
#  'right thing times',
#  'jonze charlie kaufman',
#  'human progress eternal',
#  'covers familiar ground',
#  'feels authentic 46',
#  '44 damn 44',
#  'amounts 90 minutes',
#  'best film franchise',
#  'pretty damn close',
#  'work thanks completely',
#  'eyes welled tears',
#  'razor sharp wit',
#  'visually stunning film',
#  'difficult carp storywise',
#  'thor 58 love',
#  'raising victor vargas',
#  'soaked genre flick',
#  'writer director elizabeth',
#  'good way makes',
#  'english language feature',
#  'psychological thriller cum',
#  'international film festival',
#  'beautiful message love',
#  'certain surprised content',
#  'hollywood film slick',
#  'particular moment time',
#  'hopeful enduring lesson',
#  'loses sight human',
#  'sharp script strong',
#  '8217 seen 46',
#  'stern warning sugar',
#  'worth seeing big',
#  'color grounded normalcy',
#  'uncle boonmee recall',
#  '100 year old',
#  'films like braveheart',
#  'hits just right',
#  'quite comes life',
#  'feels like tried',
#  'best selling book',
#  'thoroughly enjoyed film',
#  'post traumatic stress',
#  'illustrates nuanced contexts',
#  'film wasn good',
#  'orientações sexuais em',
#  'considered implications recent',
#  'theron saved pretty',
#  'surely masters american',
#  'sci fi disaster',
#  'thriller turn feels',
#  'jones temple doom',
#  'perfect date movie',
#  'feels like throwback',
#  'walt disney pictures',
#  'fu panda films',
#  'doesn quite know',
#  'unsettling character study',
#  'mistakenly taking young',
#  'don mind little',
#  'does manage achieve',
#  'hard figure begin',
#  'anthology horror film',
#  'american dream time',
#  'watch marvel movies',
#  'like romantic comedy',
#  'director taika waititi',
#  'doesn make feel',
#  'shaggy dog tale',
#  'day fairy tale',
#  'movie beautiful look',
#  'second best thing',
#  'movie kicked thoroughly',
#  'attention review spanish',
#  'makes abundantly clear',
#  'strongest film date',
#  'home sweet home',
#  'bang montages sudden',
#  'entertaining coming age',
#  'seemingly foolproof premise',
#  'winning writer director',
#  'action movies starring',
#  'film isn sure',
#  'meets girl girl',
#  'mary queen scots',
#  'got national low',
#  'citizens mourn incredibly',
#  'like fairy tales',
#  'vi u0161e nego',
#  'saying don make',
#  'improved special effects',
#  'love love love',
#  'apos soon forget',
#  'scott fitzgerald novel',
#  'like good idea',
#  'pay close attention',
#  'greatest hits album',
#  'sweet gentle light',
#  'weird sake weird',
#  'melissa mccarthy vehicle',
#  'el crimen perfecto',
#  'old school filmmaking',
#  'director hugh hudson',
#  'game 44 aided',
#  'obviously feel good',
#  'forgot making movie',
#  'strong emotional core',
#  'effective eventually come',
#  'talent sides camera',
#  'performances leonardo dicaprio',
#  'makes essential viewing',
#  'think little guy',
#  'performances talented cast',
#  '30 odd years',
#  'document survivor testimony',
#  'rotting baltimore inside',
#  'humanity review spanish',
#  'movies coming year',
#  'thinly drawn characters',
#  'current housing crisis',
#  'work feels like',
#  'history rich close',
#  'right place comes',
#  'list 46 44',
#  'appeal target audience',
#  'low budget ghost',
#  'spirited away chock',
#  'coping outsider dom',
#  'makes film work',
#  'science fiction ideas',
#  'genre fiction formulaic',
#  'nearly frame film',
#  'fool heart walter',
#  'best known movie',
#  'make standard cop',
#  'film understandable given',
#  'visual style strong',
#  'look love family',
#  'modern day england',
#  'transatlantic hit arrived',
#  'peyton reed film',
#  'transformers revenge fallen',
#  'director michel hazanavicius',
#  'movie people think',
#  'rain man far',
#  'does nice job',
#  'antithetical rom com',
#  'best performance date',
#  'cast smart script',
#  'set halls congress',
#  'director mimi leder',
#  'makes movie worthwhile',
#  'crowd pleasing approach',
#  'novels short stories',
#  'fascinating time capsule',
#  'romantic comedy genre',
#  'funny light hearted',
#  'small screen roots',
#  'moments humor warmth',
#  'contemporary working class',
#  'scary review spanish',
#  'just long line',
#  'wanting long time',
#  'beautifully shot edited',
#  'douglas best roles',
#  'according korine version',
#  'damn good movie',
#  'ups incessant unwittingly',
#  '46 quantumania ant',
#  'characterizations remain dimensional',
#  'really links genre',
#  'film ages insubstantial',
#  'makes good use',
#  'story worth watching',
#  'half hour running',
#  'mercado gone access',
#  'dark horse contender',
#  'parable capitalist world',
#  'wittily updates tom',
#  'south africa end',
#  'cirque du soleil',
#  'world gives strange',
#  'make fun watch',
#  'film features strong',
#  'friday night fright',
#  'does work despite',
#  'warm fuzzy feeling',
#  'locked room mystery',
#  'worth late night',
#  'horror movies review',
#  'writer director stephen',
#  'time story takes',
#  'felt like retread',
#  'self assured max',
#  'don know thing',
#  'just make feel',
#  'action sequences brilliant',
#  'story patrick chamusso',
#  'crime thriller triple',
#  'breeze deep relationships',
#  'big laughs thanks',
#  'spent lot time',
#  'moments doesn quite',
#  'fashioned science fiction',
#  'good looking movie',
#  'far laughs gwen',
#  'films legendary musicians',
#  'original film thanks',
#  'shooting real time',
#  'predictable romantic comedy',
#  'greatest strength way',
#  'thriller political drama',
#  'touching movie makes',
#  'chipmunks road chip',
#  'director phillip noyce',
#  '8217 fun 44',
#  'que percebemos que',
#  'hack man blitzkrieg',
#  'pierre luc dardenne',
#  'just wanna fun',
#  'downtown los angeles',
#  'bruce greenwood michelle',
#  'production values enhance',
#  'fusion classic dance',
#  'great film year',
#  'toy story franchise',
#  'emotional beats feel',
#  'self imposed limitations',
#  'lacks sense magic',
#  'mightily enjoyable political',
#  'george clooney shailene',
#  'rom com genre',
#  'film makes little',
#  'virus contagious viewers',
#  'tiempos ritos pasados',
#  'coming age movies',
#  'let corpses tan',
#  'theme song movie',
#  'intriguing subject matter',
#  'feel antithetical rom',
#  'wall currently theaters',
#  'charming romantic comedy',
#  'blitzkrieg bad worst',
#  'twist end certainly',
#  'viewers feel like',
#  'latest long line',
#  'nonetheless assembles large',
#  'dreary nonsensical movie',
#  'dvd blu ray',
#  'snakes plane good',
#  'buzz hugh jackman',
#  'nice little movie',
#  'strong lead performances',
#  'did make laugh',
#  'mess moments excitement',
#  'larson carol danvers',
#  'father knows best',
#  'emotional impact film',
#  'rise charming portrayal',
#  'daredevil flashy plastic',
#  'tyler perry film',
#  'classe tous risques',
#  'power child imagination',
#  'duty bound demand',
#  'recovers review spanish',
#  'film takes greatest',
#  '21st century new',
#  'action sequences don',
#  'plenty crash bang',
#  'dwayne johnson emily',
#  'iceberg slim portrait',
#  'lord rings fellowship',
#  'david sour grapes',
#  'fun right mood',
#  'ending comes like',
#  'peanut butter falcon',
#  'harry potter franchise',
#  'lush period trappings',
#  'long walking theater',
#  'patrick wilson vera',
#  'film needs just',
#  'damn good actor',
#  'exploitation violence sex',
#  'animated film year',
#  'alvin theodore simon',
#  'complex female characters',
#  've seen mean',
#  'terrific cast 46',
#  'movie stretch imagination',
#  'brings centuries old',
#  'sarah adina smith',
#  'dvd counter tick',
#  'ethnic cultural stereotypes',
#  'portrayal certain audiences',
#  'message screw u2013',
#  'poorly written characters',
#  'best thing film',
#  'hilarious cute inspired',
#  'strong acting beautiful',
#  'rachel getting married',
#  'film greatest strength',
#  'great central performances',
#  'better ve seen',
#  'life times molly',
#  'oddity like richard',
#  'mystery twists turns',
#  'film really captures',
#  'denzel washington performance',
#  'animation review spanish',
#  'real selling point',
#  'outtakes end credits',
#  'old virgin hilarious',
#  'cast witty script',
#  'brosnan filme funciona',
#  '44 ant man',
#  'interesting characters movies',
#  'attraction empathy gets',
#  'american tradition mat',
#  'women review spanish',
#  'director john woo',
#  'doesn really help',
#  'nature review spanish',
#  'film doesn apos',
#  'rare film perfectly',
#  'short attention span',
#  'tried true formula',
#  'mess ve seen',
#  'dream come true',
#  'construction american splendor',
#  'action 47 adventure',
#  'reputation treachery hope',
#  'summer popcorn movie',
#  'know thought ask',
#  'films time review',
#  'making ant man',
#  'sweat small stuff',
#  'refuses aspect seriously',
#  'multiple story lines',
#  'antonio banderas pierre',
#  'love story best',
#  'style comic book',
#  'needed character development',
#  'kind movie wants',
#  'smart thoughtful film',
#  'brilliantly directed thoroughly',
#  'year quite possibly',
#  'inexplicably stars poorly',
#  'welcome rom com',
#  'influenced looney toons',
#  'dead man walking',
#  'phases attitude makes',
#  'met cliché didn',
#  'director phyllida lloyd',
#  'maybe best film',
#  'director jim sheridan',
#  'reboot marvel comic',
#  'hours film showing',
#  'actors play parts',
#  'like work man',
#  'thought couldn apathetic',
#  'flashy narrative antics',
#  'life sadness mercado',
#  'cinematographer emmanuel lubezki',
#  'way comics years',
#  'post screening detective',
#  'box office bucks',
#  'gone long way',
#  'director christopher mcquarrie',
#  'point view don',
#  'wai mood love',
#  'haunted house movie',
#  'brash attitude film',
#  'tale crime punishment',
#  'arts sciences documentary',
#  'sci fi flicks',
#  '20 feet stardom',
#  'performances 46 46',
#  'stay charming bumbler',
#  'kim ki duk',
#  'hard tell time',
#  'rom com fans',
#  'creepy certainly compelling',
#  '44 weird 44',
#  'tells story love',
#  'filmmaking perfectly matches',
#  'kids horror movie',
#  'chapter entire franchise',
#  'movie hard time',
#  'performance ryan gosling',
#  'fun 90 minute',
#  'classic fairy tales',
#  'war takes people',
#  'romero original dawn',
#  'climate change deniers',
#  'chinese labor camp',
#  'performance tilda swinton',
#  'lawrence michael levine',
#  'bond father daughter',
#  '8217 highly entertaining',
#  'didn leave theater',
#  'loud incredibly close',
#  'live action cartoon',
#  'budget review spanish',
#  'comedy highest order',
#  'humor heart proves',
#  'career crowning performance',
#  'plays like modern',
#  'action vile technique',
#  'dialogue keeps pace',
#  'frank miller graphic',
#  'reasonably good time',
#  'way pass time',
#  'watching great performers',
#  'scene make skin',
#  'scrappy little movie',
#  'connection se7en animal',
#  'fast paced action',
#  'awkward pacing aside',
#  'film try deal',
#  'director anders thomas',
#  'makes forget watching',
#  'despite solid performances',
#  'viewer feel antithetical',
#  'joy watch 46',
#  'recall past lives',
#  'performance elevates film',
#  'despedida robert altman',
#  'think dr seuss',
#  'look pretty good',
#  'tale dysfunctional family',
#  'just plain funny',
#  'new york times',
#  'delivers magnetic performance',
#  'luc godard bande',
#  'josh kriegman elyse',
#  '44 apos thanks',
#  'love story real',
#  'oldman gives performance',
#  '46 apos difficult',
#  'hit french film',
#  'like wall currently',
#  'impressive battle scenes',
#  'moving best problem',
#  'funny ll laugh',
#  'time public burned',
#  'don want end',
#  'way sum film',
#  'fascinating true story',
#  'inventing new ways',
#  'space jam sequel',
#  'action scenes involving',
#  'old fashioned spy',
#  'wrenching true story',
#  'does just turn',
#  'oscar winning actor',
#  'just talent screen',
#  'went let pulled',
#  'film isn good',
#  'america civil war',
#  'gives film depth',
#  'bad words isn',
#  'keeps story moving',
#  'max reveals endearing',
#  'time think ve',
#  'years best film',
#  'rescue dark hearted',
#  'american high school',
#  'action adventure yarn',
#  'double lives hosoda',
#  'surprisingly thought provoking',
#  '8221 rom coms',
#  'norwegian black metal',
#  'essay baltimore dealt',
#  'big screen impossible',
#  'black white footage',
#  'contrived plot points',
#  'good looking girls',
#  'helen hunt oscar',
#  'drama sharp script',
#  'character development just',
#  'scraping soundscape moral',
#  '8217 dark comedy',
#  'thanks superb performances',
#  'feel home world',
#  'come quite time',
#  'tissue paper director',
#  'country worth seeing',
#  'doesn allow simple',
#  'plodding ness talkiness',
#  'heavy subject matter',
#  'movie glides like',
#  'return form woody',
#  'terrific romantic comedy',
#  'best thing remake',
#  'right review spanish',
#  'director writer christos',
#  'finding true love',
#  'saying positively man',
#  'series feels like',
#  'rare beasts bold',
#  'film finds audience',
#  'man smart funny',
#  'fu panda revisits',
#  'kore eda doesn',
#  'director alice lowe',
#  'make skin crawl',
#  'best disney animated',
#  'liberty equality fraternity',
#  'adding new layers',
#  'far interesting titular',
#  'goods better popcorn',
#  'style action scenes',
#  'old fairytale digital',
#  'solo star wars',
#  'dealing heavy themes',
#  'entire franchise 44',
#  'weve reviewed short',
#  'eye opening look',
#  'heart beat unless',
#  'movie trades heavily',
#  'talented cast script',
#  'certainly bad film',
#  'thrillers like french',
#  'motion capture technology',
#  'time incredible performances',
#  'damon unshowy subtle',
#  'keeping audience edge',
#  'best film come',
#  'making apocalypse entertaining',
#  'film disconcerting rawness',
#  'originality review spanish',
#  've seen stories',
#  'makes highly entertaining',
#  'long film arrives',
#  'american hip hop',
#  'year ron gone',
#  'story emotional core',
#  'best films 44',
#  'van sant shot',
#  '44 quite simply',
#  'hard feel like',
#  'tension filled story',
#  'film really finds',
#  'complete content details',
#  'score philip glass',
#  'does fine job',
#  'end 44 8220',
#  'carlos boellinger feature',
#  'confrontation plays like',
#  'gorgeously animated beautifully',
#  'head heels love',
#  'gratuitously delightful touches',
#  'vision new european',
#  'michael apted film',
#  'tim eric billion',
#  'motivation character development',
#  'make good bad',
#  'life death 46',
#  'william wyler 1959',
#  '8217 best performance',
#  'computer animated comedy',
#  'll richly rewarded',
#  'league extraordinary gentlemen',
#  'experience won soon',
#  'richly rewarding film',
#  'chilling darkly hilarious',
#  'lot fun 46',
#  'heart warming story',
#  'instantly takes place',
#  'bite refuse let',
#  'loving homage movies',
#  'que em vez',
#  'think 10 000',
#  'recalls tragedy orpheus',
#  'movie waste time',
#  'despite inconsistent script',
#  'unusual love story',
#  'obsessively investigates gray',
#  'loyal horror freaks',
#  'great love story',
#  'space dead dare',
#  'eye roll worthy',
#  'american film institute',
#  'central love story',
#  'make worth time',
#  'orson scott card',
#  'blood review spanish',
#  'film speaks directly',
#  'director danny leiner',
#  'looking blood soaked',
#  'result isn quite',
#  'film 44 apos',
#  'film just kind',
#  'john carpenter thing',
#  'film told traditional',
#  'family adventure film',
#  'just doesn add',
#  'graphically violent thriller',
#  'strong performances especially',
#  'action scenes great',
#  'film instead brutal',
#  'time worrying product',
#  'quiet low key',
#  'song sparrows rest',
#  'delivers action spectacle',
#  'phoebe dynevor alden',
#  '46 ironic 44',
#  'tough complex portrait',
#  'nearly hours long',
#  'life finds way',
#  'heart 44 apos',
#  'quot ant man',
#  '2012 delivers disaster',
#  '20 best films',
#  'early bond films',
#  'brings fresh perspective',
#  'movie forward thinking',
#  'director john butler',
#  'docs ve seen',
#  'directed superbly written',
#  'kindness strangers plays',
#  'times little silly',
#  'things just happen',
#  'creepy outright scary',
#  'music corny jokes',
#  'couldn come better',
#  'offline double lives',
#  'borg vs mcenroe',
#  'bones review spanish',
#  'academia heroes rising',
#  'john lee hancock',
#  'struggles consistent tone',
#  '58 quantumania quot',
#  'sharing scenes 46',
#  'exit gift shop',
#  'director writer unable',
#  'middle aged men',
#  'make big statements',
#  'good good bad',
#  'elderly lunatic happy',
#  'isn doing favours',
#  'screen minutes little',
#  'best sense word',
#  'poor affleck hangs',
#  'world couple hours',
#  'role reduced carrying',
#  'target audience movie',
#  've got lot',
#  'psychological slow burn',
#  'direction thought provoking',
#  'underreported mainstream news',
#  'leave warm fuzzy',
#  'brand thing altogether',
#  '70 movies like',
#  'war zone men',
#  'twice long twice',
#  'didn love movie',
#  'american civil rights',
#  'polsky film took',
#  'routine crime thriller',
#  'telegraphed mile away',
#  'kirby ellen burstyn',
#  'van sant psycho',
#  'depiction everyday life',
#  'outlandish ridiculously enjoyable',
#  'characters strong sense',
#  'rudd jennifer aniston',
#  'matter fact approach',
#  'film takes place',
#  'remarkably pleasurable ways',
#  'martial arts flicks',
#  'predictable bland end',
#  'mrs henderson presents',
#  'fails justify existence',
#  'films years 46',
#  'feature directing debut',
#  'real life people',
#  'isn quite great',
#  'empathy review spanish',
#  'action movie summer',
#  'funny just plain',
#  'lot like love',
#  'godard mon amour',
#  'treats female lead',
#  'night miami offers',
#  'world kanako mixed',
#  'earn passing grade',
#  'kölsch dennis widmyer',
#  'hardly petty cash',
#  'satire finest films',
#  'horror movies year',
#  'lingers mind long',
#  'clich 233 marvel',
#  'left seeing start',
#  'counter tick slow',
#  'deserve easily best',
#  'brahm 257 stra',
#  'beasts secrets dumbledore',
#  'emotional high notes',
#  'party review spanish',
#  'pacino robert niro',
#  'tribute sci fi',
#  'actor promised best',
#  'kids island lost',
#  'film feels fun',
#  'oscar best picture',
#  'nightmares come life',
#  'kingdom doesn movie',
#  'feels fresh original',
#  'wish fulfillment fantasy',
#  'themes black white',
#  'hit audience head',
#  'action movie better',
#  'clever gender bending',
#  'instant american classic',
#  'good time film',
#  'king directorial debut',
#  'couldn help feel',
#  'anchored outstanding performances',
#  'story makes sense',
#  'belongs hoffman precisely',
#  'people quite comes',
#  'sumptuous production design',
#  'right crafted spooky',
#  'fully embraces inherent',
#  'romantic comedy like',
#  '70s period piece',
#  'biggest commercial hit',
#  'called plodding ness',
#  'doesn quite manage',
#  'plays like erotic',
#  'likely heist thriller',
#  'bong class satire',
#  'dead things eat',
#  'mortality fixated salute',
#  'naturally performing overwritten',
#  'beautifully shot tale',
#  'compelling real life',
#  'tickle funny bone',
#  'story true story',
#  'edited action sequences',
#  'doesn bring new',
#  'really make film',
#  'great direction excellent',
#  'gentility charm banderas',
#  'entire film shot',
#  'worth seeing nétflix',
#  'close kind magnificent',
#  'gets cake eat',
#  'adele exarchopoulos lea',
#  'beautiful piece work',
#  'lot admire innovative',
#  'small town america',
#  '93 minutes 46',
#  'nature versus nurture',
#  'couldn aided observational',
#  'solid coming age',
#  'tale king crab',
#  'middle aged people',
#  'won dry eye',
#  'worst person world',
#  'involving portrait couples',
#  'fortune 58 ruse',
#  'better movie social',
#  'story doesn work',
#  'seus preconceitos ao',
#  'tonal issues aside',
#  'apotheosis disaster movies',
#  'comedy good laughs',
#  'probably won make',
#  'opaque oddity like',
#  'snowman 40 having',
#  'probably want watch',
#  'kiddie space adventure',
#  'action hero 46',
#  'drama strong performances',
#  'robert wagner jeffrey',
#  'won audience award',
#  'prejudice review spanish',
#  'impressive point big',
#  'subdued turns anthony',
#  'staggering punch awfulness',
#  'hecht page mark',
#  'kind film sends',
#  'predictable jump scares',
#  'rare instance movie',
#  'plan outer space',
#  'best children films',
#  'film 2012 wolf',
#  'long shot painfully',
#  'stiff upper lip',
#  'day rock hudson',
#  'living life online',
#  'subject matter 44',
#  'bold attempt different',
#  'carice van houten',
#  'laugh ll ll',
#  'anthony dod mantle',
#  'takes dark turn',
#  'far horror movies',
#  'family friendly film',
#  'success film rests',
#  'fails cast spell',
#  'results eye opening',
#  'fiction review spanish',
#  'meted repetitive boo',
#  'sharper sharper focus',
#  'movie seen recent',
#  'little going zeitgeist',
#  'good presentation film',
#  'ghost does absolutely',
#  'bad 44 8217',
#  'experience miyazaki light',
#  'meal ve eaten',
#  'lovely beautifully acted',
#  'waaaaay talky overcomplicated',
#  'odd life timothy',
#  'doesn 8217 characters',
#  'director patrick creadon',
#  'lowery green knight',
#  'old saturday night',
#  'director amma asante',
#  'simple love story',
#  'bong fashioned darkly',
#  'actually quite interesting',
#  'make movie place',
#  'high tech thriller',
#  'tom carroll ross',
#  'feels like songs',
#  'slow start movie',
#  'romantic comedies year',
#  'leads just ordinary',
#  'movie sticks ribs',
#  'watching big screen',
#  'susanna white second',
#  'doesn come better',
#  'swiss army man',
#  'light hearted fun',
#  'length animated cartoon',
#  'director adam shankman',
#  'adaptation ian mcewan',
#  'secret life walter',
#  'thing feels like',
#  'kaufman michel gondry',
#  'thought provoking experience',
#  'big screen movie',
#  'like masterpiece theater',
#  'stereotypes rude language',
#  'wrote directed film',
#  'doesn exactly make',
#  'men dark phoenix',
#  'film sense humor',
#  'performance single handedly',
#  'heart vocals playful',
#  'tight 90 minutes',
#  'clocks loose 90',
#  'know ve seen',
#  'solid feature debut',
#  'tim burton batman',
#  'dark hearted movie',
#  '8217 think 8221',
#  'thriller fairy tale',
#  '17th century dutch',
#  'bitter pill swallow',
#  'big screen performance',
#  'mccarthy matt damon',
#  'time family films',
#  'exactly make riveting',
#  'doesn 8217 necessarily',
#  'rare american movie',
#  'performance olivia wilde',
#  'engaging thanks enthusiasm',
#  'sequel life probably',
#  'fans right expect',
#  'goes far longer',
#  'like animation studio',
#  'film delving relationship',
#  'result isn compelling',
#  'epic adventure maximum',
#  'heart cold war',
#  'real glimpses beguiling',
#  '13 years ago',
#  'intellect wit great',
#  'fitting end trilogy',
#  'work dealing heavy',
#  'hard look away',
#  'survivor testimony stands',
#  'miss fares better',
#  'timeless film power',
#  'constantly left balance',
#  'strongest film years',
#  'couldn really tell',
#  'make worth trip',
#  'past sell date',
#  'men good film',
#  'sant collection young',
#  'light subject matter',
#  've appetite destruction',
#  'let unlikeable lead',
#  'feels like half',
#  'superhero action film',
#  'hangover don expect',
#  'heart proves athletic',
#  'gets great start',
#  'teen titans movies',
#  'documentary 1967 america',
#  'coogan rob brydon',
#  'apos feel good',
#  'puzzle box film',
#  'sci fi meets',
#  'film sense urgency',
#  'come spring step',
#  'bollywood police thriller',
#  'start feel like',
#  'stephanie spray pacho',
#  'maximum security prison',
#  'genuinely scary movie',
#  'like movie written',
#  'mirren ryan reynolds',
#  '46 46 essentially',
#  'language film oscar',
#  've left theater',
#  'make good actors',
#  'bound disappoint fans',
#  'james bond movies',
#  'film works undercut',
#  'like iron man',
#  'video game characters',
#  'delivers exactly promises',
#  'underworld franchise good',
#  'bringing character life',
#  'matt damon best',
#  'apos shy away',
#  'independence time delivers',
#  'packs emotional punch',
#  'burnt orange heresy',
#  'watch dives thematically',
#  'career director writer',
#  'friendly horror flick',
#  'black comedy elements',
#  'paced action packed',
#  'movie filmmakers hard',
#  'film festival circuit',
#  'quite moving documentary',
#  'just like good',
#  'look feel like',
#  'movies ve seen',
#  'leads battle sequence',
#  'bad movie stretch',
#  'sniper 58 white',
#  'audiences itching continued',
#  'free floating anxiety',
#  'budget adaptation ayn',
#  'film lack imagination',
#  'democratic presidential candidate',
#  ...}

# %% [markdown]
# `Get common words within training text corpus`

# %%
df_shuffled = rt_senti.sample(frac=1)
df_splits = np.array_split(df_shuffled, 5)
# for df in df_splits:
#     print(df.shape)
#     display(df)

# %%
common_unigrams_train = get_common_vocab(df_splits, ngram_range_list=[(1,1)])
common_unigrams_train
# Out:
# Generating vocabulary for ngram_range: (1, 1)...
# Vocabulary for ngram-range (1, 1) in df: 34534
# Generating vocabulary for ngram_range: (1, 1)...
# Vocabulary for ngram-range (1, 1) in df: 34661
# Generating vocabulary for ngram_range: (1, 1)...
# Vocabulary for ngram-range (1, 1) in df: 34747
# Generating vocabulary for ngram_range: (1, 1)...
# Vocabulary for ngram-range (1, 1) in df: 34407
# Generating vocabulary for ngram_range: (1, 1)...
# Vocabulary for ngram-range (1, 1) in df: 34365
# Common vocabulary for ngram-range (1, 1): 16711
# {'races',
#  'likewise',
#  'cumulative',
#  'center',
#  'antidote',
#  'starry',
#  'mamma',
#  'honored',
#  'simply',
#  'republican',
#  'poisonous',
#  'frantic',
#  'adding',
#  'mcdonald',
#  'occasional',
#  'enterprise',
#  'dexterity',
#  'destination',
#  'downton',
#  '1939',
#  'longings',
#  'pictorial',
#  'fou',
#  'wolfe',
#  'jerking',
#  'slavery',
#  'adjust',
#  'kiki',
#  'destroy',
#  'concessions',
#  'opposed',
#  'subconscious',
#  'awakening',
#  'threadbare',
#  'lensed',
#  'aspire',
#  'undistinguished',
#  'amazing',
#  'press',
#  'ringing',
#  'latinx',
#  'salvage',
#  'sharper',
#  'abyss',
#  'threat',
#  'gonzo',
#  'weathered',
#  'represents',
#  'uninterested',
#  'doubted',
#  'automatically',
#  'eda',
#  'surprisingly',
#  'va',
#  'massively',
#  'loyalty',
#  'leadership',
#  'monitor',
#  'seven',
#  'kissinger',
#  'shortcomings',
#  'ersatz',
#  'severely',
#  'citizenfour',
#  'voiceover',
#  'jake',
#  'shows',
#  'private',
#  'pursuit',
#  'nazi',
#  'colorful',
#  'situations',
#  'plunge',
#  'vocally',
#  'probe',
#  'zimmer',
#  'channeling',
#  'jittery',
#  'wigs',
#  'tempered',
#  'vittorio',
#  'freedoms',
#  'scarred',
#  'erudite',
#  'floating',
#  'unexplored',
#  'itching',
#  'uninteresting',
#  'psychedelic',
#  'devour',
#  'knowledge',
#  'ghosts',
#  'scabrous',
#  'acrobatics',
#  'shattering',
#  'rushing',
#  'wary',
#  'babe',
#  'hordes',
#  'amid',
#  'metaphoric',
#  'dollop',
#  'crammed',
#  'slices',
#  'heyday',
#  'percent',
#  'batman',
#  'hellraiser',
#  'docu',
#  'magically',
#  'kechiche',
#  'candy',
#  'charlotte',
#  'surly',
#  'harmful',
#  'addled',
#  'lumbers',
#  'green',
#  'uncluttered',
#  'priest',
#  'woes',
#  'addams',
#  'valid',
#  'geek',
#  'submission',
#  'hader',
#  'outbursts',
#  'distribution',
#  'memoir',
#  'desk',
#  'detracts',
#  'shoots',
#  'award',
#  'behave',
#  'aground',
#  'society',
#  'revved',
#  'ought',
#  'pc',
#  '84',
#  'textbook',
#  'persona',
#  'rock',
#  'bombast',
#  'athletes',
#  'overreaching',
#  'immortals',
#  'help',
#  'japan',
#  'puff',
#  'marcus',
#  'vance',
#  'fragile',
#  'kubrick',
#  'marianne',
#  'kyle',
#  'relatable',
#  'leconte',
#  'spirals',
#  'mackenzie',
#  'caesar',
#  'provocation',
#  'sant',
#  'agreed',
#  'breezily',
#  'pilot',
#  'funding',
#  'organized',
#  'contributes',
#  'solidarity',
#  'questionable',
#  'silences',
#  'fictionalized',
#  'conversion',
#  'experimentation',
#  'salt',
#  'clothing',
#  'deranged',
#  'fashion',
#  'fuller',
#  'inviting',
#  'kris',
#  'rees',
#  'unnamed',
#  'diverse',
#  'invents',
#  'principled',
#  'interminable',
#  'minimalist',
#  'poker',
#  'amy',
#  'advertisement',
#  'collins',
#  'fennell',
#  'pleasant',
#  'ryan',
#  'electrical',
#  'hauntingly',
#  'ignites',
#  'prisons',
#  'peppy',
#  'prankster',
#  'tries',
#  'joke',
#  'wear',
#  '1976',
#  'truthful',
#  'mrs',
#  'tempest',
#  'adhere',
#  'softening',
#  'grating',
#  'element',
#  'dances',
#  'heartstrings',
#  'simplified',
#  'nadir',
#  'capture',
#  'recognize',
#  'hugely',
#  'uninspiring',
#  'remainder',
#  'fbi',
#  'pulled',
#  'indie',
#  'repeating',
#  'regina',
#  'crossover',
#  'yuletide',
#  'upper',
#  'endgame',
#  'plant',
#  'propulsive',
#  'favorite',
#  'vocabulary',
#  'enraging',
#  'espionage',
#  'fatherhood',
#  'quantities',
#  'impishness',
#  'mcavoy',
#  'baggage',
#  'marlon',
#  'origin',
#  'financial',
#  'hoffman',
#  'bening',
#  'vacuous',
#  'insidious',
#  'humor',
#  'elevate',
#  'reynolds',
#  'cuckoo',
#  'ah',
#  'filthy',
#  'researched',
#  'answers',
#  'becker',
#  'parks',
#  'prada',
#  'base',
#  'substitutes',
#  'overflows',
#  'splendidly',
#  'antic',
#  'projected',
#  'mite',
#  'sellers',
#  'products',
#  'ang',
#  'euphoria',
#  'translating',
#  'surefire',
#  'conceits',
#  'dirge',
#  'messaging',
#  'bravura',
#  'blake',
#  'guru',
#  'ashes',
#  'diminished',
#  'shoot',
#  'smile',
#  'notebook',
#  'milestone',
#  'senseless',
#  'dips',
#  'tenacity',
#  'wheel',
#  'pressing',
#  'orleans',
#  'cornish',
#  'distinctively',
#  'adversary',
#  'subgenre',
#  'influx',
#  'portman',
#  'rejuvenation',
#  'effortless',
#  'troubles',
#  'engulf',
#  'maine',
#  'rocket',
#  'happyness',
#  'meaningful',
#  'extracted',
#  'marketing',
#  'counterfeit',
#  'frights',
#  'quartet',
#  'daredevil',
#  'sept',
#  'participants',
#  'bleaker',
#  'democracy',
#  'bets',
#  'walked',
#  'disturbingly',
#  'letter',
#  'warped',
#  'flipping',
#  'pawlikowski',
#  '17',
#  'armas',
#  'fulfilling',
#  'cannily',
#  'difference',
#  'slogan',
#  'compose',
#  'vampires',
#  'asian',
#  'visibility',
#  'grapes',
#  'jigsaw',
#  'tentpole',
#  'flynn',
#  'drip',
#  'keke',
#  'sexuality',
#  'bruises',
#  'pen',
#  'kurzel',
#  'tart',
#  'kubo',
#  'club',
#  'undercooked',
#  'increase',
#  'wrote',
#  'mystery',
#  'pineapple',
#  '16mm',
#  'dogs',
#  'kicked',
#  'menacing',
#  'sentimentality',
#  'riz',
#  'rewrite',
#  'etched',
#  'sicko',
#  'seeps',
#  'thurber',
#  'definition',
#  'nba',
#  'colin',
#  'skies',
#  'cedar',
#  'curse',
#  'unfolding',
#  'childhoods',
#  'platform',
#  'bonding',
#  'georgia',
#  'landmarks',
#  'type',
#  'leroy',
#  'banality',
#  'showgirls',
#  'coalesces',
#  'atmosphere',
#  'collaborative',
#  'deficiencies',
#  'incompetent',
#  'toned',
#  '106',
#  'context',
#  'woolf',
#  'taika',
#  'investing',
#  'traveled',
#  'nash',
#  'profile',
#  'area',
#  'confronts',
#  'feature',
#  'manipulation',
#  'dot',
#  'script',
#  'member',
#  'twee',
#  'sustained',
#  'contributions',
#  'independent',
#  'diego',
#  'rushed',
#  'bouncy',
#  'scope',
#  'eminem',
#  'schematic',
#  'aforementioned',
#  'regal',
#  'observed',
#  'conta',
#  'focal',
#  'campbell',
#  'puss',
#  'clinical',
#  'harsh',
#  'comedian',
#  'contrasting',
#  'expand',
#  'ms',
#  'purge',
#  'persuasively',
#  'value',
#  'mountain',
#  '2018',
#  'sadistic',
#  'felix',
#  'scholars',
#  'promotion',
#  'wears',
#  'ian',
#  'idea',
#  'supplies',
#  'highlights',
#  'houses',
#  'tolerably',
#  'bleakest',
#  'frustrate',
#  'chases',
#  'behavior',
#  'distorted',
#  'changer',
#  'mitchum',
#  'showers',
#  'overstate',
#  'fascinating',
#  'ellroy',
#  'tammy',
#  'emerging',
#  'depth',
#  'countdown',
#  'breaking',
#  'advice',
#  'carell',
#  'fervour',
#  'sprinkle',
#  'loser',
#  'cage',
#  'cleavage',
#  'talents',
#  'barrels',
#  'custody',
#  'safety',
#  'brien',
#  'imelda',
#  'lark',
#  'spunky',
#  'hitler',
#  'complain',
#  'unfulfilling',
#  'cutoff',
#  'skewed',
#  '2016',
#  'void',
#  'trans',
#  'boobs',
#  'hire',
#  'saddest',
#  'print',
#  'goddard',
#  'spiritual',
#  'regime',
#  'symphonic',
#  'briskly',
#  'kaleidoscope',
#  'succession',
#  'delicious',
#  'daze',
#  'leader',
#  'ashton',
#  'promise',
#  'answering',
#  'drippy',
#  'achieve',
#  'animator',
#  'mute',
#  'ghibli',
#  'hint',
#  'scottish',
#  'upscale',
#  'aiming',
#  'cops',
#  'punchy',
#  'glows',
#  'opus',
#  'uneventful',
#  'inserted',
#  'dvd',
#  'yi',
#  'substantial',
#  'basic',
#  'diesel',
#  'chess',
#  'explanation',
#  'autonomy',
#  'com',
#  'gift',
#  'honk',
#  'proposes',
#  'queasy',
#  'cohen',
#  'arrived',
#  'closed',
#  'pbs',
#  'taken',
#  'li',
#  'treatment',
#  'characterizations',
#  'costa',
#  'laziest',
#  'compassion',
#  'penguins',
#  'subtle',
#  'caliber',
#  'gangsters',
#  'eschewing',
#  'operating',
#  'heller',
#  'swoon',
#  'hefty',
#  'disarming',
#  'muddles',
#  'rigorous',
#  'sebastián',
#  'benefits',
#  'le',
#  'tingling',
#  'hovers',
#  'subtly',
#  'bullwinkle',
#  'trilogy',
#  'singing',
#  'schneider',
#  'strengths',
#  'tradition',
#  'margot',
#  'wheeling',
#  'pic',
#  'chutzpah',
#  'act',
#  'whistling',
#  'femme',
#  '1989',
#  'eric',
#  'thought',
#  'hubie',
#  'debauched',
#  'planes',
#  'restricted',
#  'disappoints',
#  'shoah',
#  'pap',
#  'avalanche',
#  'adversity',
#  'folks',
#  'elbow',
#  'growing',
#  'man',
#  'missing',
#  'marilyn',
#  'pines',
#  'bogdanovich',
#  'sitting',
#  'fantastically',
#  'illuminate',
#  'hot',
#  'wobbly',
#  'assertion',
#  'shallows',
#  'lovable',
#  'warm',
#  'spectators',
#  'fiddle',
#  'scenic',
#  'debuts',
#  'unengaging',
#  'dakota',
#  'acknowledged',
#  'applauded',
#  'forwards',
#  'sorts',
#  'especially',
#  'potent',
#  'harris',
#  'sock',
#  'arguable',
#  'date',
#  'companies',
#  'fifth',
#  'stew',
#  'accidentally',
#  'untethered',
#  'shed',
#  'delve',
#  'catastrophe',
#  'verdict',
#  'hysterical',
#  'unmatched',
#  'maintain',
#  'distilled',
#  'hoss',
#  'reversed',
#  'roughly',
#  'alert',
#  'faustian',
#  'duvall',
#  'impressionistic',
#  'mati',
#  'launching',
#  'chatter',
#  'dress',
#  'mckenzie',
#  'zodiac',
#  'fatuous',
#  'gorbachev',
#  'rear',
#  'ricky',
#  'scale',
#  'inconsistent',
#  'troubled',
#  'cloth',
#  'cain',
#  'cult',
#  'uncovered',
#  'realised',
#  'comically',
#  'beginners',
#  'teens',
#  '18',
#  'personas',
#  'reitman',
#  'sense',
#  'nobel',
#  'retire',
#  'continuity',
#  'exhibiting',
#  'southpaw',
#  'listening',
#  'writers',
#  '16',
#  'catch',
#  'demonstrate',
#  'gen',
#  'fields',
#  'louder',
#  'eternal',
#  'articulate',
#  'undemanding',
#  'contributed',
#  'chunk',
#  'thrall',
#  'mocking',
#  'fiasco',
#  'sharpened',
#  'hate',
#  'sony',
#  'motion',
#  'microscopic',
#  'sunset',
#  'debt',
#  'sane',
#  'dash',
#  'luther',
#  'dickens',
#  'feints',
#  'gerwig',
#  'ronald',
#  'figuratively',
#  'dutiful',
#  'torn',
#  'novella',
#  'cool',
#  'mightily',
#  'daydreams',
#  'bias',
#  'aplenty',
#  'toting',
#  'bruckheimer',
#  'varied',
#  'sputters',
#  'parking',
#  'toby',
#  'lovelorn',
#  'attributed',
#  'stirred',
#  'terminator',
#  'mikey',
#  'entire',
#  'commentary',
#  'guffaw',
#  'india',
#  'aspiration',
#  'gasping',
#  'terrain',
#  'fully',
#  'brad',
#  'beneath',
#  'wanna',
#  'west',
#  'hemingway',
#  'concludes',
#  'loyal',
#  'hijinks',
#  'emblematic',
#  'hitman',
#  'output',
#  'operation',
#  'jazz',
#  'booze',
#  'putin',
#  'offices',
#  'thugs',
#  'lush',
#  'curmudgeon',
#  'harrelson',
#  'babadook',
#  'hue',
#  'miserable',
#  'peele',
#  'immoral',
#  'hectic',
#  'lola',
#  'intimidation',
#  'warning',
#  'pluck',
#  'cylinders',
#  'observe',
#  'egos',
#  'crackerjack',
#  'clich',
#  'overlook',
#  'horrific',
#  'duris',
#  'horny',
#  'lt',
#  'photogenic',
#  'highest',
#  'accents',
#  'goods',
#  'uncommon',
#  'derivative',
#  'shy',
#  'raiders',
#  'violent',
#  'moist',
#  'irritating',
#  'warming',
#  'jagger',
#  'suggested',
#  'founded',
#  'amazement',
#  'toxic',
#  'weighty',
#  'shoes',
#  'chair',
#  'gothic',
#  'richness',
#  'duller',
#  'caruso',
#  'function',
#  'duplicity',
#  'street',
#  'wilson',
#  'waver',
#  'anomaly',
#  'quieter',
#  'plumb',
#  'stuck',
#  'curious',
#  'appetites',
#  'rose',
#  'assassin',
#  'redemptive',
#  'undeniably',
#  'rivette',
#  'hostile',
#  'recreation',
#  'overly',
#  'cineastes',
#  'underwhelmed',
#  'predicated',
#  'initially',
#  'anna',
#  'spawned',
#  'crop',
#  'scolding',
#  'documentary',
#  'marginal',
#  'perez',
#  'corrosive',
#  'weave',
#  'overview',
#  'amidst',
#  'dive',
#  'upset',
#  'caricature',
#  'enlightening',
#  'semblance',
#  'boldness',
#  'tics',
#  'witness',
#  'infamous',
#  'personable',
#  'chopped',
#  'orchestration',
#  'mayer',
#  '47',
#  'yielding',
#  'institutions',
#  'panther',
#  'beach',
#  'unintentional',
#  'breathless',
#  'communal',
#  'failings',
#  'potency',
#  'sir',
#  'hilarity',
#  'tati',
#  'planted',
#  'confrontation',
#  'ridiculously',
#  'challenged',
#  'elevates',
#  'strictly',
#  'analogy',
#  'bristles',
#  '2001',
#  'kelly',
#  'consistency',
#  'supplying',
#  'colours',
#  'extra',
#  'lesson',
#  'economics',
#  'claude',
#  'decay',
#  'knee',
#  'shawkat',
#  'holy',
#  'comparing',
#  'rave',
#  'ferrara',
#  'cassidy',
#  'fodder',
#  'flights',
#  'bites',
#  'attuned',
#  'copying',
#  'fruitless',
#  '25',
#  'fruitful',
#  'kid',
#  'nature',
#  'displacement',
#  '8217',
#  'worm',
#  'peak',
#  'founder',
#  'objective',
#  'tess',
#  '3d',
#  'neo',
#  'fathom',
#  'woody',
#  'bats',
#  'atlas',
#  'dimly',
#  'elbows',
#  'hayek',
#  'gusto',
#  'surrounding',
#  'elizabeth',
#  'memoirs',
#  'workings',
#  'excalibur',
#  'wai',
#  'flooding',
#  'spectacle',
#  'boys',
#  'cameras',
#  'timely',
#  'soldier',
#  'signal',
#  'reminds',
#  'baroque',
#  'boulevard',
#  'external',
#  'embodied',
#  'gabriel',
#  'jacques',
#  'messy',
#  'hating',
#  'honorable',
#  'extract',
#  'bounce',
#  'borat',
#  'drifting',
#  'titular',
#  'futile',
#  'inserts',
#  'inessential',
#  'alliance',
#  'considering',
#  'transgressive',
#  'main',
#  'negro',
#  'drain',
#  'send',
#  'summit',
#  'succeed',
#  'nations',
#  'astoundingly',
#  'appallingly',
#  'surface',
#  'sterile',
#  'collapses',
#  'lie',
#  'brazilian',
#  'ranking',
#  'kitty',
#  'mackie',
#  'provide',
#  'spreading',
#  'undermining',
#  'negative',
#  'depraved',
#  'rebellion',
#  'martyrdom',
#  'bereavement',
#  'interested',
#  'excruciating',
#  'prisoners',
#  'unexceptional',
#  'transitions',
#  'abdul',
#  'capacity',
#  'hawk',
#  'glimpses',
#  'erin',
#  'cg',
#  'mined',
#  'fumbling',
#  'flirtation',
#  'upsetting',
#  'astutely',
#  'debating',
#  'routinely',
#  'poop',
#  'tangle',
#  'facebook',
#  'landed',
#  'caribbean',
#  'untapped',
#  'fulfilment',
#  'patiently',
#  'freed',
#  'causing',
#  'twentysomething',
#  'charade',
#  'zone',
#  'cleansing',
#  'riches',
#  'lebron',
#  'nailing',
#  'frighteningly',
#  'costume',
#  'branagh',
#  'familiarly',
#  'hipster',
#  'instruments',
#  'direo',
#  'whirlwind',
#  'win',
#  'suited',
#  'instability',
#  'uma',
#  'gus',
#  'hovering',
#  ...}

# %%
sorted(list(common_unigrams_train))[:212]
# Out:
# ['000',
#  '007',
#  '10',
#  '100',
#  '101',
#  '104',
#  '105',
#  '106',
#  '108',
#  '109',
#  '11',
#  '110',
#  '111',
#  '11th',
#  '12',
#  '120',
#  '127',
#  '13',
#  '130',
#  '133',
#  '134',
#  '136',
#  '137',
#  '138',
#  '13th',
#  '14',
#  '140',
#  '1408',
#  '146',
#  '15',
#  '150',
#  '16',
#  '160',
#  '16mm',
#  '17',
#  '18',
#  '18th',
#  '19',
#  '1917',
#  '1920',
#  '1920s',
#  '1930s',
#  '1938',
#  '1939',
#  '1940s',
#  '1941',
#  '1942',
#  '1950',
#  '1950s',
#  '1951',
#  '1953',
#  '1954',
#  '1955',
#  '1956',
#  '1958',
#  '1959',
#  '1960',
#  '1960s',
#  '1961',
#  '1962',
#  '1963',
#  '1964',
#  '1966',
#  '1967',
#  '1968',
#  '1969',
#  '1970',
#  '1970s',
#  '1972',
#  '1973',
#  '1974',
#  '1976',
#  '1977',
#  '1978',
#  '1980',
#  '1980s',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990s',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '19th',
#  '1st',
#  '20',
#  '200',
#  '2000',
#  '2000s',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2010s',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019',
#  '2020',
#  '2021',
#  '2022',
#  '2023',
#  '20s',
#  '20th',
#  '21',
#  '21st',
#  '22',
#  '225',
#  '23',
#  '233',
#  '24',
#  '25',
#  '25th',
#  '28',
#  '29',
#  '2d',
#  '2nd',
#  '30',
#  '300',
#  '30s',
#  '31',
#  '33',
#  '35',
#  '36',
#  '360',
#  '38',
#  '39',
#  '3d',
#  '3rd',
#  '40',
#  '400',
#  '40s',
#  '41',
#  '42',
#  '43',
#  '44',
#  '45',
#  '46',
#  '47',
#  '48',
#  '50',
#  '500',
#  '50s',
#  '52',
#  '56',
#  '58',
#  '59',
#  '5th',
#  '60',
#  '60s',
#  '63',
#  '65',
#  '65279',
#  '666',
#  '70',
#  '70s',
#  '71',
#  '72',
#  '73',
#  '74',
#  '75',
#  '77',
#  '80',
#  '80s',
#  '81',
#  '82',
#  '8203',
#  '8211',
#  '8212',
#  '8216',
#  '8217',
#  '8220',
#  '8221',
#  '8230',
#  '8232',
#  '83',
#  '84',
#  '85',
#  '86',
#  '87',
#  '88',
#  '90',
#  '90s',
#  '91',
#  '93',
#  '94',
#  '95',
#  '96',
#  '99']

# %%
sorted(list(common_unigrams_train))[100:300]
# Out:
# ['2000s',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2010s',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019',
#  '2020',
#  '2021',
#  '2022',
#  '2023',
#  '20s',
#  '20th',
#  '21',
#  '21st',
#  '22',
#  '225',
#  '23',
#  '233',
#  '24',
#  '25',
#  '25th',
#  '28',
#  '29',
#  '2d',
#  '2nd',
#  '30',
#  '300',
#  '30s',
#  '31',
#  '33',
#  '35',
#  '36',
#  '360',
#  '38',
#  '39',
#  '3d',
#  '3rd',
#  '40',
#  '400',
#  '40s',
#  '41',
#  '42',
#  '43',
#  '44',
#  '45',
#  '46',
#  '47',
#  '48',
#  '50',
#  '500',
#  '50s',
#  '52',
#  '56',
#  '58',
#  '59',
#  '5th',
#  '60',
#  '60s',
#  '63',
#  '65',
#  '65279',
#  '666',
#  '70',
#  '70s',
#  '71',
#  '72',
#  '73',
#  '74',
#  '75',
#  '77',
#  '80',
#  '80s',
#  '81',
#  '82',
#  '8203',
#  '8211',
#  '8212',
#  '8216',
#  '8217',
#  '8220',
#  '8221',
#  '8230',
#  '8232',
#  '83',
#  '84',
#  '85',
#  '86',
#  '87',
#  '88',
#  '90',
#  '90s',
#  '91',
#  '93',
#  '94',
#  '95',
#  '96',
#  '99',
#  'aardman',
#  'aaron',
#  'abandon',
#  'abandoned',
#  'abandoning',
#  'abandonment',
#  'abandons',
#  'abbey',
#  'abbott',
#  'abby',
#  'abc',
#  'abduction',
#  'abdul',
#  'abe',
#  'abel',
#  'abiding',
#  'abilities',
#  'ability',
#  'abject',
#  'able',
#  'ably',
#  'aboard',
#  'abominable',
#  'abortion',
#  'abound',
#  'abounds',
#  'abraham',
#  'abrams',
#  'abrasive',
#  'abroad',
#  'abrupt',
#  'abruptly',
#  'abs',
#  'absence',
#  'absent',
#  'absolute',
#  'absolutely',
#  'absorb',
#  'absorbed',
#  'absorbing',
#  'absorption',
#  'abstract',
#  'absurd',
#  'absurdist',
#  'absurdities',
#  'absurdity',
#  'absurdly',
#  'abu',
#  'abundance',
#  'abundant',
#  'abundantly',
#  'abuse',
#  'abused',
#  'abuses',
#  'abusive',
#  'abysmal',
#  'abyss',
#  'academic',
#  'academy',
#  'accent',
#  'accents',
#  'accept',
#  'acceptable',
#  'acceptance',
#  'accepted',
#  'accepting',
#  'access',
#  'accessible',
#  'accident',
#  'accidental',
#  'accidentally',
#  'accidents',
#  'acclaim',
#  'acclaimed',
#  'accolades',
#  'accompanied',
#  'accompany',
#  'accompanying',
#  'accomplish',
#  'accomplished',
#  'accomplishes',
#  'accomplishment',
#  'accomplishments',
#  'according',
#  'accordingly',
#  'account',
#  'accountant',
#  'accounting']

# %% [markdown]
# ## Common vocabulary in train that is also in test

# %%
len(common_unigrams_train & common_unigrams)
# Out:
# 16400

# %%
sorted(list(common_unigrams_train & common_unigrams))[:100]
# Out:
# ['000',
#  '007',
#  '10',
#  '100',
#  '101',
#  '104',
#  '105',
#  '106',
#  '108',
#  '109',
#  '11',
#  '110',
#  '11th',
#  '12',
#  '120',
#  '127',
#  '13',
#  '130',
#  '133',
#  '136',
#  '138',
#  '13th',
#  '14',
#  '140',
#  '1408',
#  '146',
#  '15',
#  '150',
#  '16',
#  '160',
#  '16mm',
#  '17',
#  '18',
#  '18th',
#  '19',
#  '1917',
#  '1920s',
#  '1930s',
#  '1938',
#  '1939',
#  '1940s',
#  '1941',
#  '1942',
#  '1950',
#  '1950s',
#  '1951',
#  '1953',
#  '1954',
#  '1955',
#  '1956',
#  '1958',
#  '1959',
#  '1960',
#  '1960s',
#  '1961',
#  '1962',
#  '1963',
#  '1964',
#  '1966',
#  '1967',
#  '1968',
#  '1969',
#  '1970',
#  '1970s',
#  '1972',
#  '1973',
#  '1974',
#  '1976',
#  '1977',
#  '1978',
#  '1980',
#  '1980s',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990s',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '19th',
#  '1st',
#  '20',
#  '200',
#  '2000',
#  '2000s',
#  '2001',
#  '2002',
#  '2003']

# %% [markdown]
# ## Vocabulary after replacing numbers with empty string in reviewText column (manual method)

# %%
# Replace numbers with empty string in reviewText
rt_tr_pure_str = rt_senti.copy()
rt_tr_pure_str["reviewText"] = rt_senti["reviewText"].str.replace('\d+', '', regex=True)
rt_tr_pure_str
# Out:
#                                                reviewText sentiment
# 0       Henry Selick’s first movie since ’s Coraline. ...  POSITIVE
# 1       With a cast that reads like the Vogue Oscar pa...  NEGATIVE
# 2       Creed II does not give us anything but another...  POSITIVE
# 3       I know what you're thinking, but this is no Li...  POSITIVE
# 4       Director Fernando Meirelles tells the story wi...  POSITIVE
# ...                                                   ...       ...
# 162753  A top-notch thriller with genuine surprises an...  POSITIVE
# 162754  Some people find Derek Zoolander funny and lik...  NEGATIVE
# 162755  This fun, gentle comedy focuses mainly on them...  POSITIVE
# 162756  The film is rescued by a strong third act, but...  NEGATIVE
# 162757          A peerless exercise in stimulus response.  POSITIVE
#
# [162758 rows x 2 columns]

# %%
# Replace numbers with empty string in reviewText
rt_test_pure_str = rt_test.copy()
rt_test_pure_str["reviewText"] = rt_test["reviewText"].str.replace('\d+', '', regex=True)
rt_test_pure_str
# Out:
#                                               reviewText
# 0      Green slowly cranks up the dread with style an...
# 1      Philip Noyce's direction is elegant and unforc...
# 2      It wouldn't do to say what path Maria ultimate...
# 3      Pig is not exactly the arthouse John Wick that...
# 4      An imaginative no-budget musical of sorts abou...
# ...                                                  ...
# 55310  Ron Howard delivers an unconventional romantic...
# 55311  As an oddball art film that openly invites you...
# 55312  Nicholson wears his devilish grin from his fir...
# 55313  It's hard not be entertained by two dozen of C...
# 55314  Not clever enough for Smith fans, not gross en...
#
# [55315 rows x 1 columns]

# %%
df_shuffled_pure_str = rt_tr_pure_str.sample(frac=1)
df_splits_pure_str = np.array_split(df_shuffled_pure_str, 5)
# for df in df_splits:
#     print(df.shape)
#     display(df)

# %%
common_unigrams_train_pure_str = get_common_vocab(df_splits_pure_str, ngram_range_list=[(1,1)])
common_unigrams_train_pure_str
# Out:
# Generating vocabulary for ngram_range: (1, 1)...
# Vocabulary for ngram-range (1, 1) in df: 34255
# Generating vocabulary for ngram_range: (1, 1)...
# Vocabulary for ngram-range (1, 1) in df: 34093
# Generating vocabulary for ngram_range: (1, 1)...
# Vocabulary for ngram-range (1, 1) in df: 34309
# Generating vocabulary for ngram_range: (1, 1)...
# Vocabulary for ngram-range (1, 1) in df: 33959
# Generating vocabulary for ngram_range: (1, 1)...
# Vocabulary for ngram-range (1, 1) in df: 34234
# Common vocabulary for ngram-range (1, 1): 16595
# {'races',
#  'likewise',
#  'cumulative',
#  'center',
#  'antidote',
#  'mamma',
#  'simply',
#  'honored',
#  'republican',
#  'poisonous',
#  'frantic',
#  'adding',
#  'mcdonald',
#  'occasional',
#  'enterprise',
#  'dexterity',
#  'destination',
#  'downton',
#  'pictorial',
#  'wolfe',
#  'jerking',
#  'slavery',
#  'adjust',
#  'kiki',
#  'hypnotically',
#  'destroy',
#  'concessions',
#  'opposed',
#  'subconscious',
#  'awakening',
#  'liar',
#  'threadbare',
#  'lensed',
#  'aspire',
#  'undistinguished',
#  'amazing',
#  'press',
#  'stomping',
#  'salvage',
#  'sharper',
#  'abyss',
#  'threat',
#  'gonzo',
#  'weathered',
#  'represents',
#  'uninterested',
#  'automatically',
#  'harding',
#  'eda',
#  'surprisingly',
#  'massively',
#  'loyalty',
#  'leadership',
#  'seven',
#  'shortcomings',
#  'ersatz',
#  'severely',
#  'citizenfour',
#  'voiceover',
#  'jake',
#  'slime',
#  'shows',
#  'private',
#  'pursuit',
#  'nazi',
#  'colorful',
#  'situations',
#  'plunge',
#  'probe',
#  'zimmer',
#  'channeling',
#  'jittery',
#  'wigs',
#  'tempered',
#  'fold',
#  'joachim',
#  'thrusting',
#  'vittorio',
#  'freedoms',
#  'erudite',
#  'floating',
#  'unexplored',
#  'uninteresting',
#  'psychedelic',
#  'devour',
#  'blossom',
#  'knowledge',
#  'ghosts',
#  'shattering',
#  'rushing',
#  'wary',
#  'babe',
#  'alps',
#  'hordes',
#  'amid',
#  'metaphoric',
#  'dollop',
#  'crammed',
#  'turd',
#  'slices',
#  'heyday',
#  'styling',
#  'magically',
#  'batman',
#  'percent',
#  'docu',
#  'kechiche',
#  'candy',
#  'surly',
#  'charlotte',
#  'harmful',
#  'addled',
#  'lumbers',
#  'green',
#  'repulsed',
#  'uncluttered',
#  'priest',
#  'woes',
#  'addams',
#  'valid',
#  'corporations',
#  'geek',
#  'cramped',
#  'hader',
#  'submission',
#  'outbursts',
#  'memoir',
#  'desk',
#  'detracts',
#  'shoots',
#  'award',
#  'behave',
#  'fickle',
#  'skarsgard',
#  'society',
#  'goldsworthy',
#  'revved',
#  'ought',
#  'textbook',
#  'persona',
#  'rock',
#  'bombast',
#  'athletes',
#  'overreaching',
#  'help',
#  'japan',
#  'fragile',
#  'puff',
#  'marcus',
#  'vance',
#  'kubrick',
#  'marianne',
#  'kyle',
#  'relatable',
#  'leconte',
#  'spirals',
#  'mackenzie',
#  'misleading',
#  'caesar',
#  'provocation',
#  'sant',
#  'breezily',
#  'pilot',
#  'organized',
#  'contributes',
#  'solidarity',
#  'questionable',
#  'silences',
#  'fictionalized',
#  'conversion',
#  'experimentation',
#  'salt',
#  'clothing',
#  'deranged',
#  'derive',
#  'fashion',
#  'armando',
#  'scrambling',
#  'inviting',
#  'fuller',
#  'rees',
#  'unnamed',
#  'rev',
#  'diverse',
#  'contexts',
#  'principled',
#  'interminable',
#  'safer',
#  'minimalist',
#  'poker',
#  'elsie',
#  'amy',
#  'gratingly',
#  'advertisement',
#  'collins',
#  'fennell',
#  'pleasant',
#  'ryan',
#  'hauntingly',
#  'ignites',
#  'castro',
#  'prisons',
#  'overplay',
#  'tries',
#  'joke',
#  'wear',
#  'burly',
#  'truthful',
#  'mrs',
#  'tempest',
#  'adhere',
#  'flapping',
#  'grating',
#  'element',
#  'dances',
#  'heartstrings',
#  'simplified',
#  'nadir',
#  'capture',
#  'recognize',
#  'hugely',
#  'uninspiring',
#  'fbi',
#  'preternatural',
#  'pulled',
#  'indie',
#  'repeating',
#  'regina',
#  'sliver',
#  'crossover',
#  'yuletide',
#  'dollhouse',
#  'endgame',
#  'upper',
#  'plant',
#  'propulsive',
#  'favorite',
#  'enraging',
#  'espionage',
#  'fatherhood',
#  'mcavoy',
#  'marlon',
#  'baggage',
#  'origin',
#  'financial',
#  'hoffman',
#  'bening',
#  'vacuous',
#  'insidious',
#  'insignificance',
#  'humor',
#  'elevate',
#  'reynolds',
#  'cuckoo',
#  'lures',
#  'ah',
#  'filthy',
#  'researched',
#  'answers',
#  'coopers',
#  'becker',
#  'parks',
#  'prada',
#  'base',
#  'substitutes',
#  'splendidly',
#  'antic',
#  'projected',
#  'samaritan',
#  'sellers',
#  'products',
#  'ang',
#  'euphoria',
#  'mite',
#  'luna',
#  'translating',
#  'surefire',
#  'conceits',
#  'dirge',
#  'messaging',
#  'bravura',
#  'blake',
#  'guru',
#  'ashes',
#  'diminished',
#  'shoot',
#  'smile',
#  'notebook',
#  'milestone',
#  'senseless',
#  'trainwreck',
#  'tenacity',
#  'dips',
#  'pressing',
#  'wheel',
#  'orleans',
#  'cornish',
#  'distinctively',
#  'adversary',
#  'subgenre',
#  'portman',
#  'effortless',
#  'troubles',
#  'maine',
#  'rocket',
#  'extracted',
#  'meaningful',
#  'bottomless',
#  'gaspar',
#  'marketing',
#  'frights',
#  'quartet',
#  'daredevil',
#  'sept',
#  'participants',
#  'bleaker',
#  'democracy',
#  'bets',
#  'walked',
#  'disturbingly',
#  'letter',
#  'warped',
#  'flipping',
#  'pawlikowski',
#  'apostle',
#  'fulfilling',
#  'cannily',
#  'flavored',
#  'difference',
#  'balthazar',
#  'vampires',
#  'asian',
#  'visibility',
#  'jigsaw',
#  'tentpole',
#  'flynn',
#  'drip',
#  'sexuality',
#  'kurzel',
#  'tart',
#  'kubo',
#  'shifty',
#  'club',
#  'undercooked',
#  'increase',
#  'wrote',
#  'mystery',
#  'pineapple',
#  'dogs',
#  'kicked',
#  'menacing',
#  'sentimentality',
#  'riz',
#  'rewrite',
#  'etched',
#  'sicko',
#  'seeps',
#  'zendaya',
#  'definition',
#  'colin',
#  'skies',
#  'cedar',
#  'curse',
#  'unfolding',
#  'childhoods',
#  'landmarks',
#  'bonding',
#  'georgia',
#  'platform',
#  'type',
#  'leroy',
#  'banality',
#  'showgirls',
#  'coalesces',
#  'atmosphere',
#  'deficiencies',
#  'wasteland',
#  'incompetent',
#  'toned',
#  'context',
#  'woolf',
#  'deadened',
#  'taika',
#  'investing',
#  'traveled',
#  'profile',
#  'area',
#  'cartoony',
#  'snazzy',
#  'abusing',
#  'feature',
#  'confronts',
#  'manipulation',
#  'dot',
#  'script',
#  'member',
#  'twee',
#  'tuxedo',
#  'sustained',
#  'slush',
#  'contributions',
#  'independent',
#  'diego',
#  'rushed',
#  'bouncy',
#  'scope',
#  'eminem',
#  'schematic',
#  'aforementioned',
#  'regal',
#  'observed',
#  'focal',
#  'campbell',
#  'puss',
#  'clinical',
#  'harsh',
#  'comedian',
#  'expand',
#  'contrasting',
#  'ms',
#  'purge',
#  'persuasively',
#  'value',
#  'mountain',
#  'gunman',
#  'sadistic',
#  'felix',
#  'promotion',
#  'yu',
#  'afternoons',
#  'wears',
#  'ian',
#  'idea',
#  'supplies',
#  'highlights',
#  'houses',
#  'bleakest',
#  'frustrate',
#  'chases',
#  'behavior',
#  'undiminished',
#  'mitchum',
#  'changer',
#  'overstate',
#  'fascinating',
#  'distorted',
#  'tammy',
#  'emerging',
#  'depth',
#  'countdown',
#  'breaking',
#  'advice',
#  'carell',
#  'safety',
#  'cage',
#  'cleavage',
#  'talents',
#  'barrels',
#  'custody',
#  'loser',
#  'brien',
#  'mavis',
#  'lark',
#  'kiarostami',
#  'spunky',
#  'hitler',
#  'complain',
#  'satirist',
#  'patter',
#  'cutoff',
#  'skewed',
#  'print',
#  'void',
#  'trans',
#  'caffeinated',
#  'hire',
#  'saddest',
#  'substituting',
#  'goddard',
#  'spiritual',
#  'regime',
#  'symphonic',
#  'jot',
#  'briskly',
#  'kaleidoscope',
#  'succession',
#  'delicious',
#  'leader',
#  'ashton',
#  'promise',
#  'answering',
#  'drippy',
#  'achieve',
#  'animator',
#  'mute',
#  'ghibli',
#  'hint',
#  'scottish',
#  'upscale',
#  'aiming',
#  'cops',
#  'punchy',
#  'glows',
#  'opus',
#  'uneventful',
#  'inserted',
#  'organizing',
#  'dvd',
#  'substantial',
#  'basic',
#  'diesel',
#  'chess',
#  'explanation',
#  'autonomy',
#  'com',
#  'gift',
#  'honk',
#  'proposes',
#  'closed',
#  'cohen',
#  'queasy',
#  'arrived',
#  'taken',
#  'li',
#  'treatment',
#  'characterizations',
#  'earliest',
#  'costa',
#  'laziest',
#  'compassion',
#  'volver',
#  'penguins',
#  'darting',
#  'subtle',
#  'caliber',
#  'gangsters',
#  'eschewing',
#  'bumblebee',
#  'operating',
#  'heller',
#  'swoon',
#  'hefty',
#  'disarming',
#  'muddles',
#  'rigorous',
#  'remnants',
#  'sebastián',
#  'benefits',
#  'gals',
#  'le',
#  'tingling',
#  'hovers',
#  'subtly',
#  'trilogy',
#  'singing',
#  'nd',
#  'schneider',
#  'strengths',
#  'tradition',
#  'margot',
#  'pic',
#  'chutzpah',
#  'act',
#  'femme',
#  'eric',
#  'thought',
#  'planes',
#  'restricted',
#  'disappoints',
#  'shoah',
#  'pap',
#  'avalanche',
#  'adversity',
#  'folks',
#  'elbow',
#  'growing',
#  'man',
#  'missing',
#  'marilyn',
#  'pines',
#  'bogdanovich',
#  'sitting',
#  'fantastically',
#  'illuminate',
#  'hot',
#  'wobbly',
#  'screenplays',
#  'assertion',
#  'shallows',
#  'lovable',
#  'presidency',
#  'warm',
#  'spectators',
#  'fiddle',
#  'scenic',
#  'projector',
#  'debuts',
#  'unengaging',
#  'dakota',
#  'acknowledged',
#  'applauded',
#  'sorts',
#  'especially',
#  'astronauts',
#  'potent',
#  'harris',
#  'date',
#  'companies',
#  'fifth',
#  'stew',
#  'accidentally',
#  'smartphone',
#  'shed',
#  'delve',
#  'catastrophe',
#  'verdict',
#  'hysterical',
#  'maintain',
#  'hoss',
#  'roughly',
#  'alert',
#  'craze',
#  'duvall',
#  'lehane',
#  'impressionistic',
#  'chatter',
#  'dress',
#  'mckenzie',
#  'zodiac',
#  'fatuous',
#  'rear',
#  'ricky',
#  'scale',
#  'inconsistent',
#  'troubled',
#  'cain',
#  'instinctive',
#  'cult',
#  'realised',
#  'comically',
#  'beginners',
#  'teens',
#  'personas',
#  'reitman',
#  'sense',
#  'nobel',
#  'retire',
#  'continuity',
#  'southpaw',
#  'listening',
#  'writers',
#  'demo',
#  'catch',
#  'demonstrate',
#  'gen',
#  'ineffectual',
#  'louder',
#  'fields',
#  'eternal',
#  'articulate',
#  'undemanding',
#  'chunk',
#  'mocking',
#  'fiasco',
#  'adoring',
#  'hate',
#  'sony',
#  'unstructured',
#  'motion',
#  'sunset',
#  'debt',
#  'dash',
#  'dickens',
#  'zooming',
#  'luther',
#  'feints',
#  'gerwig',
#  'ronald',
#  'figuratively',
#  'dutiful',
#  'torn',
#  'novella',
#  'cool',
#  'daydreams',
#  'mightily',
#  'aplenty',
#  'bias',
#  'toting',
#  'bruckheimer',
#  'varied',
#  'snatchers',
#  'toby',
#  'lovelorn',
#  'stirred',
#  'terminator',
#  'mikey',
#  'entire',
#  'occurring',
#  'commentary',
#  'india',
#  'aspiration',
#  'gasping',
#  'terrain',
#  'fully',
#  'brad',
#  'beneath',
#  'wanna',
#  'west',
#  'hemingway',
#  'unfurls',
#  'dreamgirls',
#  'concludes',
#  'loyal',
#  'hijinks',
#  'emblematic',
#  'hitman',
#  'output',
#  'operation',
#  'catalogue',
#  'jazz',
#  'booze',
#  'putin',
#  'offices',
#  'thugs',
#  'lush',
#  'snide',
#  'harrelson',
#  'curmudgeon',
#  'hue',
#  'miserable',
#  'peele',
#  'imitate',
#  'unspeakable',
#  'hectic',
#  'warning',
#  'cylinders',
#  'pluck',
#  'observe',
#  'passon',
#  'crackerjack',
#  'egos',
#  'clich',
#  'overlook',
#  'horrific',
#  'armed',
#  'horny',
#  'lt',
#  'photogenic',
#  'highest',
#  'accents',
#  'goods',
#  'uncommon',
#  'unacceptable',
#  'shy',
#  'derivative',
#  'raiders',
#  'violent',
#  'moist',
#  'smoky',
#  'warming',
#  'jagger',
#  'irritating',
#  'suggested',
#  'founded',
#  'amazement',
#  'bader',
#  'toxic',
#  'weighty',
#  'shoes',
#  'chair',
#  'gothic',
#  'richness',
#  'caruso',
#  'function',
#  'duplicity',
#  'street',
#  'wilson',
#  'waver',
#  'anomaly',
#  'quieter',
#  'plumb',
#  'stuck',
#  'curious',
#  'appetites',
#  'rose',
#  'assassin',
#  'redemptive',
#  'undeniably',
#  'apathetic',
#  'rivette',
#  'hostile',
#  'hairpin',
#  'graff',
#  'overly',
#  'recreation',
#  'underwhelmed',
#  'xander',
#  'initially',
#  'anna',
#  'concocts',
#  'spawned',
#  'crop',
#  'documentary',
#  'marginal',
#  'justine',
#  'corrosive',
#  'overview',
#  'weave',
#  'amidst',
#  'dive',
#  'upset',
#  'caricature',
#  'enlightening',
#  'attaining',
#  'semblance',
#  'boldness',
#  'tics',
#  'witness',
#  'infamous',
#  'personable',
#  'chopped',
#  'orchestration',
#  'mayer',
#  'glittery',
#  'yielding',
#  'institutions',
#  'panther',
#  'saggy',
#  'beach',
#  'unintentional',
#  'breathless',
#  'communal',
#  'failings',
#  'airbender',
#  'potency',
#  'sir',
#  'phoning',
#  'hilarity',
#  'sf',
#  'tati',
#  'planted',
#  'confrontation',
#  'ridiculously',
#  'challenged',
#  'elevates',
#  'strictly',
#  'morel',
#  'bristles',
#  'kelly',
#  'consistency',
#  'supplying',
#  'colours',
#  'extra',
#  'fabled',
#  'lesson',
#  'economics',
#  'claude',
#  'decay',
#  'knee',
#  'holy',
#  'comparing',
#  'rave',
#  'cassidy',
#  'fodder',
#  'molina',
#  'flights',
#  'bites',
#  'attuned',
#  'fruitful',
#  'kid',
#  'nature',
#  'displacement',
#  'peak',
#  'founder',
#  'objective',
#  'tess',
#  'fathom',
#  'neo',
#  'woody',
#  'famuyiwa',
#  'atlas',
#  'hayek',
#  'surrounding',
#  'elizabeth',
#  'gusto',
#  'wai',
#  'workings',
#  'excalibur',
#  'memoirs',
#  'spectacle',
#  'boys',
#  'cameras',
#  'timely',
#  'invoked',
#  'soldier',
#  'alain',
#  'signal',
#  'reminds',
#  'baroque',
#  'boulevard',
#  'external',
#  'rodents',
#  'embodied',
#  'gabriel',
#  'jacques',
#  'messy',
#  'hating',
#  'honorable',
#  'extract',
#  'bounce',
#  'borat',
#  'titular',
#  'futile',
#  'alliance',
#  'inessential',
#  'considering',
#  'drain',
#  'transgressive',
#  'main',
#  'send',
#  'summit',
#  'succeed',
#  'nations',
#  'astoundingly',
#  'appallingly',
#  'surface',
#  'sterile',
#  'collapses',
#  'lie',
#  'brazilian',
#  'ranking',
#  'kitty',
#  'mackie',
#  'provide',
#  'undermining',
#  'negative',
#  'brice',
#  'depraved',
#  'masina',
#  'rebellion',
#  'martyrdom',
#  'interested',
#  'excruciating',
#  'prisoners',
#  'unexceptional',
#  'transitions',
#  'suspiciously',
#  'capacity',
#  'abdul',
#  'hawk',
#  'glimpses',
#  'erin',
#  'mined',
#  'cg',
#  'fumbling',
#  'upsetting',
#  'astutely',
#  'debating',
#  'routinely',
#  'tangle',
#  'poop',
#  'bloodrayne',
#  'facebook',
#  'landed',
#  'caribbean',
#  'excavation',
#  'cemented',
#  'untapped',
#  'transfixed',
#  'patiently',
#  'freed',
#  'causing',
#  'zone',
#  'charade',
#  'cleansing',
#  'riches',
#  'nailing',
#  'frighteningly',
#  'costume',
#  'branagh',
#  'hipster',
#  'instruments',
#  'win',
#  'whirlwind',
#  'instability',
#  'suited',
#  'uma',
#  'gus',
#  'hovering',
#  'nothingness',
#  'formally',
#  'zom',
#  'hug',
#  'spandex',
#  'grizzled',
#  'mastering',
#  'newspapers',
#  'bouts',
#  'ron',
#  'confection',
#  ...}

# %%
sorted(list(common_unigrams_train_pure_str))[:210]
# Out:
# ['aardman',
#  'aaron',
#  'abandon',
#  'abandoned',
#  'abandonment',
#  'abandons',
#  'abbey',
#  'abbott',
#  'abc',
#  'abduction',
#  'abdul',
#  'abe',
#  'abel',
#  'abide',
#  'abiding',
#  'abigail',
#  'abilities',
#  'ability',
#  'able',
#  'ably',
#  'aboard',
#  'abominable',
#  'abomination',
#  'aboriginal',
#  'abortion',
#  'abound',
#  'abounds',
#  'abraham',
#  'abrahamson',
#  'abrams',
#  'abrasive',
#  'abroad',
#  'abrupt',
#  'abruptly',
#  'absence',
#  'absent',
#  'absolute',
#  'absolutely',
#  'absolution',
#  'absorb',
#  'absorbed',
#  'absorbing',
#  'absorbs',
#  'absorption',
#  'abstract',
#  'abstraction',
#  'abstruse',
#  'absurd',
#  'absurdist',
#  'absurdities',
#  'absurdity',
#  'absurdly',
#  'abu',
#  'abundance',
#  'abundant',
#  'abundantly',
#  'abuse',
#  'abused',
#  'abusing',
#  'abusive',
#  'abysmal',
#  'abyss',
#  'acaba',
#  'academic',
#  'academy',
#  'accent',
#  'accents',
#  'accept',
#  'acceptable',
#  'acceptably',
#  'acceptance',
#  'accepted',
#  'accepting',
#  'access',
#  'accessible',
#  'accident',
#  'accidental',
#  'accidentally',
#  'acclaim',
#  'acclaimed',
#  'accolades',
#  'accompanied',
#  'accompaniment',
#  'accompany',
#  'accompanying',
#  'accomplish',
#  'accomplished',
#  'accomplishes',
#  'accomplishing',
#  'accomplishment',
#  'accomplishments',
#  'according',
#  'accordingly',
#  'account',
#  'accounts',
#  'accumulation',
#  'accuracy',
#  'accurate',
#  'accurately',
#  'accusations',
#  'accuse',
#  'accused',
#  'accustomed',
#  'ace',
#  'acerbic',
#  'aces',
#  'ache',
#  'achieve',
#  'achieved',
#  'achievement',
#  'achievements',
#  'achieves',
#  'achieving',
#  'aching',
#  'achingly',
#  'acid',
#  'acidic',
#  'acknowledge',
#  'acknowledged',
#  'acknowledges',
#  'acknowledging',
#  'acquired',
#  'acquires',
#  'acrobatic',
#  'act',
#  'acted',
#  'acting',
#  'action',
#  'actioner',
#  'actioners',
#  'actions',
#  'active',
#  'actively',
#  'activism',
#  'activist',
#  'activists',
#  'activities',
#  'activity',
#  'actor',
#  'actorly',
#  'actors',
#  'actress',
#  'actresses',
#  'acts',
#  'actual',
#  'actually',
#  'acute',
#  'acutely',
#  'ad',
#  'adage',
#  'adaline',
#  'adam',
#  'adams',
#  'adapt',
#  'adaptation',
#  'adaptations',
#  'adapted',
#  'adapting',
#  'adapts',
#  'add',
#  'addams',
#  'added',
#  'addicted',
#  'addiction',
#  'addicts',
#  'adding',
#  'addition',
#  'additional',
#  'addled',
#  'address',
#  'addressed',
#  'addresses',
#  'addressing',
#  'adds',
#  'adept',
#  'adequate',
#  'adequately',
#  'adhere',
#  'adherence',
#  'adhering',
#  'adjacent',
#  'adjective',
#  'adjust',
#  'administration',
#  'admirable',
#  'admirably',
#  'admiration',
#  'admire',
#  'admired',
#  'admirers',
#  'admiring',
#  'admission',
#  'admissions',
#  'admit',
#  'admitted',
#  'admittedly',
#  'adolescence',
#  'adolescent',
#  'adolescents',
#  'adoption',
#  'adopts',
#  'adorable',
#  'adoration',
#  'adore',
#  'adoring',
#  'adrenaline',
#  'adrien',
#  'adrift',
#  'adroit',
#  'adroitly']

# %%
# Find rows containing numbers in rt_tr_pure_str
print(rt_tr_pure_str.shape)
dfff = rt_tr_pure_str["reviewText"][rt_tr_pure_str["reviewText"].str.contains(r'\d', case=False, regex=True)]
dfff.shape, dfff.head()
# dfff.to_csv("dfff.csv", index=False)
# Out:
# (162758, 2)
# ((0,), Series([], Name: reviewText, dtype: object))

# %% [markdown]
# ## Vocabulary after replacing numbers with empty string in reviewText column (strip_accents='unicode')
